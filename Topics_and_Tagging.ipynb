# %% [markdown]
# <a href="https://colab.research.google.com/github/SrishtiPatil/supervised-methods-for-text-categorization/blob/main/Topics_and_Tagging.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
#Do this with all train, test and validation
data = pd.read_csv('/test_freq.txt', delimiter = "\t",header=None)
data.columns = ['text']
data['speaker'] = data['text'].str.split(': ').str[0]
data['message'] = data['text'].str.split(': ').str[1]
data.head(5)
# Out:
#                                                 text  ...                                            message
# 0  Speaker 0: Did you know that the University of...  ...  Did you know that the University of Iowa's loc...
# 1  Speaker 1: I think I did hear something about ...  ...  I think I did hear something about that.  I im...
# 2  Speaker 0: So, it would be in the visiting tea...  ...  So, it would be in the visiting team's locker ...
# 3  Speaker 1: Right.  Teams do all kinds of thing...  ...  Right.  Teams do all kinds of things to bother...
# 4  Speaker 0: I would hate a cold bench. Then aga...  ...  I would hate a cold bench. Then again, I would...
#
# [5 rows x 3 columns]

# %%
Tag_dict = {'CARDINAL':['100','4','one','four','only one','only 1','1','two','20','over 1.5 million','1.5 million','1 million','about 20','zeros','10','ten','12','2','between them two','three','31','thousand','23','about 12','less than 63','nine','over 220','224','5','over 300','4000','3000','16','38 billion','9','millions','15 million','5 billion','half','32000','85','39','at least three','8','only 16','almost 150','five','3','about eight grand','only about two and a half','24','less than half','22','seven','eight','200','180','just hundreds','about 200','95','51','196','21','more than 180','270 million','8.5 billion','300000','600','25','643','100 or so','60','at least one','14.1','13','55000','more than 55','0','about 500','0','more than 7 million','70','only quarter of a million years ago','zero','four-fifths','2013','50','14','1760','37','125','about 1/3','50 million','about 2 billion','a third','9pm-12am','youtube','dozens','40 million','324','2263','thousands','only two','only 100','over 100','wasnt','10000','more than 495 million','7','1900s','between 5','000 and 6','0','almost 3','18','80','only 8','41','186','more than ten thousand','3 million','137 million','2 billion','274','1000','more than one','17','1904','directed','800','up to 1000','101','18000000','22 trillion','over 5 million','6','114','66','48','4673','2430','5 million','over 300 million','300 million','0.209027778','more than 5 million','about 5 million','120','4','5','0-3','around four','160000','1700','11','2400','45 to 55 million','six','more than 1','about 160','a dozen','half 103','123000','73 2','92','2500','267','75','160k','98','4d','75 million','104 billion','168 million','274 million','350','9000','300','40','#1','almost 1 billion','almost four hundred','only 30','they;re','over 180','2011','44257','about 1200','only 20','435','billions','47','about 5','about 4 million','130000','about 5 or','4 million','7.25','hundred','26','a thousand','at least over 100 million','15','over half','1936','250 million','64','79','2000','30','54','2.2 million','only 50 million','1100','almost 200','90','99.86','1 billion','over 30 million','only 79 million','360','500k','65 billion','over 150','2020','around 12 million','415000000','almost one','almost 324','5.5','4x','226','almost 4x','58.46 million','1.53','around a third','about 58 million','over 250 million','10-21-80','over 250','100 million','50s','53 million','about a hundred and fifty','six four','no more than 2','2048','only 37','ten thousand','356','about 2000','almost half','109','19','400000','minus 50','245','132','82','more than 130','11.4 million','11 million','around 250','0','26/50','at least 5','about all 3','69','weekends','50000','9 million','over 7 million','around 1 million','7 million','16bit','about 180','about one','up to 12','1800','quarter','do.when','81','0.053472222','0','roughly 455','eleven','about 123','0','455','86','tesla','over 86','4700','2363','330000','about 330','0','around 1.5 million','1s','0s','over 200','about 109','approximately 300','3pointer','73','190','a dozen or so','150','3ds','400k','750','some one','14.9','almost 1 million','at least 10','5000','just 15','im','51','more than 2/3','only 21','123k','346000','96','40-year','36','half a million','32','55','roughly about 450','4h','almost 80','154','over 130 million','200 million','over 137 million','7500','up to 4','250','mor than 20','more than 137 million','9pm','12am','a few dozen','1500','almost 4','at least 17','only four','about 25','almost 300','only 54','4k','at least 1','0','fifteen','more than 350 million','million','over 4 million','so many millions','130745','they d','more than 250 million','only five','so many more 3','1.65 billion','410','35','44289','at least a 1000','21 billion','147 million','only about half','a quarter','about a third','1000000','almost 60 million','about half','58 million','only 18','10000000','hundreds of thousands','twelve','33','10 million','15k','2 seasons','80 billion','40s','2.2 billion','more than 6 million','s$123','0','over 1000','over 1','0','900 million','0.189583333','16-bit','about 160','0','only 13','7 billion','only 32','a couple of hundred of dollars','more than 54','27','15000000','616','42370','minus 380','armstrong and 11','about 100','over 100 million','nearly 137 million','nearly half','44256','15000','2200','at least 15 million','over 5 billion','18042','about 3/4','five to seven','203','203rd','335','700k','4.5 billion','115','only 5.5','a billion','137','about 137 million','44228','one third','just millions','74','3 billion','more than 20','three to four','13.1','more than three','a couple hundred','about ten','3d','a million','an estimated 7 million','5o','at least 18','about 25-30','1/6th','about 2','263','65','124','about 54','thousands or hundreds','around 50bc','137000000','6 thousand','tens of thousands','50/50','more than 24','49.09','about five','only 2','24-3.25','123','over 1 million','43','56',':)','400','160','over 40','about 2 and 1/2 hours','about 2200','over 2200','5.7 billion','145','about 320','over 2','0','up to billions','2049','almost a million','more than 300','about 140 million','about 60 million','oct-18','only 4','73 million','220v','110','more than 25','20 million','fifteen thousand','15145','dozen','about 4','about four','103','every 200 to 300 thousand years','only 3','number 23','9.8','22 million','every 200 to 300','105','126','more than nine','2.5','100000','8.62 billion','like 400','1.2 billion','542 million','1.8 billion','4.25','about 1 million','more than 2 million','3.7','44509','700000','nearly half million','44290','just a quarter a million years ago','nearly half a million','12 million','more than half','more than 455','58','44472','57','amazing!the','1.8 million','two thirds','21.9 billion','140 million','60 million','97','800k','800000','32000000','585 million','more than two','over 67 million','6.02','25 million','nearly the 1/16','1.5','only 70 million','312','at least two','no.1','59 million','over 400','135000','5 to seven','more than 2.2','at least 10 million','almost 33','29','800 thousand','another 32 million','about 8k','up to 180','140','m8','only 50','500 thousand','almost half million','2014','only half','44319','9s','at least 30','roughly 15','32 million','100k','8.6','two dozen','about 113','5.4','45','114.6','only three','over 7','111.1','3s','like 15 million','over a thousand','212','all four','4500','about two','about 30','27.95','700','75000','fifty','less than 100','less than 18','nearly a hundred','27 million','146 million','over 27 million','over 11 million','at least 58.46 million','number 1','8000','only 2.7','20000','over 130','0','only 300','40000','2600','four million','between 9pm-12am','at least all 50','two million','up to 8','over 2','263','366.26','215','2300','only 5','7.6 billion','about 7 million','about a hundred fifty thousand','over 300','000 euro','over 20','just two','00 to 07','72','just 54','3072','up to 200','around 150','0.16875','about 13','about 3','309','8.5 million','05-oct','100s','100 billion','about 10','0','5min','90000','78','1750','20/20','78 million','340 million','about a quarter-million','about 8','almost 1','almost five thousand','20-yr','more than 200','39/50','fewer than 8','50mil','over 60 million','44','more than 2x','about 5000','like 4','2pac','275','27 billion','153 million','524 million','2x','over 1k','500 million','almost 2 billion','odd.lol','twenty','movie','more than 2 billion','1billionth','more than 1000','33.33333333','at least 13','6 million','90 million','just one','over 50','over 15','0','at least 1/3','139 million','more than 50 million','0.395833333','41699','nearly 100','0','34','285','just 1','like 270 million','an additional 500k','8.5','26.5 million','about 50 million','93','5x','around 40 million','9pm-12','over 2.2 million','about 2015','320','521','hilarious.j','about 2500','99','234 million','only about 5','between seven and fifteen miles','8 plus','12.75 million','about 103','over 103','more than 37','more than 103','over 58 million','around 350','every quarter of a second','about one and a half','about 15','mid','911','only about 3','90 000','less than 50','111','about 5.5 million','just about 2','819','almost 125','0','only 9','5s','4s','only 15','one million','55','only one-tenth','500','4.5','only like 100','under 200','almost four','every 200','000 to 300','000 years','20-20','over 350','almost 5 fold','just 224','30000','11000','7000','up to four','212?n','more than 2','0.763','116','over 30','about four million','16 million','only 16 million','more than 140','0','0','3.57','120k','200o','like four','over a hundred thousand','10.5','oct-20','about 2','0','over 70','0','between 32','0','34','0','8 billion','eighty-two to zero','more than 70','0','thirteen','only 973','234','312000','about 150.00','40-50','two and a half','542 millions','256','between 300','only one record','13000','so many thousands of years','86000','as many as 12','at least 3rd','49ers','as many','18.9','91','less than 3rd','3months','about 2','about 3 million','around 4','0','between 100','1.65','almost 350','a hundred','627','several million','2 million','over 13','0','over 9.4 million','50bc','about3-4','89','cut.lol','more than 100','3 or so','4.5 billions','d.c','100 trillion','more than a billion','612','500 billion','58','46','about 10','more than 5','one-third','between 100 and $120','about 18','thirty','almost 2','0','715 million','67 million','only 10','about 13','0','at least 100','almost 40','fifty-eight','me!','7.3','just 75 million','600 billion','27.4','16.5','4000000','around 180','about 22 million','about 350','a high five','27500','over 750','over 500 million','a few million','901','45rpm','almost 2200','over 2400','two-one-two','1440','billion','02-mar','10x','at least 33','440 million','hundreds of thousands of years','2.7','32k','at least half','1200','only3-4','9am-12am','about three quarters','like 50','one over 18','112','211','youtube makeup half','about 14','430000','432500','more than one third','2d','roughly 20','two to three','12.5 million','9.7','over 86','0','2billion','90 00','about 55 million','55 million','28','2 to 3','9am-12pm','one second','more than 30','38','like almost 20','about 330k','a half a million years','only 3 million','only 6','only 75 million','44470','up to 4700','a half dozen','over 4/5','113','542 million years ago','about a hundred','less than 10.00','870000','over a hundred','91 million','165/245','more than 10','one billion','2017','20x','only 27.95','like half','2022','at least third','hundreds of millions','fifty fifty','about 2.2 billion','live some 400','400 million','three million','over 600 million','about 1/5','about 1000','67','127 million','205','over 126','201','338000','52 million','804','more than a thousand','three hundred','at least 52','almost 800','like over 750','about 50','about 1.5 million','525 million','1.2 million','a few dozens','52','only about 20','as many as 160','0','three 6','nine million','188','over 80','0','apr-00','tons','a quarter a million','at least 2','78rpm','between one','almost a third','more than 300','0','only 4.25','a half','sure~','49','4am','at least 335','at least 39','one to eight','1908','59 millions','around 75 million','more than 1','0','a half-dozen','only 150','so many zeros','about 100x','90k','07-oct','727','about 5x','ninety million','over 10','1o','2/3rds','between two','30-rock','nine nine','around 50 million','97 million','a dozen or','about 4','700','about 300','just 10','only about 1','as much as thousands','almost 110','pewdiepie','less than 200','80 million','41 million','only ten','about 1/6','about 130','745','433','one fifth','137 millions','about 400','6000','more than 750','little over 58 million','a quarter of a million years ago','about 59 million','almost 8 billion','58.46','only 1.5 million','about 1','200','94700000','over 540 million','989','up to 11','more than 90','0','less than 42','272','just half','about 188','263','325','95982000','972','1.3 billion','1.25','over 50 million','more than 3 million','2 and a half','up to 20','18 million','aired over 750','six million','6 millions','only 19','7percent','like 100','62','138','78-rpm','almost 180','more than 8 million','about 2','500','249','2bil','about one-third','9p-12a','almost 59 million','about one third','about 20x','only about 7percent','over 125','6331','100x','more than 800','0','120 million','only three number one','786','about 12 million','at least 19 and 1 year','59','26.8','the other millions','only eight','at least 1000','only over half','1.25 billion','162','over 350 million','09-dec','5 one','645','1 three','1 3','7s','300','000x','approximately 330000','304','about 1/2','over 542 million','crazy!did','nearly 40','only 40','12.6 million','only one second','bolero','over 50','0','15%points','over 700','number 2','about 250 million','660','134','about a dozen','roughly 50','more than 50','moon!n','over 3000','more than five billion','125 million','47000','563','only 400','25n','more than 57 million','about 365 and a quarter','10k','at least a dozen','about 800','almost 135','better than third','more than 256','only about 54','3 to 4','8 to 8','about 45','about 1500','about three quarter','635','32mil','50k','105pts','at least 3','2030','15 zeros','only 500','0','at least hilary','up to 2 million','more than seventy','listof three','four hundred','63','1.5 billion','75mil','more than 500','about 3k','china!!n','84','35 million','10 million','almost 2000','number two','half a dozen','32m.','29952','more than 15','only 34 or so','108','basketball/','as many as 1750','154 million','105-40','2live','an extra 500','0','more than a hundred years','330k','94','more than 67 million','more than 188','only 24','1 billions','almost 2500','650','1/1000','just 2','about 366.26','no more than 10','0','33bc','about twelve','64 000','700 thousand','only 3 number one','at least 1500','a tenth','633','128','0.84','almost 10','0.937','1.93','over 10 million','about 250','0','1billion','only about 300','0','54 million','over 90','0','over 4','0','50-60','a few hundred','one three','over 26 billion','thirds','at least 150','more than a dozen','really?i','5times','over 600','1.7 million','around 1.9 million','about 550','0','less than 20','almost 2300','as much as 180','about 70/30','150000','65 million','almost 50','144','over 2','400','mb','more than 40','about 130k','at least 1','all 30','only second','nearly 2000','more than 65','bigger than 100','1805','over 100','0','about 4-5 million','820000000','0.4','less than four','03-apr','199','travels millions','the millions','121','approximately a third','75 millions','almost two','hahaha','68','414 billion','about of third','less than youtube','more than 250','241','just 5min','4kids','about 54 million','only 5 million','48.5 million','4.27 million','2.7 million','1/3rd','150 million','23 million','over 7.6 billion','160 thousand','239','yummn','102','almost 115','6x','roughly 5','about 68','about 52','broadcasts thousand','18000','222','roughly 800','about three','88000','175 million','about 65','less than a fifth','over 60','430','4o','about 123000','between 2','less than 15$.','more than 30','0','50 billion','2260','more than 350','122','up to 3','over 300.00','over 188','as many as 188','about 356','about 1.65 billion','46','about 11','almost 4 million','like 2 million','2699.99','over thousand','almost 188','over 320','4g.','four thousand','over 200 million','more than 170','130','06-mar','8lbs','270','58 billion','3g.','66','21000','3/4mile','367900','64500','9.4 million','9 11','76','220','around half','between 9pm and 12am','about 150','more than','about 750','4v4','over 1/3','a few 18','fourteen','6.5 million','90s','approximately 160','0','about 234','aug-15','two or three','about 500 million','less than 1/10','250000','7 millions','around 600 billion','1 trillion','a couple hundred million','more than 300 million','between 10 and 20','over 33 million','a little over 400','around 2 billion','only like half','915','several 100','213','three hundred and twenty four','102.4','30 or so','didnt','about 3700 million','580','about 80 million','over 1.25 billion','about 75 million','38000','1001','well over 200','more than a million','just over half','a couple million','80000','older than 18','1728096','453770','at least a few hundred','20 25','an estimated 126','7700','up to a thousand','8.7 million','more than 3','cmon','33rpm','over 800','1975n','more than 300.00','only 14','42','between 7 and','almost 95 million','only 22','tht','about 58.46 million','411','about a quarter of a century','about 700','0','only 500 million','139','277','just 400-500','2.2 billions','all 3','2014?n','more than 125k','1but 2','8x','at least 50000','1','5 million','7000000','750000','only one 3','20-30','2k+','342','about one-tenth','4800','over about three','over 4','0','0','over 14','0','87 million','over 2.2 billion','only six','3.2 billion','at least two or more of one','as least third','3.9 million','4:30pm','1600','1853','350 million','11 thousand','only a fraction of the 324','123 000','about a 1minute','ten million','more than a few','4 or more','74 billion','thousands and thousands','62.8','at least a hundred billion dollars','just zero','751','over 324','all 750','about 730','only 33','almost 13','98000','around 100','over 4','700','nearly 40 million','3k','881','77','44479','over 3/4','3.5 million','50 to 50','3.5','5.25','two thousand','200000','one tenth','more than a hundred','only 7','more than 14','445','more than 18000','five or six','two-fold','over 75','more than 75','her a quarter of a century','about 10000000000','afone','at least 750','one thousand','a little over 650','516','less than 3','longer than 16','only 11','higher than 10','only 1billionth','2011n','4th','0.252777778','72035','72k.','18 thousand','between 3','up to seven','higher than 11','88','500 000','about 1853','30 million','%50 million','9pm to midnight','about 43','almost 350 thousand','only 57','30-40','about 1','100','just 4','sixteen','40pts','72 million','at least 19','15.2','over 7','700','his entire 300','0','40 under 40','only five and a half','as many as','about 63','313','414','210','up over half','at least 32','only 17','d3','11min','a few 100','0','1211','800 billion','800 million','more than 16','999','around 312','0','99.9','105.3','about 15-20','60000','almost 200k','at least 20','close to a million','50%+','some 49ers','14/25','66','at least 4','4kidstv','23.8','81.6','more than eleven or so','one half','three or four','about 40','a record 50','almost 2','about 59','50456002','0','999','897','just 1 or 2','that over a quarter','over 56','about 600','111 million','810','almost 5000','more than 4','800','4chan','only 29','about 8000','just thousands','at least youtube','24x7','427','1300','378','over 120 million','6 30','222 to zero','200+mb','over 80','about 300k','only fifty','346','almost at least half','60-10','only 356','about 500','4.66 million','250000000','980','0.55','about 2/3','as much as 65','only one-billionth','almost 6x','151','44 million','over 160','0','179','865','1475','close to 50','more than 80','half a billion','seventy-five million','500000','only 51','only 56','3 quarters','barely a quarter','eighteen thousand','almost a quarter','at least several hundred to a thousand'],
'DATE':['2015','a good day','1958','a week','1998','daily','every day','a nice day','a single week','this day','the years','10','000 years','today','under 15','2002','1912','under 15 years of age','every single day','this weekend','a lovely weekend','1977','this summer','a couple months ago','the last twenty years','an awesome day','only paying 70k','the day','2 years','saturday','1968','1993','165 years','1988','1913','100 years','1918','20th century fox','20th century','a day','days','the end of the 21st-century','a great day','1900','165 year old','first day','the last 100 years','twenty years from now','1789','election day','the old days','each week','under 16','the late 80s','2005','each year','24 years','1940','40664','a great weekend','a lovely day','1923','almost 100 years old','a century','1970s','maybe 1960s','last year','this year','2012','more than 100 years ago','halloween','the 1950s','my day','some days','christmas','sundays','only a few days','the past 45 to 55 million years','between 7 and 15 minutes a day','20+ years','two day','sunday','about it years ago','about 6 years','some last month','july 5 1994','more than 3 years','1934','next year','years','2016','these last 4 years','1990','1969','the year 2000','one day','each day','1957','1980','every year','1909','summer','opening day','1991','september of 2010','the end of the 21st century','4.5 million years old','these days','the first season','1963','49 years old','only a year','1895','the 4th century','the century','1975','1955','20 years old','1928','many light years','just one week','1930','2006','two and a half hours','2018','1938','40 years','20 century','more than a century','43','1948','6year olds','60 year old','winter','1997','the 1980s','years later','valentines day','1978','one week','4 years lol','3 days','41183','the age of 25','1972','two days','1983','seven years','the middle of the night','all three days','60s','70s','the 1970s','the end of the 1940s','the early 1900s','1920','20 years','1949','apr-18','1930','recent years','the early 1910s','later this year','1910','100 years ago','three months','1902','2 days','the year','5000 year old','1999','50 years','the next year','three days','2004','5000 years ago','19th century','three days or so','39083','jul-08','2002','friday','no vehicle day','240','000 years ago','10 years','only 15 years old','july','43 years old','226 years','only later','the age of 13','319 weeks','tennis years ago','age 13','two years','2001','about 2-3 months','only 2-3 months','2007','the 16th century','1986','the 70s','that days','all day','the year 2100','a few years ago','1950','1941','yavin 4','1800 years ago','over 20 years','about 25 years','seven year','only a couple more months','the last season','the fourth of july','last summer','a decade ago','april','1970','tomorrow','2003','45-68','all 7 seasons','2009','the early 2000s','december 13 1989','a day earlier','one yesterday','68 years old','a new dynasty','this past summer','1912 to 1952','these past few days','a lot of years','1952','1953','5 years','many years ago','a few months','the 26th','the age of 6','two 8','1989','the 19th century','7 year old','next month','the year 1991','any day','their day','thanksgiving','1984','per week','2 year old','a few years older 1984','1996','the year before','the late nineties','over twenty years','a bad year','1926','1904','some day','annual','a few days','1901','17yr','1992','the 1940s','the 1st','the 1900s','the late 1980s and 1990s','previous years','1887','about 10 years','the 1920s','a nice weekend','age 25','5 seasons','2013 to 2018','less than 82 years','the end of the century','feb-01-7','this cold day','the 21st century','age 88','20 years ago','the same these days','now','a year','shawarma','199999 years ago','1670','a merry christmas','the 15th century','another cool day','1838','the previous olympics','august','early days','day','one year','the holidays or winter months','a few years','so many years','the 9th century','this past weekend','year','the spring','12 year old','10 year old','5000 years old','80-90s','billions of years','his day','the end of this century','1971','annually','6939','1833','1939','the days of the 30s',' 40s','2008','455 light years','my school days','thirties','fifties','last centuries','2 to 3 months','about 315','000 years ago','10 000 years','17 year old','108 years','the same year','1945','87 years of age','1903','1994','1981','an eight year','28 years old','his mid to late 30s','the first 5 seasons','the end of may.','19 year old','the low 90s','the past month','the summer','the past five days','only a week','24 years in a row','the phillies years ago','early in the season','60 years old','2 years ago','many many years ago','the late 80s','early 90s','a mlb season','9013','100 years old','next jan','about 24 years','the season','the day one','almost 120 years','37987','the days','the fall season','the baseball season','26','1876','since 1903','thursday','that day','108 year','a hundred years ago','30s','the final season','7 seasons','apr-17','2011','a few days ago','about six years','1000 years or so','more than 19 years','nearly 3 decades','forty','a good weekend','3 years','about 15 years ago','his younger years','10 month old','weekend','the past few years','1973','this season','next season','a better season','the last few seasons','one next year','this time of year','1974','a few years back','season','those years later','a couple of years','the first year','the year 1926','4 days','last season','38838','33451','a couple years ago','2 years in a row','more than 3 weeks','a given year','about 1903','the year 1903','70 years','the mid-18th century','only 2 weeks','years ago','millions now a days','the year 1700','1995','roughly 1700','l played years ago','two or three years','the coming years','30 years ago','early 2005','sep-24','2018','over a hundred years','98','a long time ago','about 240 thousand years ago','2-3 months','the year 2022','5 years ago','a few','aways','six years','15 years old','the other day','the past couple of years','this last season','over 70 years','yearly','the 8th season','1 season','seven seasons','eight seasons','the eight season','the end of the 21st','a couple of years later','40422','at least 3 weeks','only 25 years old','the next decade','61 years old','the early season','a great year','almost a hundred years','6 years','20k','13745','the new season','the next season','4 years','that year','1940-19808','4-5 years ago','many years','week','the age of 15','those years','the past 20 years','18 years old','18 years','the last couple of years','weeks','this coming season','age 16','each summer','2026','the middle of winter','scary','170 million years ago','39295','the weekend','the 14th','a few hundred years','only 5 and half hours','07-nov','those days','21st century','37865','older than 12 years','42736','last october','2007 to 2017','friday the 13th','only 3 days','a couple of days','10 year olds','several years ago','70s and 80s','the 60s','those decades','that era','1880','a wonderful day','next feb.','olden days','last week','these years','500','000 years','the late 19th','early 20th century','about a century old','almost a hundred years ago','almost 2000 years','2023','a turbulent year','53','150 years ago','1916','over 100 years','the 1770s','1854','the year 200','13 years','that years ago','8 years','37 years','dec-22','2012','over 1800 years ago','at least 10 years','the next 100 years','the 10th of march','the 25th century','1 day','5.5 days','a week lol','the winter','43374','every other week','me years','the last 30 years','14 years','the last summer','the summer 2022','february','november','about 3 days','2019','my school years','almost every day','the movies years ago','the late 70s/','the past three decades','me weeks','the mid-1950s','1960s','the 80s','the mid-1960s','early 20 century','the 40s','80s','almost 1 per day','17 year','the late 1960s','the sixties','this the other day','97','next weekend','every sunday','about 28 years','a 20 year','only one year','the past hundred years','decades ago','the late sixties','1965','weekly','her late 90s','this past year','the last 120 years','77','1987','aug. 16th 2013','prime every year','around over 20 years','the last 2 years','61','nearly 20 years','the 30s','the 1700s','300 years ago','nearly ten years','so long ago','that summer','the dodo years ago','almost 20 years','over 5 years','last month','the 90s','the year 1972','20 straight years','01','durstthat','the mid 1800s','60-70 years old','155 years','years past','only eight years','this decade','6 year','the late 19th century','the 1930s','every week','june','three decades','1924','so many years ago','the beginning a day','millions of years ago','a weekend','next week','500 year old','the early 18th century','three-month','5','000 year old','the 18th century','2005-2006','33 years old','the past 37 years','nov-11','2011','four days','between 1860 and 1932','310 weeks','modern-day','1828','a couple of months','only a couple days earlier','12 century','five years ago','august 16th of 2013','the past 18-19 years','15 years of age','several years later','29 years old','200000 years ago','240000 years ago','40 to 55 million years ago','now days','around 50','000 years ago','just 2-3 months','just 2 to 3 months','the last 240','000 years ago','many years later','decades','165 year','the last 37 years','165 years old','monthly','about a year and a half ago','16 years ago','2year','fat tuesday','45-55 million years','school day','later this month','a few months older','the age of 3','20 to 25 years','20-25 years','the 20s','a couple weeks ago','about 6 months','over 6 months','the year 2013','our 365 days','the next two or three years','yesterday','2 or 3 days','a few decades','episode 1','the other week','a strange year','1960','a long day','the next 10 years or so','the kim dynasty','1980','between 1 and 5 years old','every 15 days','this week','the turn of the century','a period of months','one one day','another few years','working days','twenty years','the last 3 years','a few months ago','a million years','165 year-old','the 70s and 80s','50s and 60s','about a year ago','the week','the last few decades','over 900 weeks','two 100 year old','last years','this century','50s and','40 years ago','about 4 years','500 000 years','1943','the year of 2019','500000 years','1846','the off-season','10 days','5','000 years ago','thirty years','99 a month','the 2 day','the 50s','the 17th century','the past century','around over 100 years','1889','50 years from now','modern day','those first three seasons','prior to 1963','1966','the 60 and 70s','the soundtrack weeks','age 14','the 2000s','05','at least 13 years old','13 years old','13 year olds','october','1947','1904-1991','22 months','episode 2','the past 119 years','march','1932','every 200k-300k years','their inaugural season','their first season last year','a swell day','first two weeks','day 1991','age 3','jan-08','1983','1 year old','less than a week old','2 years old','the next few years','43252','age three','over a decade','age 3 or','that 20th century','83','1st 8','age 55','an exhibition years back','winter year^round','foolishly','monday','the middle of the week','those 3 years','the age of 20','about 15 years','only 52 years old','1616','the end of the day','se7en','1985','one season','nintendo 64','just yesterday','the new year','the last month','november last year','2 weeks','1920s','the next ten years','this past week','four years','each decade','43 years','226 year old','14 days','like 3 days','feb.','2025','fourteen days','age 85','85 years old','1830s','like years from now','the late 70s','the second season','100 year','over 10 000 years','914 weeks','the late 30s early 40s','more than 20 years','their first day','the first 3 months of 2016','that same year','now a days','one several years ago','a few weeks ago','1 per month','300 or so years ago','the winter months','early 80s','every few days','the snow queen','the holiday season','37226','some odd years','3 decades','the last few days','the mid 90s or so','more than 40 years','the late 1980s','the year 2003','the day after halloween','labor day','16 year old','almost a decade','half a day','november of 2006','each month','early 1900','those same years','40 year old','18th century','age 15','a little many years ago','42036','the early 80s','twenty-five years','the blockbuster days','a 10 000 years','the holidays','22859','jun-06','1946','the middle ages','a week later','14k','25 years','the end of the twenty first century','first year','the next day','over 10 years','39022','1800s','40 years old','2 weeks ago','my 4 year old','this coming year','wwii','over 914 weeks','the election season','1944','about the year 2000','40 plus years','a few months or even years','the beginning the day','a 20 year span','another couple hundred thousand years','thought years ago','over 37 years','38384','the past hundred years','every couple of months','18 year old','43101','about ten years ago','around 315','000 years ago','3-4 months','a baseball season','9th century','9th-century','jul-05','1994','4 year old','the 80s','only seven years old','a year later','70 years old','the olden days','only one season','seventeen-year-old','7 months','two weeks','the age of 32','as long ago as 2003','just days earlier','2002-2016','7 days','just a few days','the following year','the early 1990s','61 year old','just 58 years of age','all those years','a few days age','months','the 21 century','two decades','45s','the 1960s','a good years','the early 70s','40 years later','a dream day','a period of 20 years','long ago','1933','twentieth century fox','the current century','2-3 days','three quarters','last weekend','this very day','winter olympic season','light years','the beginning an earth day','every summer','over hundred years ago','1874','later this week','only 95th','two months','my best days','a couple days','2 months','these past years','a half million years','july 11 2011','another billion years','the year 2012','like 90 years old','almost two days','the past 40 years','valentines day','valentines day','about 20 years ago','two or three days','25 years old','10 or 15 years ago','8 to years ago','200','000 thousand years','50','000 years ago','todays day','180 years','oct. 2018','like 20 years','81 year old','years and years','three years','aug-16','2013','16954','his 30s','1961','summer 2019','the decades','nearly a century','a couple hundred years ago','september','equus','a quarter million years ago','just 15 years old','february of 2005','almost a year','age 25 in 2012','the late 90s','next thanksgiving','feb. 2005','the last year or','the year 2001','every couple years','only 20 years old','november of this year','almost a hundred years old','between 2016-2020','20 years in a row','the winter of 77','a year long tour','the year 1993','game 1','the 1800s','45-55 million years ago','a 6 year','10 years old','17 years old','over decades','50 million years ago','four year old','about 300 years ago','last a week','10 long years','7 and 5 year old','every two months','7 month old','only about 3 months','another 3-4 months','hundreds of years ago','a fast day','the work day','olympics','1929','year lol','a couple of days ago','2 months ago','the third season','a 4 year old','summer olympics','a decade','just weeks','their years','these recent years','the first winter olympics','0.000755903','the 3rd season','12 years old','oscars 3','nintendo years ago','a wild day','a little 4 year old','its third season','season three','the modern day','just the past ten years','every month','three years ago','a couple years','march 20th','around yesterday','half a million years','the shortest day of the year','34 year','200 years ago','2.85 million years','43 year old','more than a week','just one year','five-year-old','the year 1918','more than 75 years','their early years','the first 3','17 over 37 years','four decades','a couple of weeks','the year 1958','only one week lol','1869','88 year old','one breeding season','1912-1952','a span of 20 years','about the year 1853','six years ago','like 1996','the early 90s','100 year old','his century','the18th century','the 20 century','that 40 years','age 52','aug. 22','later that year','the mid-20th century','over 40 years ago','only 1998','a few years later','april 16th 1178','yes',' years ago','my younger years','wednesday','september of 2003','they day','about novels long ago','over 2 years','a sad day','about twenty years','some 50 years later','the 4 year old','since 1939','3 years ago','may','226 years old','2006-2007','just 7 short years','2nd','at least 50','000 years','about 240','000 years ago','about 300','000 years ago','only 240 000 years ago','every 300k years','only 2000 years old','only 240','000 years ago','80 years','our days','present day','just 5 years','the past years','the age of 55','the summer of 2018','comeday','the early days','the winter of 1977','the off season','nov. 11','2011','fish year','age 226','the 20th century','2024','only 14 years old','30 day','the 21st centurys','a year ago','1000s','like one week','portrays 11s','late 50s','15-20 years','a great season','one quarter','roughly 30 years ago','so big years ago','just a month','90 day','15 years','any day of the week','the age of 100 years old','around the year 1700','about 2014','the early 2000','like 2004','about the year 1700','27 years','20-day','only fast last year','next day','a piano day','the previous year','the early 20th century','two 100 year','the 1940s',' 1950s','like 340 days one year','about 5 years ago','25th century','half a century ago','oct. 6','2017','43070','42948','1844','may-11','1991','the 10 day festival','the early 1950s','315','000 years ago','a thousand years from now','the year 1986','around over 10 years','around 240','000 years ago','13 year old','400','000 years ago','about 315000 years ago','about 50','000 years ago','older than 4 million years','90000 years old','300','000 years ago','the 4.5 billion years','about 200','000 years ago','2 or 3 months','the bible days','earth day','a couple thousand years','200 years ok','thousands of decades','250','000 years','about a month','centuries','240','000 years back','month','aug. 16th','2003','the late 90s early 2000s','feb. of 2005','6 month','about 20 years','the 100 year old','a month','more than 60 years','like 10 years','ten years','like 13 years','the early 90s','about 7 years ago','the other month','two years later','the first three years','1946','around 1940','almost 13 years old','every years','august of 1962','1982','1886','10 to the 23rd','two years ago','one day off a week','42767','every 4 years','every four years','between 1950 and 1956','about 2012','the past two years','9pm to 12 am','the first week','21 days','the middle of the pacific ocean','all this year','10 ppl','this month','the last two seasons','12 years','some hundred years','five years','2007-8','the 2015 season','the late 1980s','the year 2023','age age 8','december','january','almost every year','age summer','the entire 21st century','914weeks','week-end','april 18 1930','1967','age 76','100 years of age','age 100','1937','the last year','80 years ago','2100','1','000 years','a crazy year','199999','18th','between 2016 and 2020','the three month','1964','50s or 40s','the late 19th and early 20th centuries','20 years of sundays','the 2014 season','55 years old','these past few years','a couple more seasons','the last two years','2014-15 season','his mvp year of 2015','just 2 years','the last 20 years','last years','3 in a row','only four years','a highlight year','76ers','the early and mid 90s','30 years','the last few years','great years','the 2019 season','the year 2015','about this season','the year 1988','2014-15','five year','1962','a few year ago','2014-2015','the past two seasons','xmas day btw','another day',' christmas','the 2015 season mvp','about a hundred years old','the arena before years ago','1.5 years','the year 1979','their pro years','1979-80','the first 5 years','the first five years','2017 and 2018','the year 1975','the one year','the most recent season','the beginning of the next season','a casual day','as early as 1910','3 month','9 month','9 month old','last 4 year','same day/next day','60s','a every day','91 year old','feb-04','2004','twenty years ago','february of last year','1882','the early 1890s','at least six season','the early 1890s','only 7 years later','the next two','7 years','just seven years later','6502','terminator 2 seven years later','sandler day','now than 40 years ago','more than 40 years later','3-28-86','19 years old','an amazing day','this holiday week','like 40 years','the mid-90s','the last years','the end of his century','a mid winters day','an active day','90 days','almost daily','school dayno vehicles day','october of 2008','billions of years ago','the earth days','june/july','4 years ago','1000x','five yars ago','training day','season 1 and 2','the more recent seasons','1930s','10 00 years','500 years ago','the film','the film years ago','the earth most days','the next few winters','the last 20','the next 5 years','the past year','a hundred year','243 million years ago','1871','the early to mid 90s','my early 90s','the past couple years','500','00 years','winter solstice','dec. 21','36892','december 20th','the 21st','july of 2012','the age of 12 or 13','july 11th','2011','the best month','the 14th of december','december 21st','the long day','34516','10000 years','a span of 3 days','a typical year','the past several years','just one season','07-jan','16th century','a single year','five different decades','the centuries','several years','about 5 years','the 6th century','58','a few days before','all these years','days later','about 3 months','20 years later','88 years old','nearly 25 years','january 26th','more than 50','000 years','columbus day','the nights','1','000 years42979','200 years old','the warmer months','54 years old','12 days','every 13 year old','5 months old','ever day','the first two seasons','age 44','15 year old','42826','around more than 100 years','more than 10 years','only 5 years old','his first season','less than a year later','the 80s and 90s','one some day','his years','earlier days','each christmas','1956','the year 1969','my college years','50 this year','1564','this years awards','5000 years','every 4-6 months','only 2 - 3 months','the 5000 year olds','youtuber','may of this year','the end of the season','eight years','since 1994','jan. of 2015','40452','waters days','about 40 years old','almost 20 years ago','two years earlier','those years before','another decade','seven decades','over 420 million years','50 years old','thousands of years','around 2001','about a year','5 or 10 years','a very bad day','its day','16th august 2013','about 500','000 years','two ago','jul-11','2011','a mere 5 billion years','july 11th 2011','40 years earlier','the late 60s','coming 2nd','three year','11/nasa','40940','three year olds','10x per day','our century','five year old','80s','almost every day in 2001','my olden days','56 years old','35 years','87','91','two year','another 50 years','almost 3 days','pi day','mid 90s','outnumber','every 2 years','20 episode season','fifteen-year-old','last today','every few years','all year','15 years ago','same day','5 year old','the age of 100n','100 years later','a valentines day','10 years ago','the late 15th century','the 7th century','about a five year old','about the days','37 years old','their century','the 100 years of age','one 9 years ago','a few more years','the first 2 seasons','9-12am','jun-29','2007','the summer months','22 years','the age of 18','early 2000s','the mid 1900s','the trumpet years ago','almost 18 years or so','early 90s','wild years ago','around 2012','teh 1960s','8 or 9 years','thees days','100+ years','two seasons','a modern day','more than 365 days','only a quarter days','a leap year','a quarter day and an hour','more years','the 1940a','the earlier days','the age of 100','seven-year-old','the summer olympics','shark week','a 1 year old','basketball season','a couple of decades ago','just a few decades ago','10k years','anice day','70 day','70 days','365.25 days','like 5 days','mid-october','his 8 years','1995-2000','mid-1990','this christmas','last sunday','my years','the 1990s','the past 30 years','07','a great decade','the age of 16','like 6 years','5 & 7 year olds','summer',' winter','the late 19th/early 20th centuries','85 year old','121 weeks','just two years ago','1950s','the year 1936','happened years ago','10 year','my 5 year old','10 month','a fabulous day','the year 1984','less than a year','christmas day','the younger years','5 years later','around a year later','winters','1976','a couple of years ago','76','the year 1886','the birth year','400 years','the last century','june 8 1977','last 10','000 years','the last season of the punisher','season 3','3 season','fourth season','a single day','the school day','16 years old','21st century fox','the last 2 weeks','seven years ago','i week','four days later','just a day','13 year ago','a long work day','542 million years','one these days','the last 45-55 million years','1958?i','1 week','two later','mash years ago','new year','10 months','the 21st-century','the first few weeks','age 10','5 years old','more next season','24 years old','the past three seasons','months ago','a few weeks','just a few weeks','8675','almost a hundred years later','only 3 years from now','33s','5 year olds','my days','under 20','0','april date','that season','the year 1564','blackwater','71 year','71 years','about 1960','a 17 year','150 years old','about jan.','70 days one','more years ago','1000 weeks','only days','1947','1956','about 15 years old','like 2 reponses ago','tuesday','game 4','jan-26','1982','1929 to','18.he','a couple of seasons','turns 35','the end year','2014','the late 50s','like 1958','a 18/19 year old','the last 10 years','the end of this year','age 18','the normal season','the next couple of seasons','14 week','14 weeks','a couple good years','the late nineteenth century','only 18 year olds','under 18','the late 19th and 20th centuries','16 week','half the day','everywhere now a days','this era','three thousand years ago','about my day','spring','season 14','first season','about 30 days','just the year 2018','her years','tthe last few years','the earth 365 days','15 months','thirteen days','june 17th','over 10','000 years','10 of those years','like 17 years','21 years','about the first season','season 2','season 4','couple of hundred thousand years','only two or three months','315','000 ago','previous centuries','1950-1956','1872','1908 summer','the last decade or so','just a week','315','000 years','300','000 years from now','some years ago','centuries - gmo','the kickoff month','every 3 months','last 5000 years','two centuries ago','the mid 18th century','14 and 10 year olds','a few more seasons','the first half','only around 50','000 years ago','more than 100 years','all four years','a hundred years','only 2 and a half hours','the early 2000s','exact year','june 6th 1946','an amazing year','76er','aug-16',' 2003 google','late 19th century','his later years','34 year old','dec-30','1984','this youtuber','6 days','just a season','first month','100 days','the first full year','since 1996','3 months','a strong year','the next several years','10 years later','up to 240','000 years ago','six year','2 100 year old','nearly three decades','about a year later or so on 2004','the cast of the 2nd','about his perfect day','my perfect day','14-15 years','saturdays','sept. of 2018','13 years ago','perfect day','the 1997 season of 3rd','almost 13 years ago','30 years old','per year','ten years old','jun-15','2018','more than 13 years','about 10 years old','that years','opening weekend','a perfect day','the perfect day','that decade','more than a decade','two thousand years ago','the end of his 2nd','his days','lucky year','16 years','last day','that long ago','125 years old','friday nights','feb. 2nd','these current days','their dream day','every 2 weeks','a dc dream day','a special day','7 or 8','sept. of 2003','the next 2','decade','about two weeks','14 years','the holiday','the year 2005','the exact year','acting days','dream day','4 per year','the year 1962','at least the present days','3 per year','at least a day','a regular day','2004-2008','2003-2009','around the year 2000','about 400 years','age 5','only 30 years old','45505','this fall','40 years as of 2014','several a year','many per year','the 25th century bce','every day of the year back','this winter','just every 4 years','eighteen','the year 1994','each month as of january of 2018','a few months back','so many 100 year olds','a rebuilding year','last year or the year before','300+ years','20 year','over a year','almost 500 years ago','only three years','the 2nd to last one','around 30 years ago','next summer','between the ages of 16-26','first 18 or so years','late 90s','like 1997','365.26 days','an earth year','its early days','age 17','from day one','several pairs a week','the past couple of months','two months later','the next 10 years','about last season','the current season','mvp 4 years in a row','the last few weeks','all 4 years','number 12','about ten years','a years','the first few years','one years','about a long year','2011 neptune','5 billion years','the late 90s','the month','around now a days','the next couple of months','2000s','10-15 years','the early 20th','about 25 years or so','2088','a couple times years ago','the 12th season or so','the 12th season','this basketball season','150 years','3 day','centuries ago','2 to 3 days','the 80 year old','every 26 months','millions of years','340 day','the first billion years','36982','340 days','around 50k years ago','the gym 7 days','a couple decades later','the past and','almost 1000 years','till years later','early today','these years later','apolo 11','84 years old','1 single year','a fantastic day','all summer','next century','3 years old','august of 2013','42217','at least 75 years','an average mlb season','4 year','a good year this year','october last year','christmas eve','now-a days','around 300 years ago','forever ago','almost 100 years ago','one days','between 1912 and 1952','19583','the first six months','their senior years','40','000 years old','the calendar year','the age of 85','iphone 8','nevada days','only 365 days in a year','170 million years','the late 19th and early 20th century','now over 100 years','the last couple of days','the eighth season','the post season','several months','iceland?n','the 90s','70s',' 80s','1st','up to 226 years','my younger days','45 years ago','youtube many years ago','every weekend','age 82','the age of 82','like 8 years in a row','that 70s','less the a month','broadways','their strongest year','the 19 year old','about a 19 year','just over a century ago','a month or so','six year old','the twentieth century','recent months','500k years','the 1940','three day','a wonderful week','leap year','about 240k years ago','three generations ago','up to 43 years','an off year','89','a little bit ago','later years','the first 19.5 years','the 15 year old','000 years ago','1990s','10 & 11','elementary','the fall','just 2 months','aug. 2013','the 13 years youtube','14 years ago','the last weekend','almost 100 years','a 18th century','any year','the next 10','000 years','like 10','000 years','late march','a few days later','the weekend ahead','10 day','the coming days','these next few months','a hot day','the 10th','about 25 years ago','almost 25 years','a fun day','more than a couple years','25 years ago','july 5th','the 4th of july','almost 25 years ago','july 5th','1994','3-4 weeks','fourth of july','more than 70 years','about 10000 years','time - days','half/half','10','000 years from now','some years','07-05-1994','almost 30 years','more now a days','18th-century','nearly every year','22 year old','36 year old','at least 19 years old','aday','light-years','around almost 25 years','about 6 decades ago','the fourth century','about 40 years','5-10 years from now','about 2010','the earliest days','320+ days','2 100 year olds','nightly','a 3 day work week','their day to day','the hot humid days','a extra day','the beginning of next week','everything theses days','just one day','just a year','just one year -2001','almost everyday','my earlier years','better days','about april','42095','1 year','7 years ago','just a few years','a lifetime ago','december of 1994','the first 24','jan-04','2013','almost 1800','last breaths','the 11 year old','14 day','nexy year','every other year','the first day','about 100 years or so','most days','6 years old','april 1st','2015','3 seasons','earlier this summer','the first few seasons','between 1950-1956','4 years older','just years later','may/june','44 years','christmas one year','the age of twenty-four hour','a standard earth year','455 years','previous seasons','12 or 13 year old','their early twenties','about 13 years','march of last year','about?n','several weeks','1973 2','august of 1991','a few season back','a 3 year','another 15 years or so','5 years from now','40x','the early 1900s','mid-june','only 20 years','jun-14-20','42156','the 17th of june','the last 15-20 years','a busy year','these day','three month','last 4 years','my age of 8','my age of 10','the next billion years or so','about a week ago','2015 season','forty years later','two 100 year olds','the middle of the day','just over 20 years','9 years','around 24 years','a 5 year old','40 plus years old','white days','16 year','between the years 2016 and 2020','three years old','their weekend','the coming months','up to 20 years','the last 20 or 30 years','early next year','the mid 2000s','80 year old','a typical season','a single season','august 16th','an actual year last 365.26days','those leap years','the early 80s','feb-28','2016','day weekend','this years','then years later','the older season','some weeks','a 1 year','11 more months','our day to day','the first two years','only seven months','80s & 90s','more than 40 years ago','the post war years','only 18 years old','around 14 years','13 years or older','the past 200 years','the further years','all of my years','sept.','a model year','last longer than five years','at least 5 years','roughly six years','45 to 55 million years','weird days','late 2003','the year 1955','april of 1564','april 1616','the 1590s','current day','the early 1920s','00s','the classic days','the year 2014','the year 1992','100 year olds','this past spring','fifteen years ago','only 13 years old','1979','much later','around 12 years','84','the first 3 seasons','8 seasons','season 8','40+ year-old','this april','15432','about six months','1891','an interesting season','sundays now','around 2010','six years olds','season 1','last 10000 years','the rest of the century','the early day','every couple of years','nearly 10 years','only 240k years ago','1-2000 years ago','75million early','the year 1977','late 60s','the next one','the last few centuries','50 a year','three this year','ones day','2010 to 2014','the 4 years','weekday','the best years','long time ago','the ability long ago','75 year old','130 years old','7 and a half years ago','another year','gets?n','the first eight seasons','one years ago','a whole day','a new season','the later 90s','thursdays','a number of years','a century and a half','a weeks','many centuries ago','the last 4.5 billion years','more than a few weeks','the weekend','long gone days','only 3 years','the other years','a single year back','more than 15 years','a great day friend','the dog days of summer','mid august','99','999 years','1 neptunian year','only 1/billionth','about the early days','1935','1907','the later years','18 year olds','almost 1920','almost two centuries','feb. 4','2004','25 year old','more than 14 years','some 18 year olds','just 300 years ago','earlier this year','41579','december of 94','42552','40360','2- 3 months','the last thousands of years','only 2 to 3 months','40 these days','300','000 years','3 days long','23rd grand slam','about two years back','the year 2010','the end of the ninth','little every year','12 years ago','earth days','early 00s','only 7 years','30 year old','87','old days','over 40 years','the turn of the 19th century','a class year','aug. of 2013','last century','1005','the 2nd season','the end of season 1','a firefighter movie years ago','the older days','16 to 18 years','8 months','a few weeks old','season one','a day in 1930','the past 16 years or so','teh year','5','000 years old','a century ago','1908 to 1975','the christmas holiday','all about 240','000 years ago','the a day','the end of 21st century','a couple of years or decades','about 20 years back','the last 50','000 years or so','another 50','000 years','one year and a half ago','those a week','one long year','less than 20 years','april 2nd','eighteenth-century','ancient days','about 10 years ago','a short work day','the good ole days','the year 1908','a good 10 years','i guess days','another 4 years','221 years','later the next day','1732','a pleasant day','earlier','my college days','the 2nd','the age of 70','oct. 3','1947','the holiday weekend','low 70s','hundreds of years','the last 16 years','more than 11 years','just two years','nearly 30 years','20',' yep','the 26 year old','of years ago','50bc ceaser','around 50 years','roughly 10 years','apr-18','1930','almost 320 years old','about 3 years ago','maxim years ago','6 seasons','the good ol days','10 more years','the later seasons','around 2002','several billion years ago','under 35','like 20 straight years','just over a decade','just a few years ago','the early 1800s','every day huh','mid 90s','this early in the day','the 2010s','the upcoming year','a number of years back','four-year-old','the past 100 years','about 32 years old','an earth day','the 19th time today','mid of 1850','as long ago','a good day ok','thirteen year olds','the next two to three months','about 50 million years ago','thirty years ago','203 months','the 1500s','86 years old','some rest days','between 1998 and 2018','5 year','8 year','an 18 year old','any other month','the past 19','the last ten years','90th anniversary','mar-04','2018','the first 8 seasons','morrow','sports years','over hundred years','3 decades ago','four years old','the beginning of the season','the season this year','the first decade of the 2000s','my high school years','a year or so','2027','78s','the late 90s early 00s','turns 55 years old','almost 7 years','another three and half weeks','3 a year','6-8 seasons','a full year','only every 155 years or so','every century and a half','a long winter','55 years of age','aug-03','1949','the early 19th century','7-31-80','about 30 years ago','november of 2011','8 years ago','like 1990','three-day','about 2 years ago','over a century','the late 70s','the year 2002','more than ten years','one per year','1959','22 or 23 year old','age 36','the latter half','the 11th century','three weeks','beer day','six months','those old days','like 5 full seasons','every few thousand years','less than 200','000 years','around 50000 years ago','several thousand years ago','a few thousand years','20-30s','more than 50000 years','2 to three months','26 years','only two years','te years','a super day','the 800k a year','16 straight years','like 2001','the recent season','d-day','the middle century','a half a day','the early to mid 90','ten-year','around these days','12 months','those early days','the early years','over 150 years','just a year ago','the 10','000 years','2112','later in 1948','100 years from now','about a years','billions of years old','his 4 year','around 2000','now years later','their young 20s','20 years in 2017','two year old','the last 40 years or so','over 5 years ago','7 year olds','about a month ago','about five years','average 5 years','86','less than 20 years old','1 year olds','36','09','christmas this year','13 year','1822','20 and 30 year old','19960','about his final years','the year 1963','labour day','at least 20 years','365 days','20 year old','late 70s','the year 1896','august 3rd 1949','four years later','five months','the end of their season','the cba season','the year 1989','the late 1960s','a hot few days','the last dodos','21 year old','over 30 years','no more than two days','the next days','a days','feb. 2012','around 15 years','seventy days','57 years old','the 27th season','the mid-19th century','75','the car years later','the 1970','dec. of 2018','1993-2016','a second ago','quirk','his second year','his first year','almost 60 years','about that years','about 8-10 years','those many years','about 20','000 years ago','40','000 year old','2009-2017','2005-2008','800k per year','about a decade','the 2018-2019 season','more than a year','obama','all day long','earlier or later','2017-2018','17 years','about 1 year','the 21 first century','the first decade of the 2000s','91 years old','the vinyl days','mcdonalds','what year','a couple of years back','the age of 95','only a few months','50bc caesar','about three months','as recently as','4 seasons','post-40 year old','the lean years','the past 240 000 years','like 2-3 months','almost 300k years ago','63','a two year','four year','the age 20','only a year old','just 7 years','14 and 11 year old','their teenage years','a year earlier','the past 8 years','42005','only a year later','the grizzlies years ago','per month','35 years old','some games years ago','about this year','nike later','50 year old','14 nba season','4 year degree','a week ago','the end of every year','a national holiday','38169','early july','these last few years','the 17th championship','a given day','jam 2','about two years','200 years','five season','mid-30s','his college days','14 year old','120/ apiece','only 34 years old','june 6 1946','just a year later','the same day','45839','the first season of true detective','next feb','june 22nd','two 19 year olds','blabber','28 day later and 28 weeks later','the 93%ers','june last year','fifteen years','more than 10 thousand years','16 consecutive years','last past 10','around 1960','500 years','the last 3 months','this friday','over 5 billion years','last 500000 years','24 7','almost every weekend','over 16 years','around 2005','about 200 thousand years ago','the beginning of the 20th century','2005 to','an 8 year old','8-12 year olds','about 8 weeks','a billion years','4.5 b years','the full four years','2018-2019','the spring of 2019','6 months','1911','the age of 41','only 19 years old','about 9000 years ago','about pre 20th century','a season','summer weekends','five year anniversary','less than 10 years','year mcdonalds','82 year old','6 year old','months - or years - to','1000 years ago','500 k years','about the 3rd season','two weeks ago','the past 50 years','the 20th season in 2009','six years in the 1990s','240','000 years','around 30 years','the early era','the next few months','the football season','my later years','last november','111 years','the 24we','the next century','the next few weeks','late 2019','like 1915','1919','this time next year','201 years','more than 2000 years old','past decades','dic 13th','the fans year','a free month','them days','the 18 century','like months ago','every 8 years','june 27th','the playoff season','a rewarding day','about 18th century','only around 120 years old','the 51 year old','the same month','67 year old','01-oct','late 80s','about 1989','the age of 100 years in 1992','the early 1920s','a couple of 100 year','the year 2011','more than 914 weeks','forty year old','the late 1970s','the 20th and 21st centuries','one every day','their kids day','four-year','the quarter','several 21st century','more than 16 years','every couple weeks','mid-1985','the late 1800s','9 years old','the fifth season','that week','a 17 year span','almost two decades','january 8 1983','the many years','only 19 years ago','the last 160 years','almost two hundred years','a year or two','about a 2 year old','all day long everyday','111 years old','the 10 years','this over','forty years','all the other years','more than a 100 years','last...','august of 1949','the 20th season','almost 10 years','another 100 years','the previous years','west days','the whole year','the year last night','four more years','about 30 years','the mid 90s','one in years','nike years later','the 30+ seasons','four entire days','july 11th','2001','only about 65 years','at least the 21st century','at least the first two','the age of 19','october of last year','a full season in one day','9 months old','a year old','some years back','the first sunday','sunday every year','their first season','17 weeks','the regular season','the age of 40','his last season','three or four years','3000 years ago','the beginning of 2018','13 & older','1880','around 30','43 days','just 15 years ago','every 15-20 years','nov. 2','about two months','ten years ago','jun-08','1977','50 years ago','the people 1st','the mid 70s','almost 15 years','youtube 1 year','1 month','season 12','this past season','an 11th season','11 seasons','15 seasons','2nd year','last us half a million years','present-day','day of the week','the second week','every hundred years','a couple of decades','years-long','an era','about seven years','about the 1960s','16plus years','about 21 years ago','weekdays','the last couple years','88 one','50 each year','high school years ago','you day','about that 70s','his era','only 16 years','2 days later','his 10 years','a losing season','the big 10 last year','annually every year','season 2 or 3','26 years ago','two whole days','the age of earth','the past five years','a minimum 3 years','aug-23','20 days later','the 1932 summer olympics','80s','68','about the year 1993','1804','the late middle ages','over 165 years','65 years','the last 50 years','about a year back','tuesdays','1778','173 years','5','000 year-old','the age of 68','last phd','like 30 years','quite a year','a beautiful day','the 2nd century','38018','a given month','anyday','christmas trees','the early 60s','some years later','that many years','about this years later','almost 16 years ago','about 100 years ago','age 60','40 year','1 year later','the year 1998','the full 4 years','1839','0.07','nowaday','a little 85 year old','12k','an episode 5 days','45323','barely last a year','365.24 days','summer 2018','the year of 2003','27607','twenty first century','about 76 years old','2021-22 season','some good years','several decades','114 years old','the early earth the day','4.5 billion years ago','114 year old','busy year','122 years old','the weeks','60 years ago','before 18th century','holocaust','the early 1910s','the late 1940s','november 11th of 2001','three days weekends','this tuesday','toured years ago','the end of season one','about three years','april 18th 1930','about 19 years ago','3 year old','about 2005','the year 1805','50 per year','19630','years and years ago','the earlier years','40848','20+ years ago','several decades ago','1812','about 17 years','over 200 years','the first sunday in february','the 2007 season','four years ago','49 years','the next 3 years','next years','every single week','the 2nd 1/2','almost 90 years old','last weeks','a bad day','past years','at least late march','half the year','almost 50 years','83','one year or so','only last one season','april 28th','88','1789 to 1913','2067','5.5-hour days','24-hr days','seasons 31 and 32','the 1000s','the 80s late 90s','only 40 years ago','her last year','the middle of the 20th season','5 days / wk','16 years2 100 year','99','03','2000 years ago','the 4th quarter','age two','the end of the 3 weeks','the last day','8 days','nov 11 2011','last july','nov','2011','up to 4 days','another 2-6 years','the middle 1950s','the late 80sa few some years ago','my work day','a sunny day','half and half','the last 100 years sadly','17th century','another day','around 1987','under 30','days','pre-1965','170 years','the age of 6 years old','jan-21','2018','an uncerain week','the past couple of decades','72','1st model a','the 21st.','a median age of 68','april 21st','8 years earlier','october of 2012','up years ago','one per week','all 8 years','a dodge long ago','a long hard day','last 2','the summer to','only ten years old','2002 four','the entire year','that many years ago','the school year','5 & 7','11 years old','the 1950s and','multiple years','her day','the year 1978','the 1st three seasons of arrested development','college years','per day','the middle of the','every decade','542 million year ago','another 542 million years','the mid-50s','rebook?n','every other month','country.n','a snowy day','4 month old','50','an entire year','the last couple of decades','march','1864','a 3 month','pre-1805','current years','50 years later','just last week','era','fiscal year 2017','fiscal year 2016','heyday','a few years earlier','31 consecutive years','fridays','only two or three days','almost 2 days','10-12 seasons','winter ?','4 years old','a free 3 months','200+ years ago','five and ten year','ten year','219 years','a little over the years','over 800 years','36 years ago','may','1969','august 19th','2004','decades-old','a bunch of friends years ago','ten years of age','week 8','a bye-week','the next 20 years','around 1964','almost twenty years','the early 1800s','1860 to 1932','the next twenty years','its second season','early in the 20th century','about 13 years ago','like a decade','2+ years','this past christmas','1750-1820','a few each year','november','2011','only 25 years ago','several days','a stink years ago','1801','noverber 11 2011','almost 2 centuries','about 16 years','like 500000 years','only 1/','those 4 years','the civil war years','these four years','novemeber','since 1909','3 years or so','just 100 years ago','the many months','the last 25 years','the year 1928','about a week','almost 16 years','from 1196 to 2001','200','000 years ago','50k years ago','some 5000 year old','65 years old','the 1910s','19 years','the first 12 seasons','since 1853','the end of the 20th century','this spring','the secret 4 days','older days','the 30 years','late last year','the 11th','the year 1916','nearly 70 years old','21 century fox','late 2000s','longer than a century','spring/summer 2019','23 years','the service years ago','the first years of the century','90s grunge era','the two 100 year old','almost a month','one hundred years','the late 80s and 90s','only about 25 years old','last january','a later season','a child years ago','nov-11','2011','10s','a lot years ago','1-2 months','the childhood days','the last two','out years ago','holliday','like 25 years','february 14th','d day','six seasons','first two season','the mid 90s','like 16 years','43586','a better year','world centuries ago','facebooks 15th anniversary','9-10 years old','a 21st century','third year','thought second year','their second year','the last 90 or so years','the few years','the first seasons','daily 7','then thousand years','six years later','around 15 or so years ago','the following weekend','nov. of 2006','little over a year and a half old','a number of years ago','just 17 weeks','the first sunday of february','those 20 years','all the years','maybe years ago','one 17 year old','the year 1945','less than 108 years','over 94 weeks','a specific month','200 days','a 17 week season','the late 1880s','the last a year','125k','250ish years old','just 2001','their twenty 20 years','summer of 1932','the day in 1972','1770','next two years','1 thousand years','an average season','a more few days','18111','another 200 years','last about half the season','the age of','the pilgrim days','1905','the late 2010s','1806','the late 60s','trumop','8 year old','a full four weeks','the first 90 days','my 60s','fifteen month old','the 8th century','anothers day',' week','the last couple decades','the year 2004','jul-16','2022','just 15 years','the years 1950 and 1956','8 years later','the second half','the past decade','the last 100 or so years','a regular season','about 2 years','last summer some days','69','few years','1942','the year 2026','years long','last 16','20c','all last year','the last several years','the year 1800','age 70','may-50','0','simpler days','the 1850s','almost 170 years ago','may of 2017','the day some time','dec. 7','over 15 years','less than 100 years ago','day one','the grunge days of the 90s','2253','at least 18 years old','another sad day','at least a few years ago','a season prior to','a season prior to 2007','50 that year','only to one year later','sixteen years','90 mil a year','about that 70s show','one election day','election years','out years later','the last decade','some good days','the last quarter','a weak year','18 years ago','1.6 million years old','a million years old','over 2 million years','this is years and years ago','a 30 year','about 3 a year','80s-era','the first 10 seasons','a few short weeks','this next summer','1.5 days','16 years in a row','pre-1918','over one hundred years','the modern day watergate','its fifth season','just 1 year','40 year old virgin','summer camp','age 6','two a month','school days','the end of the 1966 season','one bye week','since 2002','many decades','around 1928-1929','those years ago','only 2 years','a good decade','twenty games one season','the 52 year old','about 50 years','about the 17th century','around 2004','a decade later','the first days','six-year','over 160 years','16-18','fifty years','the year 1933','his eighties','the early 1980s','20 seasons','a lean year','his many years','10 months of snow','day 1','23 days','about t','17 week','half a year','all next season','like 30+ million','only 6 years ago','62 years old','almost 10000 years','only 10000 years','less than 25 years','this past month','the year of 2015','like 30 to 40 year old','november 11th','24 years one','21 weeks','like 5 months','a productive day','the late 1990s','nearly 200 years','like 2008-2009','as late as 2003','s past','only now','more than years','hundreds of years from now','a bad 2nd half of the season','a day long','08','1bn','generations ago','only 2000','awards these days','nearly a decade','the past six weeks','the past few months','the week before','the 2018 season','only 315000 years old','this fine day','the past two decades','10 or 20 years','everyone month','the house months','the 70s anyways','14th','a better day','the killers years later','since 1989','4536','late 1920','the end of the year','93','the end of a season','45 years','2012-2013','past days','some last season highlights now','this in years coming','no days','nearly 16 years','this last holiday season','the year of the','football years ago','another month','28th','the past weekend','one per month','21 years ago','the years since','a christmas','the late 1800s','about 12 years old','the 18tth century','an odd year','between 1843 and 1846','many days','only seven years later','his last two years','around almost 20 years','78s','the championship one year','lath year','95','2+ centuries','about the year 2003','nov. 11','2011','nov-11','2001','the year was','the first decade of 2000','ign.com everyday','68 years','about every day','a few years old','a couple of 17 year olds','2007-2009','almost 40 years','the 30 year anniversary','the fall of 89','the last 10 years or so','about eight years ago','less days','the end of october 2018','a rainy day','a big year','just the 20 years','16 full years','season 12 or so','9 seasons','at least a week','250 millioper year','2052','at least fifty years','the last four friday','jan. 2018','which year','about 319 weeks','the mid 30s','fifty a year','college days','like 5 years','teh day','the mast years','around 2008','41 years old','1st 400','a couple a few years ago','moden day','16 years or so','the modern era','last two days','the last couple of weeks','this was years ago','about the 12th season or so','do',' week','sixteen yearsthe next few decades','the 4th of february','about 9 years ago','halves very year','some time ago','football dynasty','only a couple weeks','the next 50 years','last few season','a good year','less than 19 years ago','a great season this year','about 37 years old','some lean years','like two months','february every year','only 16 season','before 1900s','forever','february each year','under 10 years or so','this years 17 week season','his rookie season','the 16 week normal season','at least the first 2','the pas 37 years','only 40 years old','modern days','lincolns 8th','1 weekend','two quarter','a tough few years','this sunday','16 year olds','the end of super bowl 46','the past 17 seasons','the last 2 decades','the next seasons','their season','one this year','a few years in the early 2000s','11049','2 or so days','seven months','the summer of 2012','the bowl every year','a big day','1960','his junior year','15th century','their 80s','october of 1986','a good week','more than 2 years','8 more years','1896','everyday','feb. of 2012','nearly every day','about six months back','about one season','a little over 15 years ago','1890','65','a hazy few days','1906','their dynasty','any given year','the past couple of centuries','19303','1916 222','the only years','the last 75 years','a horrible season','the 2017 season','next sunday','the entire 2017 season','the next 30 years','that weekend','1995-wow','the other 3 quarters','the average years','the past two years','the 17 week regular season','an entire season','the first sunday in','just 10 years ago','february 4th','17 seasons','game day','38 years old','four quarters','the end of last season','his high school years','their first year','2 year','a few years older','the first quarter or so','16 seasons','1922','september to december','all season','a year before 2007','the first month','the first sunday in feb.','evey week','a season before 2007','one last year','the worst season','this past time','4 quarters','all year long','11 6191','season 30','a slow year','a terrible year last year','a good year last year','around almost 30 years','32 days','barely 100 years ago','1.75 years','feb 4th','2004','a bad 90s','the mid-2010s','couple years ago','22 years ago','their childbearing years','only 18 days','some 120 days','the end of 2019','such a dynasty','43132','his first two years','50 tds that season','an interesting year','only few weeks','several seasons','7 and 5 year olds','the nineteenth century','the 19770s','their earlier days','almost 3 years ago','the 17th and 18th centuries','ww 2','the dynasty','last yearsa good holiday season','the next 2 years','only five years','30 seasons','at least 20 seasons','6 super bowl','dynasty','the 60s','years earlier','sesame over the years','11 years ago','so important years ago','another 12 years','close to 125 years','about a decade ago','1699-1780','a 100 years','week 11 last year','those bye weeks','off-week','the 50 years','another 500+ season','a monster year','all these days','halo 3','last 7','a bye week','week 4','the next 8 or 12 years','couple weeks','39','two hundred years','april wine','1980 to 1989','only year 1','the great weekend','just 14 days','a blast day','the year 20111','evey day','1792','the four days','nearly two years','the early 90','the worst 70s','under half of a season','longer than 16 years','last week-end','nearly year','the beginning of thte 20th century','10000 year','early september to december','10','00 years','their year','2-3 years','the past 3 seasons','just a couple of years','the sanchez years','over many more years','16 weeks','46 years','the 1960','seventeen years old','ten years or so ago','40725','100+ year old','their wolf days','about 100 years','8 years old','one point years ago','november 13th of this past year','late 80s','little over a century ago','just 60 years ago','1 years','4 days later','the 2022 season','this 17 year old','only 4 years old','about 2004-2008','the holiday bowl','his 2nd year','1802','the last three years','1776','about 30 or 40 years ago','about 70 years ago half','the next three weeks','age 71','45 days','25 plus years','90210','todays','football season','a bad season','the first month of the season','the year 1932','wealthlies','the early 1990s','a great week','the end of the 21 century','the future years','the simple days','built long ago','around 2003','16 season','1927','a key year','the hundreds of years','4-8 years','early thirties','one year old','one month','9 months','the 35s','just 23 years old','the last two years lol','the day','u of ok days','less than a quarter','earlier this month','too years','dec. 21','2008','new years','the 60s','week 5','the 40s and 60s','years ago','25000','a nice year','early september','100 year anniversary','13th','the following season?','position 13th','prior to 2001 season','the last 8','a shoe shopping day','almost every week','around 16 years'],
'EVENT':['the nintendo 64','cha cha','world war z','world war i.','the world cup','the super bowl','us open','game of thrones','golden globe','valentines day 1991','a world series','world series','world cup','the 1926 world series','the world series times','world series championships','world war 2','brooklyn nine nine','infinity war','the 1908 world series','the 2016 world series','another world series','series','the works series','world seriess','the wold series','the first world series','super bowl','the battle of little bighorn','world series total','the fall classic','the show game of thrones','the childrens series sesame','civil war','the womens world cup','92 world series','the hbo series','game of lions','the cultural revolution','cup','fifa world cup','2022 doesnt','the civil war','olympic','festival','us international','the cold war','the shift festival','fort worths symphony','winter olympic games','winter olympics','depression','the chinese cultural revolution','us open tennis title','grand slam','a us open','war','the korean war','the 2004 super bowl','the guinness world record','the tonight show','the us world series','the national prep championships','the next generation','winter olympic','korean new year','the british cup','british cup','the art of war','the big six','video game','spiderman series','independence day','daily show','the us open','star trek series','revolution','woah','olympic winter','super contra','tecmo super bowl','fantastic four','world war ii','the fantastic four','the barcelona olympics','the winter olympics','grammy awards','the vietnam war','the great bambino','the world tennis tournament','the 2022 qatar world cup','qatar fifa world cup','the fifa world cup','womens world cup','academy awards','austin powers','olympic games','the guiness world record','armour','the movie treasure planet','babies','china doesnt','the fifa cup','the rfk stadium','the winter solstice','a civil war','world cup victory bonus','the great british baking show','global citizens festival','a shakespeare festival','post-vietnam war','scottish protection of animals act','valentines day 91','world seriesthe 1992 world series','ghostbusters',' groundhog day','golden globes','fall classic festival','game 2','cameo','the war of the worlds','the 2022 world cup','the super nintento','the womens world cup','iphone','a chinese new year festival','chinese new year festival','lunar new year','this world cup','sports year','the daily show','the incredibles 2','the incredibles 13 years ago','game cube','the breaking bad series','a renaissance festival','the bachata festival','the 2018 world cup','the all star games','leap years','the geneva summit','the twlight movies','the great british bake off','trojan war','world war 1','the smithsonian kite festival','super bowl mvp','the paella festival','ps3','the geneva convention','game 5','wold cup','first world cup','qatar fifa world cup final','the fyre festival','the world series lol','the 93 world series','the 2012 london olympics','the little big planet','world war two','groundhog day','us open tennis','memberships','the great depression','t-series','the us constitution','the world music festival','california governor campaign','meat week','timberlake','the penn quarter','womens world cup','harts war','k per year','the uk version days','show','the world series championship','yorks area code','spring training','the 28 euro','watergate','the 1969 us open','the chapelle show','world war one','four radio','rich)id','euro','the vancouver grizzies','the star wars','king kong','winter olimpic','the special olympics','the 2014 world cup','neptune','nba finals','netflix original series','olympic winter game','the us world cup','the world cup championship','the fifa world cup often','the world cup lol','world cup given its','the qatar world cup','2022 world cup','super bowl rings','nuntii latini','days like thesegreat women','stanley cup','the hunger games','the zach cup','olympic winter games','new years eve','bart','world war','another super bowl','the chicago bears','super bowl lii','the seoul olympics','the koi fish','the selfie movement','another world war','the national day of prayer','the academy awards','white christmas','the olympic games','world war i','international day of the','6 world cup','the american revolution','hugo','cold war','the thomas the tank engines','the second world war','sesame street','game 7','the weekend update','geneva convention','post-vietnam','hurricane florence','a world cup','the 2nd world war','world cup final','the 2022 fifa cup','qatar world cup final','the world cup','the maccabi games','the 1930 world cup','word cup','the daily show on comedy central','world cup 2022','the 2022 cup','qatar world cup','the tokyo 2020 olympics','the gulf war','the world war ii','youtube premium','war of the worlds','valentienes day','the us opens','world war the television was improved into black and white.','show days','the second world war black and white tv','the world series for baseball','the game cube','the weekend update','comedies','golden globe for best comedy series','first super bowl','the philly super bowl','the 85 bears','the simpsons bart','the detroit red wings','the world summit','ravens super bowl','brooklyn 99','scary movie lol','the iraq war','womens cup','the world cup final','a super bowl','super bowl 52','super bowl 46','the 2017 bears season','this super bowl','mlb world series','the super bowl 8','worlds','the median viewer age was 68','the chicago stadium','pokemon','rams','talking super bowl','the war of 1812','fifa world cup series','the olympics world cup','sometimes april','world war the black and white tv','tokyo disneyland','patriots super bowl','world cups','the world cup games'],
'FAC':['tupac','top gear','smooth criminal','the great luke','eiffel tower','the golden globes','the screen actors','the lion king','netflix original','arapaho','comedy central','jacobs field','the bay bridge','linkin park','2st grammy','the roseville shopping center','hulk','the mouse king','cowboy','easter','linkin parks','wrigley field','the san diego padres','fenway park','the chicago cubds','sesame','yankee stadium','shea stadium','yankee fan','raven','schleswig-holstein','a space odyssey','the el royale','seasame street','the international space station','tierra de castilla','elm street','3rd rock','vatican','the sunspot observatory','the lego movie','simpsons','linking park','bb king','the boston garden','kanye west','the panama canal','the panama canal zone','jurassic','the rock/punk rock','xbox 30','the eiffel tower','the white house','lion king','broadway','pennsylvania avenue','the rugrats movie','the solar system','the capital one arena','madison square garden','couldnt','mouse king','the river thames','the tesla model s','the folger theatre','the wrestling hall of fame','the tower of babel','schlewsig-holstein','the golden knights','the st. louis blues','lake erie','hockey night','ninth gate','the hologram theory','mainstream media','the maryland zoo','gotham tower','brand finances','the germany lego factory','broadway musical','my left foot','guitar hero','polka dot','capitol','metro','wrecking ball','arent','the ancient roman amphitheater','lincoln park','dark side of the moon','dark side','red rum','hiking/ mountain biking trail','disneyland','the space shuttle','the kennedy center','the golden state warriors','natalee holloway','grand houseboat','the milwaukee schlitz','the red wings','lynkin parks','raf','the eiffel tower twice','episode i and solo','the kepler space telescope','the blues hall of fame','wonder women','marvel','the great snail-o-pithicus','the mouse kind','the statue of liberty','nashville international','black panther','the ancient greeks','the broadway musical','the king of rock and roll','tarzan','stephen king','jurassic park','the javanese alphabet','the nba hall','the milwaukee bucks','golden state','virginia tech','the golden gate warriors','the olympic tower','the cow palace','the portland trail blazers','the golden state warrriors','the golden gate warriorsthe oracle arena','the iron throne','t2','space jam','the rapping lucy lu','the new black','tellus','havent','my xmas eve dinner party','red rocks','the black panther','australia day','1997 golden globe','paleo','the golden globe for best comedy','mcdonalds drive thru','gupta','dc','kingdom come','odyssey','the songwriters hall of fame','the stanley cup','incredibles 2','reptar','millennium park','the space shuttles','the moon btw','facebook','the lincoln park','godfather 1','the great lakes','star war','the holy grail','the green lantern','hazey flow','virgina','the dark knight rises','whose line','brooklyn nine-nine','london bridge','the brooklyn bridge','north face','the new york times','the burj khalifa','the global citizens festival','the black keys','the kung fu hustle','the circus of the senses','u of kansas','air jordans','the u street music hall','nba hall of famer','the golden state warriorskennedy center','jump street','the national mall','the wolfram alpha','mt everest','guitar myself','olympic sports gear','the golden glove','the video game','the golden globe','the golden girls','folger theatre','mall','capital hill','the golden globe for best comedy series','incredibles 1','presidents day','ncis la','incredibles ii','the 3rd rock','glens garden market','the renaissance hotel','chester bennington','the great wall of china','the grand tour','buckingham palace','the golden globe best comedy series','the bladensburg dueling grounds','bladensburg dueling grounds','international space','the art walk','the king of hawaii','the stephen king','series sesame street','reel big fish','gangnam style','stephen kings','the gillette stadium','the king jefferson','grand theft auto','the playstation vita','etemenanki','the eiffel tower lol','pearl street sw','the town green','the red ball','the night clerk','the app store','the sun beat out seinfeld','downing street','galloway street','south dakota avenue ne','the roman amphitheater','the red special','speaking of sci-fi',' starship troopers','the new york knicks','the hologram theory lol','broken road','the ace venturas','rugrats','twitter','dark side of oz','windsor castle','the royal wedding','the golden theater','white stripes','co2','lavar ball','xbox','grand turismo','the band muse','oregon trail','stubbs','kuala lumpur airport','lnkin park','windows 95','capitol building','ventnor sports cafe','the puppy bowl better','puppy bowl','drunk history','hubble','patriots','chuck e cheese','fury road','the king hawaii','dulles airport','the lombard street','oracle','the golden state','the golden state warrioes','the san antonio spurs','olympic tower','fifth avenue','the hollywood roosevelt hotel','the dolby theatre','the kiss wikipedia','my great grandmas house','long island ny','stranger things','strait outta campton','the dark knight','the mackinac island','schleswin-holstein','wouldnt','the bundy tapes','the human torch','google maps','rocky horror show','the dalton brothers','the green lantern film','space shuttle','the miami heat','michigan state vs','candace park','nba hall','the golden glob','camden yards','mustang','thompson square','schoolhouse rock song conjunction','the f troop','the blue lagoon','the brisbane g20 summit','bromantic','chuck e cheese lol','the oakland arena','the golden globe award for best actor','disco','the charlottesville day school','catalina island','sephen king','the grand canyon','grand canyon west','treehouse of horror xxi','patent-motorwagen','brambleton regional park','pennsylvania turnpike','hybird theory','grand ole opry','shining','hilary','burger king','films?stephen king','n sesame street','olive garden','the kansas jayhawks','the white house guest house','the us nuclear icbm','hoveround','pi','zuck 2.0','ph.d.','the fresh prince of key largo','another hall of famer','weekend update','sp','voltaire','jfk airport','mackinac island mi','muhhammed','cook inlet','the oak ridge boys','kenny','cape town','times square','the pennsylvania ave','the guest house','uof m','g.o.a.t.','starks','n64','the 1st moonwalk','national park','pennsylvania avenue nw','another netflix original','daniel day-lewis','anoine de la','family','the two noble kinsmen','the big bang theory','the revolutionary war','category 5','pres of indonesia','tortilla coast','19th street','red green colorblindness','pennsylvania ave nw','the white hosue','austin tx','a statue of liberty','vp hilllary','tuman','the great white hope','1211 avenue','don king','trump tower','hollywood roosevelt hotel','guaranteed rate field','white house','the philadelphia spectrum','the quick-e-mart','bible','griffith park','the beverly hillbillies','the great dustbowl','college park','the eifel tower','eiffel','the south park family guy','the sega genesis','the hall-of-fame','benz motorwagen n','apfa','damascus international airport','the walter reed national military medical center','max','sessame street','simpsos','air jordan','ravens','ventura highway','hollywood video','notre dame','the iowa hawkeyes','cumberland','locker room','750th','fx','red box','hollywood holloway','lake huron','bachelor','the art museum','atari','23rd street nw','the carol burnett show','flame','the big macs','pokemongo','lillyhammer on netflix','the london symphonic orchestra','the cobo center','the kid power bands','trump international hotel','the white house correspondents association','buger king','the longest yard','the white shark cafe','lambeau field','browns','the green bay packers','the effiel tower','rb derrius guices','shoe carnival','gillette stadium','the denver broncos','qb','browns stadium','foxboro ma','199th','kickball','the thomas','eagles','the gillete stadium','the baltimore ravens','main street america','fantastic 4','the bumble bee','veep','the horowitz steinway','morning blitz','emmy','the woodrow wilson','replica house','crimea','chapel','fedex field','the family guy','sclewig-holstein','carole king','fleet street','stranger','eating','triple h','mar a lago'],
'GPE':['japan','taiwan','alaska','hong kong','nutcracker','south korea','japana','minnesota','us','canada','america','uk','navajo','boulder','germany','colorado','netherlands','u.s.','the united states','usa','mexico','border','texas','netflix','kanye','michigan','korea','eminem','pennsylvania','hershey','athens','nevada','india','lucas','virginia','georgia','manhattan','china','utah','istanbul','salvador','el salvador','ximena','shameless','chicago','missouri','australia','hollywood','miami','hercules','oedipus','greece','ram','seattle','washington','new york','los angeles','atlanta','dallas','california','north dakotas','u.s','russia','sacramento','north dakota','ww2','north dakotas','las vegas','oregon','oklahoma','hawaii','antarctic','roku','iraq','the western united states','england','adam','the soviet union','south carolina','maryland','telluris','oscars','nosferatu','the united kingdom','norway','france','depp','kinda','treasure island','bambi','brazil','woodstock','queen','mikado','new orleans','united states','kansas','kansas city','pakistan','britain','hindenburg','astroria','baltimore','gran vals','talkeentna','scotland','compton','kanye wests','electro','new mexico','the last airbender','north korea','obi wans','leia','guatemala','yavin','donkey kong','madden','maverick','seinfeld','ireland','kentucky','glendale','new zealand','viginia','charlottesville','pennslyvania','tennessee','havenr','oakland','ca','yuki','turkey','switzerland','gone girl','the ottoman empire','wikipedia','poland','cleveland','boston','iran','florida','dubai','london','fixer upper','pompeii','vermont','degrassi','minneapolis','mn','nigeria','clancy','helium','la','comedy','green lantern','moscow','paris','nokia','moranbong','toque','dunce','winnie','los gatos','alabama','new zeland','aloha','dark','moranbong band','iceland','israel','austin','side','parkland','fl','jahai','hominina','machado','harper','strasburg','phoenix','brooklyn','ottoman','ny','springfield','sf','san francisco','ethiopia','westeros','essos','aladdin','croatia','malta','zulu','walmart','detroit','d.c.','copernicus','newton','wisconsin','bronx','cuba','puerto rico','the dominican republic','venezuela','houston','italy','egypt','beat','zuckerburg','vegas','mackinac island','norther','angora','mackina','palo alto','north carolina','siri','indonesia','indoenesia','cortana','hs','ophiophobia','minnie','tolkien','belt','talkeetna','austrailia','malta scotland','spain','ganymede','direwolvles','st. louis','ottoman empire','scottland','morocco','bluetube','orlando city','orlando','pascal','freshwater','argentina','belgium','qatar','napa','portland','fahrenheit','tunisia','puglia','napa valley','smith','grey','trojan','eephus','pandora','r2d2','nissan rogue','macinac island','holland','mi','denmark','sweden','kansas city jaz','curiosity','schleswig','motown','elvis','bummer','alexandria','finland','nm','e.t.','san fransokyo','empire','lilyhammer','lacoste','rome','python','genesis','new zealands','falls church','bridgeport','connecticut','stereo','alphabet','metallica','nirvana','cratia','g20','nderstand','ohio','washington dc','alska','titan','roman amphitheatre','upgarde','javanese','rio de janeiro','hockey','ice hockey','bulgaria','concert','norfolk','teddy roosevelts','antifa','diy','pet sematary','maine','the netherlands','iowa','dead pool','jordan','sushi','busta rhymes','denver','aspen','singapore','sahara','asimo','s. korea','louisiana','n. korea','satan','memorabilia','braille','the czech republic','school','asimov','czechoslovakia','czech republic','slovakia','belgrade','notre','arkansas','yorick','everton','metoo','the rock','richmond','v.a.','sabrina','lego','spock','phanton','nashville','veranda','menlo park ca','twista','green eggs','ham','rick','alamaba','vietnam','illinois','zendaya','rodman','canadia','ukraine','givien','bularia','ushanka','illyria','the skull of yorick','third rock','syria','mississippi','universes','harmonicas','galveston','saudi arabia','rhode island','delaware','washington state','park city','makinac island','s. africa','harlem','instanbul','humans.n','new york city','queens','cardi','hiroshima','nagasaki','north or south korea','bulletproof','magma','caifornia','prisons','ikea','pac','great britain','twain','space','persia','graffiti','ughhh','va','berkeley','fantasy','foo fighters',' snow patrol','ahve','its','zepplin','moon','jj','venus.','pallas','muse','amsterdam','zuckerberg','orphan','new jersey','gotham city','ketchup','jersey','weird al','gotham','sasebo japan','tokyo','kyoto','haydn','earth-199999','pluto','armenia','seinfield','thrones','kenya','panama','district of columbia','u.','arizona','st. louis blues','kombucha','astoria','montgomery county','jamaica','mightve','kevlar','eeyore','roswell','lichen','demetri','canbe','blockbuster','voltron','golden states','mine','may.','aruba','berta','ri','austria','pilgrims','toronto','stewie','queensland','mormon','big bend','benedryl','nothing','phelps','pittsburgh','the brooklyn nets','lew alcindor','donovan louis','daredevil','vudu','lacrosse','ocala','machinac island','venice','nort korea','pensylvania','pennsylvannia','mexico city','monaco','willows','narnia','az','lester','pontiac','mich.','scream','benjamin','kubrick','akron','mackina island','long island','drama','university','mobile','s. ca','utube','broadband','bangor','me','thailand','macau','elephantts','zebrafish','daytona beach','mahi','latvia','cold rock','orcas','earths','clerks','nolan','vinyl','soviet union','the empire strikes back','thsoe','wikileaks','twilight zone','del. danica roem','wildest dream','t.s.','the 69 us open','einstein','south park','harden','haywood','u.s.s.r.','kayne','kanyes','lamar','drake','p.diddy','il','nd','milwaukee','sy','knowm','antikythera','mj','dragon','l.a.','grammy','san bruno california','ill','nintendo','wreck','kobe','yikes','spider-man','tobey maguires','airbnb','pittsburg','nelly','venom','hungary','maccabi','sixer','the virgin islands','kpop','bahamas','nw','chitown','zuck','outta','south wales','megahan','prince william','theatre','oj','dramas','ikea heights','obi wan','nc','burbank','occupy','beverly','phineas','inf ireland','angilau','tonga','blues','gilgamesh','cambodia','guitar','thames','gs','steph','south west ohio','philadelphia','acrid','oh','rockets','the golden state','san fran','santa','akron ohio','bran','norht korea','weselton','frozen','moana','celia','southwest washington','south africa','hawking','mackinac','artpop','beyonce','glasgow','epcot','sport','washington d.c.','savannah','audiophiles','caitlyn','thou','amazom','west africa','islands','levi','timberland','lativa','lollapalooza','omaha','broccoli city festival','astronomy','the ivory coast','expos','serena','polo','glenelg','superbowl','christmastime','pompei','beatles','pong','mcgiver','ninetendo','archie','veronica','arc','get out','sydney','native american','whopper','pussy','malaysia','itunes','menlo park','beijing','lillyhammer','goji berries','south beach','telsa','spacex','teslas','memento','marijuana','the us virgin islands','albuquerque','the dc comic kingdom','empire state of mind','tchaikowsy','jackson hole','panhandle','panama city','friendship','columbus','pompii','portugal','bitcoin','ethereum','ios','minecraft','legos','spartacus','thati','huber heights','alameda','fb','s.f.','myspace','st. bernards','youcd','indiana','kiss','rio','tsunami','volcano','s s.','st. anns','new yorks','vitriol','r.i.','st louis','jonesboro','the u s','washinigton','bangkok','harvest','jerusalem','nebraska','balletn','montreal','kick ball','georgetown','deleware','jay-z','roc','neat','palestine','madagascar','birdbox','omari','charlotte','shire','monopoly','xenophobia','afghanistan','smartphones','hing kong','the windy city','lebron','space jams','julie','julia','van halen','kayne west','beverly hills','spielberg','syfy','hotlanta','goat','los angelas','san bruno','blue apron','nintendo gaming','ottumwa','des moines','knoxville','chicano','saverin','mccollum','santa cruz','shutter island','the gaza strip','ocean city','md','flubbber','harry','funny!!ryan stiles','fornite','dalmatians','oberyn martell','algeria','bigbang','revenue','rapping','madrid','the washington area','north east','kansas citys','ny city','antartica','bromanic','pakku pakku','pakku','pac man','shania twain','pirates','willy wonka','nautica','jansport','wheaton hills','yutube','cafe','panam','dakota','fiji','donut county','twaim','shibas','westerns','evolution','island','wc','shaquille','labradoodle','casper','kumar','sun','downtown dc','new zealands','boycotts','lancaster county','port city java','violet','atlantic city','groundhog','d.c. dream day','north bathesda','pixar','jumanji','takoma park','north bethesda','parr','caesar','third rock beat','incredibles','tahoma park','theater','washington',' dc','ghostbusters','carlton','brat bird','arlington','tibet','chess','pa','larry crowne','golden girls','blanche','states','soundgarden','omg','amphitheatre','hydra','bergen county','nicu','p.','hanks','bartolomeo','the motor city','statford','bellamy','hehe','pennsylvania ave','vermilionville','bandana','kawhi','kristaps','luka','o.k.','mountain view','hostels','eeeewwwwww','halifax','guildford','afgan','ussr','cars','san diego','ariana','buffalo','cincinnati','ecuador','uruguay','naples','burbank california','www apps','reno','nev.','warrior','the twilight zone','belfast','van dyken','capital gazzette','prince edward island','buffet','kinda boring','los vegas','bc','osteria','brexit','gran turismo','chine','summit county','bell island','baltimore county','emilia','clapton','sg','vancouver','fatiguesn','name?n','hawaii - aloha','s','adam22','led zeppelin','labrador','roman amphitheater','stairway','u of michigan','kansas city chiefs','lic','braile','chappaquiddick','jonathon','kindles','washington d.c','prince george','donkey kong jr.','v.r.','imran','beauty','the british empire','ehtiopia','the emmys','latin','vienna','pablo escobar','dvd','alexadnria','colombia','hinderburg','college','improv','collinsville','northn','san antonio','great u2','madison county','barns','garages','somewhere','the kingdom anamalia','carlin','pyeongchang','casablanca','button','bulldog','st. georges','the emmy','fangoria','fleetwood','northern ireland','othello','macbeth','adidas','hasbros','laborador','philippines','holloway','st. petersburg','wyoming','miami heat','yugoslavia','sao paulo','theu','arlington va','toms hanks','angry birds','washington city','new york state','zucks','made','cena','kardashians','n.k.','kiera','millennia','berlin','macianac island','moss','vr','gear vr','yugioh','pikachu','tennis','brockhampton','gypsy','ragtime','patton','north africa','biebs','massachusetts','claustrophobia','u.s..','willl','prokofiev','benz','nedarra','silver spring','md.','greater washington','laurel','jackson','bloomingdales','benstien','the puppy bowl','dodge city','puppymosas','baldwin','nban','washington dcs','cake','tampa','sublette county','wyo.','bird','barcelona','kalakaua','land','mclean','charleston','cashola','miami heats','laval','u wl','southafrica','dalton','stones','spokane','shania','reykjavik','groot','kabul','qarabagh','thomas','greenland','victoria','center city','jaapan','mackinac island island','the kingdom ended','marietta','oklahoma city','sacramento kings','san antonios','nascar','vasectomy','afirca','fraiser','architecture','aladin','the united states lol','uconn','new york ny','secaucus','honduras','chile','peru','mackinac islands','carter','anaheim','bubba','fla.','extremadura','nj','airplane','zukerburg','caser','san antonio spurs','lynrd skynrds','ace ventura','underdog','non sequitur','north mexico','messi','los angeleswinning','matchbox','narcos','sugarland','marsn','pennsylavania','mueller','cajun french','nooglersn','south-africa','keller','new hampshire','u.s.a','jc','weightlifting','okinawa','guangzhou','hansbrough','wonderland','the united states','frasier','zimbabwe','umpiring','vacation','huntington beach','l.a','nickleback','jfk','sorta','p.e.','ivory','kazoo','jefferson','trump','politician','hayes','inodnesia','bowie','young','creativty','groovy','black mirror','schleswigholstein','aleandria','blockchain','icdland','schleswigholtein','merida','brave','shangai','shandong','slum dunk','puma','the u of k','shanghai','memphis','shaquille oneil','thompson','iguodala','ma','the city of cleveland','dameron','niseko united','stockholm','slang','trump','north koreas','newyork','mount bethel','pa.','airship','brisbane','geneva','a united states','the hermit kingdom','bethesda','dumb','caesars day','ginobli','goodfellas','libya','afganistan','tempe','s africa','dresden','wherever','t.v.','j.r.','idaho','work!i','a.m','hualapi','vezina','angola','i. anyways','emeryville','alameda county','studio city','ethipoia','vince','europe?i','findland','klendathu','prnk','hoeber','qualcomm','thine','saudi arabias','sochi','wouldl','winston','jughead','wallmart','michigan state','haha','lillehammer','yepn','rambo','bananarama','koreas','peyongchang','efferson','the united states democratic party','mcdonads','bluerray','black adder','chili','instagram','canaan','harry styles','nikes','kelper','armania','zucky','melo park','lakewood','hilliary','scotty','el paso','coldest winter','austin?n','russia edward snowden','hernandez','analytica','yuge','washington jfk','melania','the dc united','blonde','tupelo','slovenia','canda','churchill','st. matthews','st. matthews','h.s.','tulsa','indo','japa','gavelston','sonny','south dakota','salem','lot','canaan banana','yo','zimababwe','aristotle','broward county','putin','republics','marriot','paypal','south park','pysics','linloln','nairobi','the sunshine state','soooo','ying','costa mesa','hanoi','superstar','prince','chicago stadium','yeas','mckinac island','eden','netflix?n','helsinki','malus','hillenburg','superbad','the simpsons crew','itchy','scratchy','the g20 summit','st. pats day','dublin','hulu','scotts valley','popularity','j.k','the united states marine corps','allen','zulo','baymax','south afric','journey','bands','geeez','barbecue','beloit','podcoin','panasonic','b.o.','dicaprio','schlesweigholstein','opposite','new jersy','history','sega','the united statesweeeeeee','north kora','zombabwe','the kings of england','quebec','timberlands','cyprus','izods','el reno','danny','the la rams','kong kong','pointe','kennedy','mass games','sith','gloria','django','blizzard','wagon','bananas','indie rock','denver broncos','klingon','miguel cabarellos','grande','kiki','gaelic','grande-butera','manchester','palm','skeptical','3xx mill','hamstrung','mackinac michigan','zuckerbug','schlewig-holstein','nepal','new york-new york','sri lanka','brunei','erie','hayden','bartolomeo cristofori','maga','southhaven','scrubs','breitbart','with','rio de janiero','s wierd','al','indoensia','riverfront','alexandria virginia','potomac','estonia','noth korea','jkf','millennial','irma','costa rica','universal','macron','most republic states','bend','city to city','newark','virgin','pumba','prague','washingtons','dokken','redemption','byrds','pratchett','googleplex','scottsdale','tucson','amnesia','maroon 5s','south koreas','jeffereson','canadian hockey','hugh lauries','the u of kansas','famer','u.k.','likei','cancer','basketbal','teh dc','thousand oaks','bluegrass','bluefish','pompeli','red rock','beltsville md.....','unclaimed baggage','bennington','beltsville','navada','alladin','the united arab emirates','empire state','ivory coast','bengal','florida state','jones','swansea city','tech','itn','zimbabwe?n','the roman republic','koine greek','austin city limits','the airship hindenburg','olympian','tasmania','carson city','rock','foo fighters','mumford','indonisia','stadiums','bumbi','xenomorph','disney','ausralia','amigos','murray','caddieshack','humane king kong','devumi','horrid','u of iowa','santa claus','zimbawe','omerta','indianapolis','cause','logic','ughs','nv','pres banana','zimbawes','prince william county','sacremento','stephen','turkey oscar','bosnia','ringo','fance','lollaplooza','concertina','sutherland springs','tex.','ooooooh','manila','north amerca','ahmed','blutube','youtueb','thehof','nlw','autralia','el barretal','new zelaland','illini','norwegia','the u. of iowa','alexadria','u of','wonderhow','agon','washingon','trum','troy','notta','myanmar','the nutcracker hahahah','crusty','a.m.','peyton','anyway','joberg','military','annapolis','awesome','minnesota fats','broncos','ellaville','caps','nats','flint michigan','el salvadore','benfica','ciolek','animal kingdom','hybrid','zaimbabwe','new amsterdam','carnevale','tebowmania','broad city','huxtables','rushmore','monty python','zelda','jacksonville','marshall','embiid','megawati','regan','shap','intro','ebola','south parks','the us military','gaddafi','apparently','mt view california','polaris','is212','tebow','eli','feast','archie jerseys','saint','playbook','louisville','san franscico','istambul','ceausecsu','romania','ozark','n.c.','rb','uc','oaklahoma','flux','las vegasthe u of iowa','the u of kansasgaming.n','galverton','handmade','foxborough','mass.','los angeles rams','bledsoe','wentz','nickelback','mahomes','shaquim griffin','montana','multitasking','suv','ukrainian','hussain','san jose','delhi','huopai','ulighur','iowa city','cumberlan','mass','providence','belichick','pravada','presiden','new-york','fox holes','cananda','gigabit','kanye west lol','gaza','williamsburg','north virginia','the u of iowas','new york jets','guam','kelly','negan','tara','mich jagger','hindenberg','topeka','g.washington','holden','zapara','whoopi','lordstown','ahh homer','olympic village','georgia tech','skeleton','bobsled','wasington','the u. s. presidents','the virgin island','doha','bataclan','wales','north virignia','norweigan','staying','merkel','necada','windsor','germanys','mount vernon','ou','canaada','bannon','britan','t.i','iowan','left-handed','odell','gorgeous george','he','the united league','denver oakland','ahwatukee'],
'LANGUAGE':['greek','roman','spanish','french','russian','mandarin','arabic','hebrew','japanese','buti','americans','grownish','maroon'],
'LAW':['the seventeenth amendment','constitution','awards','super star wars','porcello','the geneva conventions','the battle of the little bighorn','the icelandic constituion','flintstones','war and peace','election 75%','section 3','the revolution of the moon','civil rights act','the voting rights act','roe','the civil rights act','the billboard music awards','constitution via facebook','american sign language','dp 2','batman','goldeneye 64','article section 4','the toronto film festival','billboard 200','a basic income','protection of animals act','1930s-1950s','the rule of cool','section 1','article section 3','grammy awards for best rap/sung performance','outkast','the volstead act','the rush plus','the first amendment','emars','the black cat in dc','section 2','harts war with bruce willis','article 3','iron man 2','lotr','the connecticut boys','article one','the facebook ','the freedom of the press foundation','factual section 2','the home goods','mlk day','act','1','2','roe vs wade','a nintedo 64','the un law of international rights','47331','a youtube celeb','300k euro','the movie straight outta compton','the cma album of the year','the world record of','romanov','arrow','solar','the paris agreement','the geneva convention summit','imagine dragons','article one of the us constitution','the law enforcement','bart doesnt','asmr','a national election','the az cardinals','the constitution','harts war with','the freedom to farm act','the hebrew bible and greek septuagint','ruble','super','the national 4th of july concert on the mall in washington dc','a voting rights act','cannabis cooking show','constitution ave','remember myspace','the bears and packers','the mother of all stats','roe v wade','the article section 2','the article section 3','the voting right act','the goon show','the geneva conventions'],
'LOC':['venus','jupiter','earth','asia','blue planet','wild ones','chewy','the deep state','west','mars','the pacific ocean','africa','south','arctic','goonies','moon/','spaceballs','siths','europe','hans solo','the last samurai','north america','the kanye west feud','donkey','sharp objects','northern mexico','marina district','captain america','who','ugg','lake michigan','the gulf of mexico','the korean wave','the old west','the north siders','the south side','americas','isotopes','hollywoods','caribbean','the bay area','latin america','google hangouts','the oculus rift vr','machine learning','homepod','woods','the hudson bay region','attic','west coast','the wine outlet','the west coast','the middle east','the east coast','cloud','inside out','mount everest','mt. everest','wifi','the pacific rim uprising','r&b','kashmir','teslar','silicon valley','central park','milky way','the west wing','new england','the hudson bay area','antarctica','the red planet','circus galop','new moon','nile','the magic kingdom','medina','lara','the south china sea','the southeast of usa','the kissing booth','iphones','s insane','google earth','jenners','elon','seahorse','the moody blues','cold planet','proxima centauri','middle earth','batman forever','death valley national park','cape canaveral','mars haha','south louisiana','northern rescue','opera','pacific','ashe','midwest','everest','europa','psycho','hudson bay','viktor tsoi','south koreas','n. america','zeppelin','wikileakes','old faithful','planet earth','tangier island','hindnburg','fenders','the mississippi river','north americas','arctic sea','flagstaff','strait','atlantic','east','thanos','the earth first','south america','san andreas','gulf','the northwest atlantic','the moon','hampton roads','northern virginia','the mars opportunity rover','the mars rover','climb mount everest','interscope','born','mummy','southwest','reboks','north koreas k-pop','red mars','guantanamo bay','east asia','wizards','san francisco bay','the san francisco bay','the north pole','the south pole','masut','speaking of earth','hudson bay region','the northeast us','the northern lights','hoover','central','sc','pitch','volta river','fantastic beasts','decalse moon','huskies','hannibal','n. americas','northern ohio','jazz','east coast','northeast ohio','stan','western europe','global','3rd planet','kendrick lamar','hangover','victorious','pixars','birds','new yorks','sound','the pacific ocen','bay area','lake','pats','ruan seacrest','gordon hayward','the hudson bay','eruope','baseball america','shelties','the the moon','capitol hill','punch out','the galapagos turtles','third','mainland','new light','the green mile','greatdid','echo','the hotel transylvania','snowden','mt.','mount','club west','the east potomac','whiskey','teacup','the moon rocks','caesars','the san jose sharks','sweet valley','northern spain','theyll','north americas','haunting','the atlantic ocean','dream','abbotts','verdant','the amalfi coast','osteria costa','the blue planet','the planet earth series','bbc america','turing','the led zeppelin','the amazon echo','amazon basics','murder mountain','playstations','beast','the amazon rainforest','the sean patton drafthouse','america graffiti','30rd rock','the south park','aristotles poetics','poor big bird','seacrest','the immortal jellyfish','western','the dead south','niagara falls','central america','westworld','robots','the new testament','paradise','the nfc east','the middle and near east','mt. everests','cosby','north','pond','the punisher on netflix','classics','northern michigan','the gulf coast','ticketmaster','treasure planet','anthem','the green hornet','the unites states','wundergarten','nob hill','russian hill','the north america','only south america','scots','mavel','truman','the botanical gardens','gran','the big east','olympians','diogenes','spoty','hudson bays','team america','the pacific northwest','xboxes','google translate','northern california','the east coast bigfoot researchers organization','north sea','middle east','s kinda','northeast','middle america','shrek','the haunting of hill house','nederlands','the treasure planet','stars','schewig-holstein','west cowboy','loudon valley','mackiac island','the northern hemisphere','uber','pearl harbor','musical america','siberia','north texas','the moon haha','the old atari','the aloha shirt','ocean','booth','a space jame','the moon pink floyd','red-grenn','key west','latin lol','balkans','spidy','north pole','the east room','the south lawn','green bay','the pacific amphitheatre','the hollywood bowl','the korean peninsula','mid meal','professional tennis','crystal','the george w bush','delta','telluride','comcast xfinity','wind','u','the skokie park district','solo','sean bean','the mississippi state','gulf coast','the northern territory','western lake erie','kindergarten','make america great again','wharf','the southeast thee','miss america','the north sea','the third rock','amazon rainforest','south america lol','mountain','southern california','northern va','sergeant','vs silicon valley','the middle states','agri-biz','the orange bufoon','amazon','travel','teas','twice','the west africa','hope','a.d','nam','mackinaw island','gran slam turismo','dl hughley','west wing','new orleans saint','the capital gazette','corvette','the michigan st dr','atlantic ocean','unlike europe','west coast hollywood','noah','the western hemisphere','barack obama','the hoboken jets','green bay packer','begnals','nfl','the jacksonville jaguars','the jupiter storms','nfc east','bowl','the new england','isn','jellybeans','south asia','quarterbacks','the streisand effect','south florida','the arctic monkeys','ne','the mountain states','the planet jupiter','the north east','steinway','narrator','assateague island','the amazon river','south park flowers','duque','south park episode','the bat area','new zelanders'],
'MONEY':['$1.09 billion','84 per cent','billion dollar','over $8.5 billion dollars','$65 billion dollars','only $500k','$65 billion','$1 billion','around 5500 $','3 million dollars','between $5','000 and $6','0','over 1 billion dollars','about $1','110','just $9','over $8.5 billion','only $309','over $270 million','4.5 million','1.65 billion dollars','only $7500','an extra $500','billions of dollars','about $65 billion','over 8.5 billion','a billion dollars','309 dollars','15000000 dollar','only 309 dollars','million dollar','thousands of dollars','$65 billion dollar','5 bucks','$$$','65b','217 million dollar','10 million dollars','$50 million','$2 billion','$21.9 billion','$10 million','$10 million dollar','2 billion dollars','$390 million','$8.5 billion','over $309','0','0','only $309 dollars','$15 million dollars','$270 million','three million dollars','6 thousand dollars','$500 billion','500 billion dollars','more than $700','that billion dollars','3 million dollar','1110','only $9','300-$400','only $50 million','4.5 billion years','over 4.5 billion years ago','over 20 billion dollars','$18 million','about 8 billion','less than $30','$3 million','more than $27.95','the 28 dollars','$144 million','$20 million','millions of dollars','$123 000','over $1 billion','20-$73','500b.','$3 million dollars','a few million dollars','up to $12','3 million bucks','9 bucks','over $1000','less than $100','over $100 billion','$75 million','hundreds of billions','$104 billion','$3.5 billion','$-16 million','$274 million','300 dollars','more than $300 dollars','300 crocodiles','about $100','ten million dollars','4.5 billion years old','tens of millions of dollars','10$ a month','a million dollars','$3 million dollar','$1.65 billion dollars','almost 9 billion dollars','4.5 billions years ago','$15 million','only over $309n','3 million $','#274 million','$12 000','40 dollar','$33.3 million','about $89','over a billion dollars','more than $300','less than $10','182000','104 billion dollars','only $28','8.5 billion dollars','only 10 dollars','$','4 realms','1328009800','$200 million','10 million dollar','65 billion dollars','$53 million','123000 dollars','1 billion dollars','only $15.00','330 million dollars','million-dollar','15 dollars','up to $955','more than $40','10-$15','up to 8 pounds','about 4.5 billion years ago','a thousand dollars','1b','$1.65 billion','about two billion dollars','$2 billion dollars','two billion dollars','forty dollar','only 1.65 billion dollars','2b','roughly $300','3.15 million dollar','one trillion dollar','only $250','1000 dollars','multimillion dollar','hundreds or thousands of dollars','78$ million','$78 million','over $100k','7.5','around 65 billion dollars','375000','hundreds or even thousands of dollars','only $15','more than 300$','about $123000','over $85 billion dollars','over $85 billion','$40 million','$40 mil','only $130','#6','more than 80$','only one dollar','over $169 million','just $24 million','$500 000','at least 65 billion','7','500 bucks','$3 mil','$67 million','about $123','0','only $3 million','9 dollars','as low as $50 million','only 50 dollars','around $300','over $300','$1 million','over 1 billion','130 dollars','about $26','more than 1 billion dollars','8.5b','over $250','3 dollars','more than $53 million','20 per cent','$50','$25 million','2 billion dollar','nearly $15','0','$800 000','$32 million','4.5 billion year','more than 1 billion','more than $1 billion','us$1.65 billion','about $120','0','more than $25 million','$130 dollars','$15 000','$100 billion','200000-300','000 years','1.65$ billion','$90 million','$120 bucks','$90 million dollars','6 million dollars','$100','$6 million','$90 milion','about 4 billion miles','more than $2 billionn','more than $2 billion','multi billion dollar','over $585 million dollars','75m.','an estimated $65 billion','up to $300','a few hundred bucks','700','0','late $40','$20 millions','$5o million','10 of millions','six pence','$1 billion dollars','only $1','$1','only a dollar','75 million dollars','$21 billion','$16.8 billion','over $270 million dollars','a little over $300','about $300','#2','1110 dollars','1 dollar','fifteen cents','8 million dollars','a few #1s','12000','$250 million','$7.5 thousand','over a million dollars','between $300 and $400','billion dollars','35k','only $50million','$80 billion','$50m','only $80 billion','40 bucks','#name?','a billion dollar','at least 2 trillion','60k','around $40 million','only $5000','800m','$32 millionn','21.9 billion dollars','14.99','over $2 billion dollars','2 dollars','only 1/billion','1.8b','just $75 million','over $863 million','$146 million','found$3 million dollars','only about $5k','$5 lol','104b','nearly 2 billion dollars','$22 million','4.1 billion years ago','over 65 billion dollars','an additional $500k','50 cent','9$','40$','8 million dollar','over $8 billion','$100 million','a penny','only $59','$100 - $','almost a million dollars','$8 million dollars','7','500 dollars','them billions of dollars','about 1000 dollars','about a billion dollars','$1 bn','over $67 million','like million dollar','one billion dollar','$12 million','12 million bucks','$8.62 billion','about $12 million','12 million dollars','$32 mil','a mere $100k','almost a billion dollar','a measly $100','0','$43 million dollars','100s of millions','over $2 billion','9 billion dollars','32 million dollars','$8 billion','only $27.95','100','000 dollars','about 100 billion dollars','three hundred dollars','1.65b','thousand $','about $28 dollars','about two billion year ago','about 700 millions years ago','only $125','270 million dollars','only $300','$75','000 dollars','almost $120','0','74m.','five dollars','less than 2 million','the billion dollar','another 2 billion dollars','40 dollars','at much as $300','only 3 dollars','just $27.95','67 million bucks','50 billion dollars','50m.','another $2 billion','around $30','$309 dollars','only 17$','70$!','17$','#1 and #2','104 billion dollar','$104 billions','$52 million','around 542 million years ago','$ 2 billion','$10 dollars','90 million dollar','$78 million dollar','$78 mil','$300 dollars','50 million dollars','1$','only 75 million dollars','about $28 lol','more than $104 billion dollars','$200 mil','1.8 billion dollar','more than billion and trillion','1123000','only $75','$1.8 billion','$104 billion dollar','only about $10','several hundred dollars','346827','5k','7500 dollars','the estimated 104 billion dollars','up to $15 million','$50 million dollars','at least two billion','14 million dollar','14 million dollars','a billion dollars lol','20/20 lol','$3','1.925b','288.08','more $$$','21 billion dollars','around 40 million bucks','as finding $3 million','a mere $9','4.1 billion years old','700','000 dollars','$700 000','$6 mil','between $100 and $120','125000','almost 13 millions','$ 78 million dollar','the billions of dollars','$10.1 million','27.97','74 billion dollar','more than $50','40 million dollar','$3.38 million dollar','$3.38 million','50$','800 000 $','$ 10 million','$ 90 million','$10 million dollars','over $100','75000000','only $80','100 billion dollars','less than thirty dollars','$50 mil','like 75 million dollars','4-$20','almost $3800','only $1.65 billion','200 million dollars','123','0','$100 000','about $100000','$16 million','$100','000 dollars','more than $50 million','up to $143 billion','millions more dollars','one billion dollars','about $12','0','about three hundred million dollars','between $25-$40','about $12','$90 million dollar','17.41','1b.','only $6','$126 million','as much a $200','$12 million dollars','100-120 dollar','between $100 to $200','12million','about 6 million dollars','up to $100','$55 million','more than $800','0','6million','seventy-five million dollars','250','000 dollar','about $30 bucks','4.543 billion years old','70000','$2.5 billion','almost 2.5 billion dollars','22 billion dollars','300-400 dollars','5 cents','more than $6m.','just $7','500','20 dollars','like billions and billions of dollars','between $100 - $120','more than $104 billions','$300 million','over $40','3.91 billion','about $40 million','only $4','less than 20 bucks','$50 to $200','only recieved $9','more than $104 billion','16 bucks','over $50','104','over $2b','just $1','just $8','104 billion lol','$80 million dollar','$10 mil','more than $1000','around $15','300 bucks','$28 dollars','only $25','over $500','0','much us dollars','60-$400','$330 million dollars','up to $6000','over $8 million','$15 billion','up to #300','140000000','over 2 billion','$560 million','$264 millions','$352 million','$31 million','as much as $100','over $53 million','1.95','# million dollars','120000','more than $700','0','two billion lol','up to $74 billion','like $300','2.2 millions','$104 billion dollars','$40 bucks','a few billion dollar','10 thousand dollars','10m youtube','only 50 million dollars','28 dollars','one 1 billion','the billion $ nfl','about 1.39 million km','$ 700 thousand','$15 million dollar','nine dollars','$19 million','less than','over 104 billion dollars','.99 cent','over 1 trillion dollars','only like $300','about 10 million dollars','about $1.7 billion','$36 million','20$ million','over $123000','over $1b','just 36 million dollars','$8.5 million','5 billion dollar','5 billion dollars','only 11 bucks','99 bucks','21.8 billion dollars','124000','around $35','over $200','$148 million','over $700','0','$300k','a mere $75 million','more than 99 cents','75 million dollar','only 2 billion','32 million dollar','more than $200','over 8.5 billion dollars','3000000','$2 million','20 million dollars','30 000 $','625','$1 bulliion dollars','an estimated one trillion dollars','only $75 mil','1.65 billion dollar','$140 million','$400 million','346287','40 or so dollars','just one million dollars','half a million dollars','67 million dollars','less than #30','us$65 billion','around $104','0','0','0','35 million dollars','three millions dollars','little less than $6000','over 6 million dollars','only $5','000 to $6','0','5000 to 6000 dollars','$200 million dollars','half a billion years','under $30','1400','over $182','0','182500','#1 or #2','around $170','130k','over $346k','like $50k','$1 trillion','more than 500k dollars','$75 million dollars','about 104 billion dollars','$40','some $15','over 200 dollars','nice deal $800','0','$32 million dollars','123','000 dollars','10-12 dollars','8100','over 500 million dollars','about #metoo','27 dollars','more than 420 million','8.5 million dollars','over 270 million dollars','2b.','less than $300','100-120 dollars','like 9 dollars','50-150 bucks','over three million dollars','about $300','0','$13 million dollar','a couple of billion','fifty million dollars','more than $300.00','some 650 million years ago','800','000 dollars','32','0','000 dollars','$ 12 million','800','0','$12 mil','nearly $12 million','about $28','27 bucks','three milllion dollars','300$','one dollar','hundreds of dollars','about $700000','as much as $300','700 grand','$2.4 million','500','000 dollars','over $700k','more than 4.5 billion','only $25 million','billion-dollar','only like $16','close to $100','tens of thousands of dollars','$1.1k','$330 million donor dollars','200','0','about $20','0','$800k','less than 200 bucks','around 30 bucks','$150 billion','less than $20','three millon dollars','more than three hundred dollars','$32 million dollar','about $5 to $10','$27.9 million','almost $9 billion','6million dollars','$90 mil dollar','$100 to $200','$9 dollars','more than $1b','104 billions','75million','104billion','$75 mil','several billion lol','$100 to $120','more than $100','100-$200','less than 25 cents','10 million bucks','$90 mil','$800 000 million','#1 lebron','six million dollars','100-$120','$153.3 million','over $100 bucks','as high as $100-$120','6 mil','between $100','17.14','90000000','between $100 to $120','800 grand','only $10 million','about $8','0','$65 million','1 billion us dollars','346k','$10m','three million dollar','million dollars','99 cent','$28 million','700','000 bucks','$700000 dollars','roughly $820','0','0','346 grand','almost $30','0','more than $100','0','almost 400000 dollars','over 8 billion dollars','a literal dollar','one million dollars','only $75 million','123 000 dollars','almost $300','$2 billion dollar','multi-billion dollar','about $350','$35 million','250 bucks','around 50 dollars','$177.2 million','1.9 million dollars','$6.2 million','a pretty penny','0.01','15 + million','close to $1 million','10 to 15 billion dollars','130','000 dollars','1 million dollars','#3','seven hundred thousand dollars','$$$$','20 min','about $700','0','around $123k','5 dollars','$1.2 mil','over $300k','20','000 dollars','ten million dollar','$800 k','3.1 billion dollars','over $700','one hundred dollars','$150 million','$155 million','over $100 million','1.4','roughly $820','0','000.more','a billions of years','over 400 billion','1.2 mil','75 millon dollars','1bi','$15.1 million','$1.65 million','a few hundred dollars','2.7 million dollars','just $','50 cents','just $50','$23 million dollars','between $100-120','6 milllion dollars','up to $120','10million dollar','90 million dollars','$800 grand','100 grand','around 4.1 billion years ago','over 3 million bucks','104 billion $','$ 75 million','a thousand bucks','one uses four million gallons','$60 million','0 dollars','zero dollars','over 100 billion dollars','well over 100 billion','about $104b','the hundreds of billion','less than $28','329','hundreds or even thousands','$40 billion','40 billion dollars','only up to $70','0','420','19 yr','15 billion dollars','60 million dollars','$60 million dollars','like $50','0','$100 million dollars','close to $','hundreds of thousands of gallons','almost $10','another 2 billion','330b','every penny','60$','up to billion dollars','about $70','$4 million','230','about $1600','$4210 dollars','34 per cent','money - $700','0','sixty seven million dollars','1.3b','777','71.3 billion dollars','$52.4 billion','up to $112.13','a mere $75 mil','under $10','multibillion dollar','140 million dollars','$75 millions','over $10 billion','$7 million','a posthumous #1','$1.12 billion','more than $10 billion','more than 1.25 billion','around 104 billion dollars','more than $400','250 million ppl','$665 billion','$587 billion','more than $20','60$ million','1k','2.74','$8.5 billion dollars','$4 billion','$180 million','$10-20 billion','13 million dollars','$10-15 billion','about 3 million dollars','almost $800','0','over 300 bucks','820','40=$98','$6','$340 million','1.5 billion dollars','just $50 million','$04 billion','a few thousand dollars','two cents','1 billions dollars','between $300 to $400','300','000 euro world cup','1billion dollars','over 2 million dollars','8.62 billion dollar','about 700','000 dollars','almost $700','0','$75m','earlier $300','over $14','0','about $500 billion','$85 million','just $75mil','around $100b','an estimated 26.29 billion','$74 million','$60-something million','200 or 300 million','about $700.000','over $1b.','6 m dollars','between $100-120?','$15 dollar','15 dollar','$11 freaking dollars','only 1 billion lol','like 300 dollars','12 dollars','1.1t.','#4','100m.','about $60 million','over $300','0','those billions of dollars','more than $1','$1k','like 1 billion dollars','$200 billion','a few dollars','1.8 billion dollars','billions and billions','all $3','almost $1700','30+ million dollar','less than 30 dollars','about $1500','only $600','under 2 billion dollars','youtube 1.65 billion dolllars','$12 to $14 bucks','almost $60 to $70','only $72 million','at least $300','more than 8 billion dollars','almost $200 million','just one dollar','about $800','0','us$ ...','a fair few dollars','just $12','about $32','more than $2 billions','$10 bucks','around 5$','over $100','0','up to $50','0','32.000.000','just $800','0','approximately $1 billion','$70 million','10s of millions of dollars','189000','39000','$450 billion','40$ canadian music','$134 million','$2.35 billion','$50 000','around $700','0','55$','22000','400','000 dollars','about $50','0','$50','000 thousand','#name?','$84 million','#name?','almost over $275 million','$440 million','about $20 billion','almost $800 million','about $15 trillion dollars','more than $2.3 trillion','about the $3 million','over $6','almost $0.5 billion','827 dollars','400m.','$3.2 million','less than $30.00','about $2 billion','at least $50','3 millions dollars','3million dollars','13','000 bucks','over 104 billion','$75k','60 million dollar'],
'NORP':['european','han','amphibians','silurian','scottish','guardians','german','hans','han solo','martins','british','kardashian','korean','american','republican','indian','democrat','republicans','asian','hans christian','turks','russians','democrats','superman','eurasian','martian','christian','athiests','italian','chinese american','horror','canadians','canadian','african-american','clint','portuguese','west african','swedish','australian','germans','soo','african','linkin','ramones','foxnews','japanese american','native americans','soviets','tetris','indians','polish','marine','gaines','europeans','avengers','south korean','geese','hawaiian','chinese','victorian','sumerian','chinese-american','dalmatian','norwegian','thai','vietnamese','majid','orphans','yankee','marquee','dems','cheifs','us marines','highlanders','dodger','saints','koreans','dutch','sikhs','mexican','veterinarian','falcons','iffy','israeli','prequel','arab','pakistani','republlican','marines','stradivarius','batmans','costa rican','panamerican','african american','slo-mo','brits','irish','schindlers','jews','shift','texans','democratic','becauserepublicans','dem','republicans democrats','eastern european','new orlans','swiss','argentinian','quintilian','south koreans','hawaiians','north korean','britains','aquariums','czech','mosrite','grecians','western asian','shakespearian','ethiopian','curtis','turkish','the native americans','broccoli','politics','norwegians','ohanian','soviet','florence','morty','jordans','slovakian','bulgarian','icelanders','physics','thatd','enders','pocahontas','romans','aladdins','celtic','conservatives','mans','egyptians','mythbusters','asians','asian-americans','malawian','liberian','brazilian','christians','heinlein','spiderman','persians','persian','spidermans','european american','trashumanists','smallfoot','idiot','ziplac','cubic','batgirl','armenian','bruins','british english','new yorkers','miguel','marxist','cyanobacteria','celine','scarface','muslim','egyptian','diverese','north american','african americans','sharks','all-american','poiticians','alabamans','avian','stellar','pseudo-french','appalachian','babylonians','nubians','iranians','n. korean','africans','communist','alaadin','poles','spurs','mist','exorcist','blockbusters','amish','orangutans','clippers','denzel','muslims','leary','denisovans','reptilian','silurians','neanderthal','heavens','australians','britian','shakespearean','cambrian','jellyfish','sixers','thor','greens','nanette','lynch','polynesian','californian','okron','jewish','egot','shards','dorian','austrian','stefani','titans','baristas','-4.9','darwinism','north americans','malaysian','nests','ethopian','south african','hispanic','crew','kadatian','japans','darwinian','e.','haiku','facebooks','neptunian','siberian','athenians','hughie','african americans','valentines','vegans','ryan','catholics','jeans','hoarder','somalians','bartman','somali','somalian','somalis','dominican','celtics','instabul','nigerian','comedians','frenchman','polititians','pelicans','assange','psychologists','cavs','pacers','african-americans','lambs','poiesis','finnish','alanis','indonesian','pacman','packman','floridians','caribean','jean','central african','hungarian','pan american','easiet','great american','sealab','pakistanian','virginian','athenian','vegeterian','new republican','beerlympics','tahitian','audioslave','japanese americans','phillippines','african american alabamians','south africans','norweigans','locki','talentd','ironman','loki','antoine','wailers','alaskan','transhumans','neptunians','davish','kaboom','basque','catch','african american communities','mongolian','ecuadorian','mian','chiefs','darnold','villian','nazi','mannings','r.','cloverfield','phones','mexicans','austrialian','isis','buddhist','kuinka','swans','sean','brit','album','inter-korean','belichik','puerto rican','shakesphearean','synetic','shakesperean','strat','italians','napster','anti-muslim','instas','loyal','portman','areans','candian','australian-american','know','nihil','syrian','nuntini','cassidy','dslr','catholic','twins','chester','amercian','anti-democrat','cali','south asian','excite','prodigy','finns','transhumaninist','tourists','engine','kristian','the south africans','sr','bigfoot','jamanese','marreese','baby','serbian','wimbledon','tigers','martians','norweigian','renegade','freudian','franch','swede','physicans','tatum','scandinavian','north koreans','brazilians','sherlock','youtubers','measles','sentinel','zoot','google','saudis','qatari','w/saudi','blowfish','androids','ash','comedian','ryans','seafood','ottomans','phish','celebrity','southern','candidates','strategist','pro-russian','pro-american','independents','non-republican','jupiterian','jovian','galilean','income americans','centrist','zebras','norvegian','spartans','nazis','marlins','miracle','middle americans','oceans','aliens sans frontiers','obese','artists','stonemans','african - american','non-democratic','torrys','biden','sebastian','australasian','yeras','protestants','jamaican','saudi','uighurs','alexandrian','fred','arabian','non-catholic','freedive','luddite','south-african','denis','quidditch','brazillian','2 african americans','latin american','indoesian','ukranian','black americans','libertarian','mormons','black democratic','oak','appaloosa','hardy','anti-democratic','lol republican','socialist','northeastern','repubicans','zimbabwean','tunnel','vulcan','white','daft','target','non-christian','southern democrats','new zealanders','ethiopan','hindu','daniel','womans','internets','pan-american','clampets','nationalist','phillipines','finnish latin','aboriginal australians','the north koreans','some new yorkers','central american','non-democrat','barkan','venezuelan','indonesians','finish','santas','answer','foxxhole','kareems','south american','n. american','southpark','android','thaats','judeo-christian','drammatic','simpons','eastern','northwestern','anti-jewish','d.','new or saints','famine','slight','floridian','aikman','non-iranian','iranian','green-ellis','ap','austrailian','africa-americans','kellan','todays american','nutritarian','heisman','afican-american','imagine','nyc chinese','pro-chinese','philippine','peruvian','alex','eisenhower republicans','new channels','sebatian','palestinians','israelis','austailian','beats american','ol american','wealthist','democratic socialists','rush','alannis','wikileak','feds','slovakians','slovak','colombian','chineese','thezonians','quarterback','hecan','elijah','hawkeye','kennedys'],
'ORDINAL':['second','fifth','3rd','19th','95th','5th','8th','fourth','20s','eighth','40th','firstly','80th','11th','46th','3pt','nineteenth','16th','6th','90th','53rd','thirteenth','50th','seventh','sixth','12th','ninth','4ev','100th','15th','7th','21st','69th','27th','60th','23rd','secondary','10th','30th','44th','55th','24th','93rd','45th','33rd','17yo','9th'],
'ORG':['umbrella','os','olivia','miranda','congress','detective comics','michigan state university','that','ot','hyena','it','hamsters','harrison fords','chewie','snl','the reptar wagon','black country communion','the house of commons','knights','k.o.w.','senate','house of cards','darth vader','fox','blade runner','sci-fi','espn','espnu','ncaa','hc','walt disney','ana gloria henrequez','cindy','minnie mouses','hahahaah','walt disney animated studios','walt disney pictures','the mouse house','fanfest','the chicago cubs','us olympic','cathode ray tube amusement devices','apple','icelandic','the washington post','amazon.com','nice','abc','usps','clint eastwood','shark','vp','the republican party','the republican party of old','govt','grand','us presidential','wonder','the united nations','the silence of the lambs','the sacramento library','shakespear','the batman begins st','warner','lol','rotten tomatoes','the air jordan','lincoln','vesta','abc family','ballet','disney soundtracks','wb','rt','jej','aa','guinness world record','shame','treasure','vader','fight club','the us government','fifa','obscene','ged','eminiem','dres death row','hendrix','freddie mercury','hypocrites','pinafore','phd','pink floyd','cornell university','bbc','freddie','eurovision','pink floyds','calico','starship troopers','darth vaders','olympic gold','nike','mcdonalds','big mac','the walt disney company','disney land & world','pride month','avatar','tupac shakurs','mac','mickey','awww','pixar','obi-two','snes','darth vadar','titanic','nasa','the red sox','playstation','sony','the cincinnati reds','the department of defense','gta','imagine a major league baseball','collateral','moviepass','crazy','reed','ellen','fox news','ign','reputation','social','deep purple','creed','falcon','cnn','fox & friends','msnbc','3rd party','the nixons and bushs','lsd','the whig party','tyler','demos','taylor','gop','seneca','wiki','fda','jeopardy','the goon squad','rip curl','liked','aww','harvard','scientist','helpful associates','hbo','nope','the supreme acchievement','fraser','friends','kung fu hustle','seinfeld',' friends','wii sports','nhs','ptsd','cubs','the houston astros','baseball','yours','the boston red sox','fangraphs','camden yard','nyt','sox','the la dodgers','the ny giants','mlb','a','the sf giants','nba','soccer-baseball','red sox','the canada flag','chicago cubs','the new york times','ymca','abu dhabi','nhl','drake university','hotline bling','best rap/sung performance','pbs','this old house','twin cities of st. paul','marvel comics','oxford','un','education','tchalla','nsibdi','the black panther party','merril lynch','justice league','bumblebee','transformers','michigan state u','digital imax cameras','benedict cumberbatch','duke university','hmo','the supreme achivement','hugin and munin','avengers age','ultron','k-pop','renaissance','billy mays','h.o.t.','backstreet boys','digital underground','christoper','cupcake','apollo','baby driver','vhs','persian cavalry','pet semaraty','cribs','mtv','nwa','professional ballet','khaki','backwards?n','cs lewis','lysol','cruella','cotton','fann','dream theaters','tesla',' spacex','neuralink','the boring company','solarcity','clint easthood','naacp','hertz','maxwell','harpers','uranus','the space force','bbq','semaq beri','fed','mcgann','imdb','us postal service','amazonbasics','yankees','the atlanta braves','the major league baseball','the chicago cubs baseball team','nl','marine corps','the toronto blue jays','hai','phillies','the white sox','that','hosmer','philadelphia phillies','the washington nationals','citizens bank park','the national leagues','the new york metscy young','odubel herreras','odubel herrera','american league','national league','diamondbacks','walker buehler','the dodgers/reds','the target bullseyes','dodge','brooklyn dodgers','atlanta braves','the womens','giants','united state national sports','braves','cubbies','ws','chipper jones','world serires','the little league world series','bum','mercury','billie bean','mccovey cove','sf giants','new orleans royals','lorde','national geogrpahic','national geographic','tolt','walt','gotcha','royal by lorde','royals','soccer baseball','american sports','good','ks','the ford theater','ford theater','wiz','hawkings','pixas','als','toy story','u.k','brewers','mets','jets','shea','ichiro','cincinnati reds','the new york yankees','the marine corps','yankess','home runs','the baltimore orioles','the reds for chapman','the blue jays','orioles','woman','algorithm','rubenstein','hobbit','stanford','lockheed','freaked','quitfacebook','bk','lenovo','theorem for ai','theorem','ibm','freddy','sirius xm holdings','sonic','tx','pandora radio','the british museum','mohair','hawai','team bird','beastie boys song intergalatic','hahaha google','yahoo','ask.com','alexa','delta airlines','disney world','hiccups','next','kimodo','bad times','terry','paramount','medieval times','old disney','kippa','the national spelling bee','marlboro','california love','the dark crystal','time','disney channel','the disney channel','red ruffing','united nations','martin','arya','aliens','luna','nationals','major league','justin','the world series baseball','jb','national pastime','cub','the us marine corp','lannister','natl geo','ps','english league','mls','the slang for association football','billy mayssports','lol poor beibs','dod','intruders','ada','bell','lethal','ibrahimovich','doe','luke','sts-120','space force','la cabotte colline cotes-du-rhone blanc','smith-madrone','imax','wonder woman','marbury','ballet shoes per week','new york giants','jobs','nes','wwe','the guinness world records','dark towers','the santa clarita diet','hahaha nice','pilgrim','tycho brahe & johannes kepler','wwi','iceland air','blue','discipline','gravity','sci','the gallic wars','burger','kavanaugh','forbes','napoleon','cybertron','musk','guinness world records','netflx','the rebel alliance','house','rep','fantasy congress','cspan','hoover & charles curtis','fdr','book club','the book club','mortal kombat 2','the supreme achievement of','trojan wars','wi-fi','alien','the planetary society','toa','violin','the world chess federation','fbi','u.n.','wonder womans','society','texas a&m','poetry','the israeli defense forces','justice','dc entertainment','the israel defense forces','paramount pictures','dreamworks','netflick','defense','cgi','kleenex','association football','association','fifa world','youtubes','the the last knigh','k & k','paris hiltons','time magazines','kims','gaia','the empire strikes','the writers guild','cia','rna','collins','we are the champions','the boston tea party','sub pop records','the american accordionists association','neveda','state','mississippi center for justice','federal','alibaba','harvard & yale','artificial intelligence','artificial intelligence (ai','computer science','never','hangouts','standford university','googeplex','ai','bachman turner overdrive','rock music','ocr','fame','apec','cedar point','clever','jaws','britons','indiana jones','chicken','reo speedwagon','nyc','gen xers','dmb','national symphony orchestra','pink floid','boston dynamics','cbs','ebay','the us senate','the sargent of arms','whigs','rep & dems','craziness','the united states senate','house of representatives','independent or green party','the second party','iliad','supremo court','velcro','patagonia','christianity','alabamas','the house of representatives','hmmm','million dollar baby','stanley','lane lambert','artifical intelligence','lapd','abba','cbgbs','farmers','stephon marbury','ll bean','smart phone','white houses','kkk','grand old party','supreme court ruling','the democratic party','democratic-republican party','blue tube','ping','atp','federer','pelosi','democratic party','supreme court','nadal','priscilla','sergey','rene','tube','atps','nessie','przewalski','the visual effects society','marvel studios','the disney lion kings','lochness','rogue','mcconnell','want','fishy','two pm studios','candy','switched?roosevelt','the bull moose party','oh brother','coens','tron legacy','the nintendo switch','atrari','the federal reserve','the king mouse','royal torrence','gee club','billy mays','ite','fyi','rappers','spider','hummingbirds','dodo','tupac shakur','highways','onion','locheed','imperial','roman gods and goddesses','blue origin','vector','anki','kid','honda','android devices','intel','unfortunaley','rbmg','cozmo','dpk','perks','league of legends','futuresex/lovesounds','nipplegate','straight outta compton','airplay','spinal tap','guinness','mar','casio','the woods tour','mickey mouse club','saturn','toyota','nikola tesla','nicola','faulty towers','frodo','hogwarts','troll','enders game','enders game','navy','megaladon','ss','fantastice beasts','j.k rowling','radiohead johnny greenwood','pretty','caddyshack','century','us senate','nbc','ventures','nokie edwards','venture','nokie','fender','whitesnake','hydro power','memes','guitars','walmart hq','whole foods','transformer','djs','lincoln parks','bard','paris hilton','ohare','nbc sports','the supreme court','the university of kansass','banned','river curtis','morgan freeman','nintendo entertainment system','flying circus','american movies','charlies angels','save','oops','spykids','uc berkeley','professional reviewers','warner bros.','the seattle mariners','super smash brothers','nan','greed','mariners','mario brothers','star trek','love','star','swift','hot country songs','the us marine corps','tron','ender','snoop','predictim','burger kings','trumpster','thors','alphago','bk','orange juice','eminem/mgk','noclue','big macs','army','dartmouth','eod','lorax','sec','mcdonald','nickelodeon','winona ryder','verizon','netfilx','the duffer brothers','celebs','u2','george strait & jeff bezos','stratocaster','pineapple express','harvard law school','bulls','learned','university of kansasconsidering','knicks','university of kansas','naismith','kareem','nk','layla','academy','dath vaders','iverson','exoskeleton','reebok','mounted police','the u.s. olympic','air','peaky blinders','wolfram','theoretical physics','faction of fools','romeo & juliet','the faction of fools','wsc','shakesspeare','gallaudet university','friends for a golden globe','the best picture academy award','the penguins 2','panda','m c hammers','ac','mario party','comic con','blizzard entertainment btw','the rip curl','technology','theory','universe','cosmos','nicolaus copernicus','matrix','iswab','seinfeld and friends','wal-mart','shawshank','someone','friends',' seinfeld','the african penguins','rei','cricket','clint eastwoods','dc comics','lasagna + mondays','peanuts','cs lewismichigan state universitys','campy','dark knight','trinity','anne','sci-fi novels','stooges','vaudeville','lol stephon marbury','stephon','wolfenstein','apple computer','isp','funny microsoft','crazy rich asians','audio books','covert affairs','spielberg for et','goats','ms','radiolab','the nintendo entertainment system','gladstone','elevation','yea','laces','natural forests','the united nationsthe umbrella academy','sci-fi/fantasy','badly','world of warcraft','air jordans','the stephon marbury','the air jordans','akihito','paris hiltons','gif','gangnam','n','sci','she','radio shack','k-mart','sears','toys ryou tube','stuff','dark humor','marvel worldwide inc','fee','the toronto raptors','ferrari','the social network','capn crunchs','bestbuy','workers','led tv','megatron','nightmare','cnbc','rebook','judit polgar','baa','the university of kansas','hhahaha','orourke','fox-news','the division bell','loreena mckennit','the dark side of the moon','cd','national football league','the hated rack press','elephant','the hybrid theory','universal studios','the o brother','sacramento ca','mumford and sons','maniac','g&r','solid iron','eddie perfect','beetlejuice','cn','cat','animaniacs','houses','nra','the justice department','snakes','warner bros pictures','cobey','migo','eurasia','vikings','gluten','at&t','the united states postal service','amazons','ups','mafia','pop music','warner bros','pablo','coronel','greedy','kuiper','digital','ada lovelace','armstrong','news corp.','demitri','box office','silence of the lambs','chappie','silence of the lambs;','signal','hill','adam west','surfs','condiment king','riddler','joker','oy','charles entertainment','breyfogle','great entertainment','batman',' entertainment and comic books','kapow','the justice league','the condiment king','detectice comics','sasebo','freddie & ','simpson','pepsi','the old queer eye for the straight guy','pert dinklage','centrury','compton album','goldman sachs','science fiction and fantasy literature','starbucks','tseries','e.t','bugs','deadpool','usmc','msu','juggernaut','deadpool comic','super smash bros.','tolkein','bells','silent','blues-blackhawks','golden knights','keeps','fitbit','stoker','shelley','cornell','tatooine','hoth','ii','iii','og','water world','darth vaders','mama mia','sassy','wal mart','ihop','huge','the miami dolphins','usa usa usa','rings','turman','virginia senate','sci-fi epics','well','congress of cultural significance','the black and white pokemon','the marine corp','sirens of titan','hitchhiker','galaxy','google noogle','coke','ice','toys r us','neil','webn','the princesses of powerdvr','bieber','gg','yellowstone','yves saint laurent','saint laurent','saint laurent spring','aspca','pets mart','super troopers','torajan','berta kondoruras','eddie','astronomers','love pokemon','geez','runs','send','usn','vitamin c','macy','united','youtub','xmas','amazon film & tv','amazon toilet paper','id','cat woman','superheros','aol','alphabet corp.','isreal','gmo','songs','the imagine dragons','lgbtq','sting or shaggy','puck','winehouse','smart compose','the smart compose ai','przewalksi','creighton','evangeline lilly','seinfield & frasier','the kentucky bourbons','pom','persephone','hades','sasha','lilly','lily & ben','the united nation','kansas university','clevelands','ford','the fender stratocaster','marvel and dc','pet force','islanders','yea clippers','wnba','the canadian hockey team','gaa','rbg','phelphs','tame impala','the u.s. supreme court','iron fist','defenders','golden state warriors','university of kansass','suns','the oklahoma thunders','oklahoma thunders','oscars than dicaprio','the us supreme court','olympics canadas','atlas comics','walt disney company','national','bandy','vault 76 & red dead 2','the guiness books','burger king promotion','guess germans','the american dream','miami dolphins','jeep','good will hunting','toy','funky','mason-dixon','pythons','oscar wilde','u.s. customs','darth sidious','dark sidious','terminator','jedi','olivia wilde','the alvin ailey dance theater','calvin','find coltrane','alvin ailey','ailey','twyla tharps','the ny city ballet','lollapalooze','wowww','the parkland high school','kmart','hamlet','aux','usb','blues foundation','juliet','miller','the fabulous thunderbirds','best contemporary blues album','bing rewards','texas chainsaw','rocky horror','the academy award','ithaca','cinematography','bambie','pixar studios','google.com','nintendo entertainment','timex','zx spectrum','amiga','msc','idf','gmail.com','pocanhontas','the royal shakespeare company','shakespheare','frat house','discovery channel','black panthers','facebook and myspace','yt','american superhero','timely productions','red skull','boseman','bp','kalakauua of hawaii','graff','macbook','marvelous','access','awesome!there','marvel and dc comics','ms university','wildaid','eeeew','tumi','optimus','shark fin soup','nz','the revolutionary war-era','cujo','kinda nice','lohmiller','the washington redskins football team','redskins','washington nationals','honus wagner','iike','teh','kinda cool','octopus','kepler','cartoons','the argentine tango','violet parr','usa olympic','the washington wizards','vision','normalman','capital one','warriors','cavaliers','n.korean','soylent','hidden figures','kinda strange','ivanka','congressional','the societ unions','deomcratic party','straight','korn','sony/atv','fearless','iheart','the grand old party','wildest dreams','sony/atv music','project runway','carmelo','amazon prime video','pink floyds','the rollings stones','richards','smithsonian','kinda wanna','snoog dogg','tb','freddie murcury','baseball player','rap','evel knievel','bryant','tupac shakurs','pixar room?n','rappers','soundcloud','onfroy','ugh','still','softball','major league baseball','boiling points','def jam','the toronto international film festival','first man','poker face','alejandro','mad men','hollow','neandertal','denisovan and neanderthals','neanderthals','u tube','white magazine','ivey league','whooper','co','fro','dippin dots','enders','science','kp','now google','hollywood studios','bmf','contra','white star','hybrid theory','apple computers','activision','facilities','kobe bryant','their supreme court','kobe bryants','oscar','kansas university lol ironic','salt','universal pictures','divorce','spidey','busan','blade','avengers infinity','app','the lochness monster','tnt','the tennis channel','the university of kansaswake forest','the dallas mavericks','sport?n','bts','crazy little','graceland','dj fontanas','the three stooges','detective comics comics','boy band bts','korean rappers','great whites','nba finals mvp','lakers','unwilling','facebook',' twitter','blizzard entertainment','lonely heart club','office','nintendo nes','times up legal defense fund','jukebox collective','the seattle supersonics','detlef schrempf','scotty pippen','knievel','kaynes','vadar','dune','kk','lsu','davidson college','warner brothers','the disney studios','mowgli','independent media','minneola','haha its','amazing','mnm','the rocky horror picture show','lipizzaner','siale angilau','even','us marshal','the tongan crips','amazon rain','what','rap artist','youngsters','the harry potter books','jk rolling','jk rowling','sirius blacks','potterhead','ravi','bebop','inward bound mindfulness education','moonwalk','kids yoga','the divine comedy','the rhinoceros party','joke party','coltrane','miles davis & john coltrane','gospel','aretha','the harlem womans','guitar center','us censorship','quantum','the michigan state university','the dark side','golden state and','durant','currys','itg','kerr','rockts','mvp','shoot allen iverson','air jordan 1s','golden state warriors?n','gsw','phoenix suns','the santa cruz warrior','the houston rockets','trevor ariza & pj tucker','the nba finals','steph currys','the santa cruz','nbl','davidson','the nba the basketball association of america','wardell','powerpoint','nba title &','brawn','houston rockets','the national basketball association','underarmor','curry','national basketball association','usa basketball','kyrie','vt','the cleveland cavaliers','the santa cruz warriors','the mother of dragons','cur','cool jazz','the jazz trumpeters','fox news corporation','fox news network','fox newsfox news corp','unicef','gayo','k pop','seo taiki','icbm','google home','kepler telescope','sun','nooglers','the capital fringe festival','msn','mph','amazon hq','oxford university','chadwick','oscar wildes','wilde','bender','jeep grand cherokee','chrysler','grand lol','cadillac','horror films','npr science fridays','grandmas house','sont/atv','union market','poker','american horror story','chicago & northwestern','mtv boiling points','hobbycraft','the fall of blockbuster','smart','mac','black and white','the black album','lemonade','the fox channel','alexandria ocasio-cortez','aoc','repubs','ocasio-cortez','news corporation','ge','told','wapner','this disney broadcasting network','disney productions','the department of justice','department','ami','the artechouse museum','the hirshorn museum','nicki minaj','jenner','nikki','apple music','kylie / travis scott','spotify','nicki','way','clint eastowood','american ganster','fallen','the wall and dark side','key','rage against the machine','godzilla','ratm','captain marvel','firestorm','cw','arrow / flash','gofundme','supermario','un habitat','spaceship troopers','hahhaha','cbgbs','pity','combined','spotify','it','husky','vans','old navy','perreloco','humboldt broncos','western canada','offset','the international astronomical union','au','oort','the university of marylands observatory','ludmilla kolokolova','northern canada','bezosthe national league','the royal canadian mounted police','the pacific league','the premier league','epl','the tennis association','tupac','yaaaaaaa','high school','martial','ihave','hsers','classical music','rip tupac','acl','npr','hawkgirl','oscar','the macabre and supernatural','merrill lynch','peele','small pox','iss','netflicks','roma','echo devices','bundy','the cabinet office','bronze','infowars','justin biebers baby','burger king whopper','facebook hq','reserve board','the fed reserve bank','orange','3rd rocks','dui','crunch berries','kale','waterloo labs','beibers','elon musck','ooooo','tesla motors','powerwall','bmw','queens university','the university of pennsylvania','the wharton school','the college of arts and sciences','tesla',' inc.','nikola','chevy','gerber','kind of blue','gibson','concerts','gubernatorial','the rolling stones','hobbits','jrr tolkeins','boston red sox','notorious b.i.g','roi','uraunus','teh supreme court','wolfram alpha','nietzsche','mcdonalds drive thru','taco bell','the new england patriots','cleveland cavs','the warriors','western pa','imbd','baby metal','the florida panthers','rapper busta rhymes','gpa','peak oil','peter thiel','snoop dogg','cinnamon','the natural history museum','newport','princess jasmine','the green lanterns','charles entertainment cheese','facebook and google','fdic','andriod','dos','radio shack tr-80','the .53%','cinematographer','repitition','lifters','the rings','karma','mit','advance publications','captcha','ada lovelaces','the eve-online company','obl','dayton','welp','jgl','the warner bros','askew','full','tcp/ip','tos','tupac & biggie','king of hawaii','highway','billboards','drake visited drake university lol','young money entertainment','paper ghosts','customs','waldo','the us billboards','parkland high school','the macarthur foundation','wapo','the michigan gop','thiere','morgan','the voice of darth vader','nah','the hall of fame','al-qaeda','hedgehog','blue labs','nasdaq','the mn twins','anything','matsuzaka','d-wade','country music','the catoctin creek distilling','the prohibition party','museum of american history','ernie','ctw','lgbtqia','the round house','charcoalblue','steppenwolf theater','steppenwolf','the box office','tyler perrys','us nuclear','wilson','castaway','ball','beastie boys',' notorious big','the lion','american grafitti','coachella','floyd','dmx','hate','tng','the cubs mariners','wpm','the fantasy congress','taylow swift','the reputation tour','swit','n.w.a.','nissan','a new yorker','garth','rapper','the d.c. united','natural history','the coffee bar','hhaha','mccovey','ella fitzgerald','jazz music','canandian','league','coco schumann','canadian itunes','notorious b.i.g.','young mc','rappers delight','news','paypay','ntozake shange','the make a wish foundation','the baltimore school of the arts','rhythm','the marine corp color guard','the walt disney family','amc','keyword','ms doc','emmys','the burbank ca ikea','snow white','fargo','robins','the brimingham childrens hospital','gold digger','watchmojo','rapper big sean','warner bros. probably not academy','antoine de la mothe','honeywell','new zealandâ´s','cal ripken jr.s','temple of doom','timberwolves','lol monopoly','capitalism','rip','the olsen twins','full house','mccarthys','life of the party','the happytime murders','allied','fawlty towers','gangster','iconix','nicki minajs','rapper bust rhymes','aws','p.t. barnum','blm','ww ii','repuplican','ours','wild','damnnnnn','revenge of the fallen','green berets','detroit antoine de la','extreme lean','price','crocodrile','green eggs & ham','children','eragon','ny times','leavign neverland','the the brief wondrous life of oscar wao','the sacramento public library','the new york times childrens','audi','anne jones','the the supreme court','the supreme court house','mercedez-benz','mercedes-benz','n.b.a.','grizz','the la lakers','the basketball association of america','nba tv','the nba hall of fame','waterphone','yo u','lotsa','the cleveland cavs','ving rhames','isthe terminator','a drake university','ball and kuzma','wv','washington wizards','ucla','big bang theory','criminal minds','dvr cable tv','netflix','erin','evh','cadilac','mlk','coming to america','ddl','the american international group','amazon ownd imdb','fuller house','cern','the starship troopers','times','mines','fruit of the loom','the office','video games','vpn','virtual private network','stevie wonder','the us govt','burger kind','ppl','fox corp.','friends',' frasier','fox news channel','murdoch','hindsight','libraries','circuss','bailey','romcoms','ur','drake visited drake university','books through bars','aclu','la lakers','understand google','youtube tv','www','shoes','the darkside of the moon','the beatles white album','hughes','mtspace','brain may','the hamptons five','iguodola','durant and green','the air jordans','oracle arena','hamburger','steph curry','5th higest','sam & cat','florida panthers','sam &','the manchester bombing','irving','bogut','isreal and palastine','gen z','radio disney','tegan','hangover',' harold & kumar','g5','air travel','the rock',' connery',' hathaway','kuman',' hangover','the modern age','walt disney studios','burbank ca','the hidden mickeys','fake news','productions','bing.com','the end times','ac/dc','aka','lexus','hyundai','kia','elon musks','tagaryen','tyrion lannister and arya stark','got','portia','dv','facbook','cristeau','ultra','cubs 2016 world series','the brooklyn robins','cadillacs','utorrent','ip','edison','the howard theater','siriusxm','the national postal museum','nike iverson','kc','undefeated','the gs warriors','gortat','brooks','usab','the international basketball federation','lebrons high school','al qaeda','kimmel','gps','wtf','ocsar','palace','the boston celtics','kennedy centers','guess the center','league the national basketball league','mis-using membership','air jordans','ishtar','burger king facebook','orlando magic','neopets','haaaaa','celebrities','u','','chemistry','hahaha yup','saadat shahr','shakespeare','cartelli','the university of virginia','anyways','alejandro',' romance','steaks','the reelz channel','lovers','met office','oasis','blue jeans','the washington general','leone','gmc','mercedes','wrangler','kelly towles','mario bros.','aorry','cable tvs','ape/humans','var','premier league','nintendo systems','mma','mixed martial arts','sk','their stadium','the new england revolution of major soccer league','rage against he machine','bon voyage','hmu','ohio state university','syn-propanethial-s-oxide','gm','anya','benjamins','speeding','af am','cherimoya','kiddie','mn zoo','the world records','humans','the english league','everynight','nordic','guiness world records','lucas films','darth vadars','the freer gallery of art','the cherry blossoms','the cherry blossoms','nuggets','alphabet inc.','stanford university','sitcoms','burger kings promotion','the air force','wilileaks','nye','oneal','take paris hilton','i loved deadpool','the casper sleep shop','laurie','dance?4','i[phone','student leadership center','the washington generals','carter-vickers','swansea','warms','the world logistics','starship troops','the national museum of natural history','imagination stage',' adventure theater','ipic theatre','ipic','california adventure','harley davidson','space invaders','disney pictures','the national building museum','starbuck','slj','zombieland','kfh','incredibles 2s','graphics','disney studios','bird direct','step brothers','bm','the national portrait gallery','frasier',' friends','the adventure theater','the natl building museum','the natl portrait museum','smithsonian museum','the spy museum','r.o.b.','the museum of natural history','considering nitendo','black & white','julius','point break','friend','the imagination stage','comedy morgue','westminster abbey','c. centrals','non','the national portrait museum','the winters tale','the natural meseum','the supreme achievement','neflix and chill','underminers','kf hustle','capitol someday','super nintendo','gamecube','favs','a nintendo switch','the time.nthe nintendo entertainment system','frazier','reynold','elon musks','megaman','nation','national building museum','winters tale','royal courts','imagination stage','the national meseum of natural history','the iron giant','noce','the natural museum of history','museum','the natural history meseum','school of rock','jack black','canis','supposedly','microwave','voyagers','dassault falcon 900','blogger','olaf','the state senate','world chess','comcast','iron','hopkins','the justice league though','a league of their own','hahahaha','sleepless','mmm','freddie mercurys','guiness','nag','suess','tlc','ccr','capitan','klan','justin bieber','whopper facebook','durant.lol','packer','amazon studios','india & pakistan','irs','puffy','jupiter radio','the tea party','the farmer-labor party','the nonpartisan league','tea party','turner & hooch','splash','cristofoir','schroeder','holy','detroit - antoine de la','rip chester bennington','haha fair','n. korea &','brick & mortar','amazon & netflix','prob','live aid','legal','captain underpants','amazing - necessity','the white house btw','bushs','the white hose','cabana','state of union','friends on netflix','louisiana state troopers','bear','texas rangers','taiyana aaliyah thompson','knkow','the mortar board','ozarks','cle','their customer service','specialized','timmy','constituents','pakistan jazz','polyphonic improvisation','reptar wagon','busta ryhmes','megadeath','russel brand','the disney brothers','american idol','idol','am/fm radio air time','cha-cha','bop','hostel','hellmanns','the movie the hobbit','the academy of contemporary music','monster energy','a.i.','jrr tolkein','baxter','trustbusters','ali baba group','the country hall of fame','amy','talk','norvergian','everyone','anaheim ducks','the anaheim angels','docile coyote','the university of illinois','jabari','antman','accordint','lokheed','bond','easier','scuba','hominid','pluton','founder','wharf st sw','phobos','the world tiger summit','band','disconnected kids','sensory processing','olympics canada','harold & kumar','grosse point blank','the elon musk tunnel','native icelanders','party','friends and seinfeld','air travel times','killer gnomes','cp','scooby do','home ecj fink','horror movies','kasparov','friends and seinfeild','lollapuzzoola','crosswords la','amtrak','constant','alphabet',' inc.','fire & blood','blue jays','the jordan 1','uyes','cuter','texas holdem','death star','drink','the supreme courts house','sassy hats','the disney brothers cartoon studio','warnermedia','cheerio','the american academy of pediatrics','forest','flatulence','blue-ray discs','spoken/sung texts','knighted','youngblood','sacramento library','sr.','atxaga','studio ghibli','navy-marine corps stadium','gallons','heard clint eastwood','sued','mlg','ufc','hill house','sci-fi/anthology','the super nintendo','obamas','the u.s. marine corp.','uncle tupelo','the country music hall of fame','fender stratocaster','niners','the capital gazzette','the capital','vandyken','minor','mezuit ozil','girls',' inc.','congress fantasy','the ny mets','brave new world','kings','world','koi','celebrties','the bavarian breakfast','recently disney land','disney land','the walt disney studios','american choppers','teh rock press','hubrid theory','biebers baby','plato','nathan','mgm','vespa','the european union','eu','the british army','departure.nn','tpeople','backups','theresa','caeser','chretien','bellatrix','uin','the standford university lab','the stanford university ai lab','the french explorer antoine de la','the postal service','k','teh dutch','intercity uber','julian assange','facebook a myspace','animalia','funky chicken lol','ripken','annie','postage','the bad girls club','abbey road studios','doger deakins','best cinematography','iraheta','generation paranoia','traffic','social media','bucks','thagt','cbs bbc vevo','gibi','scary movie','ru','rolling stone','grail','tab','td','recent news','the amazon postman','tvs','brandin cooks','the everything store','the national cherry blossom festival','weather.com','world','mturk','burger kingâ€™s','eastern canada','hobbes','app challenge','alibaba group','office max','samsung','peyton manning','fair','nyc/brooklyn','bosch','starship troopers or enders','patriiots','the solar systems','also','','kellykeegs','medha','buffalo bills','water energy','cs','the major leagues','coen brothersthe tea party movements','apocrypha','radio','rapper tupac shakurs','atticus finch','amys','submission','wonder womans','university for fantasy','pwi','the justice society','drice','napoleon dynamite','phds','pink','nown','christian contemporay','quatar','the secretaries general','ecommerce','stealing','finding nemo','msd high school','cheers','office.was','the smithsonian american history museum','guardian','super mario brothers','psp','ps vita','international cricket council','telephone','harrison','the national symphony orchestra','censorship','fed government','interestinig','hbu','orchestra','the norwegian government','zues','admission','vegabonds','u.s. navy memorial','goose','bethesda lane','tysons','vienna fans','the dc comics','filmstruck','warner media','entire','sgt','cpr','washington post','justin bieber songbaby','the hungary national football','the disney company','mad men right','american womens','roy disney','lyft','pan am','suite sixteen','theon greyjoy','disneyworld','the london symphony','walk disney pictures','topps','bermuda','stuart little','commonsensemedia.org','the office for the 1000th','feardotcom','pg13','enemy of the state','rfid','dorsey','ibook','stephen malkmus &','conan','9:30 club','comic','hahaha good','interesting','ascenseur','men','northrop frye','how','the best bar in america','parliamentary system','the u.s. house of reps','the indian government','fruit ninja','deliverance','eastwood','cbe','beatle','the baltimore school of arts','kareem jabbar','shaw','burbank ikea','sci-fi story','netflixast','ithought','giant','science fiction','university of kentucky','buzzfeed','milgram','ua','cury','fox new corp','nbc news','command','conquest','firefly','hoggle','ell','the opening ceremonies','modern family','kung fu','google pixel','wwf','lasagna','ringo star','trump/kim','the milwaukee brewers','o.a.r.','olympic athletes','the international olympic committee','duracell','goodgle','hard','hudson to perry','the office (us','threes company','kung-fu','yoriyas','zimmerman','busta rhymes & dmx','snoop doggs','rger dankins','the us department of defense','brothers','prolific','astronaut','dualstar entertainment group','the fuller house','rss','net neutrality','the federal government','oklahoma university','halo','hoya','the world of potter','gallipoli','sherlock holmes','borders','err','masters','seeems','hilda','realy','feel','the american league championship series','detroit antoine de la mthe cadillac','spartacus stanley','bing crosby','kubricks','fuzz','cinematographer roger deakins','the super nintendo entertainment system','neville flynnn','bale','shakepeare','dr. house','starlings','titus andronicus','the royal shakespeare co.','the time i get to phoenix','duchess','drama',' entertainment & news','primitive technology','pocahantas','amleth','mt. evesrts','titus','the waverly gallery','morgan fairchild','cheech','pan american maccabi games','aussie','charley pride','dream theater','looney tunes','mercedes benz','shelton','amy winehouse','the brit critics','maury','fleetwood mac','mcvies','pentagon','the highest court','the charlotte hornets','the national basketball league','nicks','crowded house','mc hammersstevie nicks','xmen','antonie de la','something','comedian patton oswalts','patton oswalt','basketball','the los angeles lakers','united states postal service','white tv','rhiannon navin','lucas studios','chewbaca','parrots','big sean','harvey','the us nuclear icbm deterrent','penn state','meg','icm','m&m','buick','frontier','pederson','oxygen','ncis','supernatural','tupac shakur and notorious','comic book men','panda researchers','hiddensee','the wooden rooster','murder club','kinda old','icbn','pandas','labyrinth','white sox','white sox/cubs','jim beam','shop','sebastian jenkins','le bron james','labron','mad tv','borstein','atmospheric','the microsoft theater','mustve','solar system','yesss','progressive party','bet myspace','team usa','mens','podium','grace','abbys','the office',' park and rec','showtime','a golden globe','lincoln continental','clara','goper','shark tank','the us postal service','amazon publishing','cognitive processes','militarys','us icbm','kingdom hearts 3','templestowe college','airbnbs','turner','national guard armory','post','aerosmith','idc','every single day.im','gallop','stormy daniels','stormy','apprentice','wealth','sprint','sag','ahh','intel extreme','mech','chocolat or cry baby','clay','right - mcdonalds','polyarc','quill','the us dept of defence used playstaion 3s','the ps vr','playstation home','psvr','abc news','democratic national committee','fnc','fox new','the simpsons','steves','ozzies','fcc','the big lebowski','neflix','n american','nthey','mountainview ca','the milk carton kids','exxon','google headquarters','all','client eastwood','kmfdm','reed hastings','diddy','fifth harmony','viacom','grand teton national park','mri','mazda','subaru','free mercury','who','world health organization','hated','dang','ive','doofy','chihuahua','middle school','iverson reebok','nanotech','senators','katherine applegate','applegate','the animal welfare institute','inter continental','washington ballet','the benz patent-motorwagen','the washington capitals','fox tv','cheech & chong','chonger','cancon','ethanol','reddit?n','song','come','u.s. nuclear deterrent','papal','julius casears','sherlock homes','ocd','drone','autobiography','bloomingdales boundary store','superbowl party','the lsu tigers','wolf trap farm','texas jacks','duncan','markkanen','bloomingdales','the meaning of life','holy grail','the grateful dead','edm','mama mia 2','lou reed &','vista','sci-fi pick','marine core end game','gigs','eff','iversons','shakespeares','liverpool','krupa patel bala','the fox news channel','burger king fb','the oklahoma sooners','p[layer','hubbard','aaf league','christ','entertainment','the higuest court','carnival','parliament','wings','ttyl','circus','holidays','good news','northamerican','blu-ray','us nuclear icbm deterrent','micky ds','hamlet in high school','clair danes','boss baby','horse','stargate','gamergate','london symphony orchestra','icbm deterrent','euros','charities','cinema','peta','am/fm','the baltimore museum of arts','creepy metallic','falme','the ohio school of broadcasting','vfw','king','soldiers','mercedes c','the wisconsin dells','eek','planes','icelandic air','mcu','the treehouse of horror xxi','taliban','luke cage and agents of s.h.i.e.l.d.','astronauts','plains','didier drogba','kinda sucks','jtt','hdmi','tracy ullmans','ott','matthews','us postal','guess','ms jones','hotels','the lobster','space balls','crazy blind date','percenters','macgyver','hall','the university of kansass history','the oklahoma city thunder','thunder','carmello','us supreme court','la clippers','oakland warriors','west side story','midsummer','hamnet','the new zealand basketball','cav','the supreme court supreme justice','rgb','wizard','hawks','porter','maranda','the supreme court building','nba draft','sa','mcdoanld','elegiac court','walt disneys','the oscars on radio','aerosmiths','lps','numerical','harvard law','supreme','marine corps color guard','ford motor company','foot bicycle train','nlcs','reds','pennywise','outsider','celeb','the pixar studio','hastings','the washington monument','ku','the harlem globe trotters','the globe trotters','tinder','ipo facebook','golden eye','rare','christian bale batman','aquamam','diseny','theron','fuller','paranormal','the national art gallery','court','usc','nba entertainment','diesel usa','wheaties','jk','the navajo generating station','national park system','walmart.com','the secret service','wendys','aretha franklins','bi','yale','big sur','us nuclear icbm','telecommunications','fantastic fours human torch','mmmbop','miami herald','homeric','oxford universitys','wakandian','anchorman','the university of north carolina','remi','neptune','ender','invasion of the body snatchers','lives of ancient thinkers','empire strikes back','heat','american rhythm','gs warriors','guilty','guiness world','radio relic','mixi','tofalli','the fighting cocks','craft','quavers','michelin','shadow','rpg','eagles mine','bradly beal','nba all','polly purebread','odie','the detective comics','stay','x-men','episodes','nuclear','atari version of pong','ihob','merc','parrot','ronaldo','c.s lewisthe l.a. times','southwest airlines','boeing','fg','the silent witness','the heurich house museums','nc tarheels','chuck e cheeses','the original nintendo entertainment system','gopro','best buys','jiffy super','aretha franklin','mddonaldsnoway','emmys','apple & the','forrester','ct','serice','the u.s postal service','bundy tapes','sugarland reuniting','cmt','the mandalay bay events center','disobedience','the red and blue association','chimps','victorian times','biggie','artists pictures','doc','target use','apple corp','best buy','quit facebook','drive.ai','cadillac coupe de ville','pokemon episodes','jupier','data','email','ford','macguyver','nankatsu','fredette','outback steakhouse','the long lions','monumental sports and entertainment','cba','umpires','rugby','yankee swap','the fb/burger king','infiniti','car','tablet','the ford company','za','american humor','danelle umstead','rock and country','the society of youth','the society of the old','paralympic','danielle umstead','indonesia doesnt','radio to lady','the mercedes-benz','mitsubishi','antoine de la','the family research council','connie gay','twisted metal','goverment','government','the u.s. government','hoosiers','stephen hawing','banana','the young republicans','the lakers','karem jabbar','us supreme courts','imaging','raccoon','the new york knicks &','cheryl','okc','bball','hambone','hahahahaaa','scotus','orleans','rutherford','cd & mp3s','straight outta campton','jump','cool','springsteen','bono','into','likley','litworld','scholastic','caddy shack','simpsosn','the simpsons treehouse of horror','oddessy2','zion','universitys','funny air jordans','ex-nba','srx','antoine de la month','dm','koko','starship tropers','the ragamala dance company','car','mccartney','dipg','intrinsic pontic glioma','ace venture','facebook or google','ftc','us divorce filings','exp','portal','phy','alpha token','fsu','champs','the l.a. lakers','the chinese basketball association','thet','physicist','marcus morris','aperson','reebook','laker','leonard','san antonion','magic','mpv','spacejam','nike air jordan','university or kansas','the wash. wizards','clevelanders','af','expensive','sear','great pacers','kansas jayhawks','the u.s. supreme court building','los angeles lakers','the supreme courts','boohoo','heats','basketball association of america','coaches','iverson reeboks','cfl','jordan',' iverson','walt disney world','scooby-doo','the l.a. angels','the isralei defense forces','police','deniro','lars keplers','marshal','the king of country','hof','the voice want','the voice','the movie starship troopers','uhm','cs lewis & tolkien','nadia comaneci','the philadelphia union','school house rock','shr','conjunction junction','lee jeans','king of america','jazz great ella fitzgerald','mcnugget','mcnuggets','goliath','f troop','redford','puzzle','walk disney','3072 oscars','savalas','the paris hilton','goolgle','nato','hahahah','the kids post book club','montebello','john burroughs high school','bruce','levinson','the marx brothers','winona ryders','finalnd','tc','formulaic','cocktail','national basketball league','popvich','rain man','jann','byolp','disco fest','biggie and tupac','ubers','thune','office space','sparky','vonnegut','jupitor','boyle','the ncaa division i tournament','the university of virginia womens','ngoty','villanova','the us supreme court building','marge','lizards','msd','literally','erinn','ikea hights','the nutty profressor','fox television group','flanders','hualapai nation','faa','nta','papillon','lawyers','hualapai','la dodger','guatemale','kareem jabbars','arike ogunbowale','the indiana pacers','ogunbowale','grubauer','the slovakian womens hockey','fernando','likw association','martin strings','the national security agency','hawke','radios?jupiter','the big mac','iron mountain string band','dillards &c','the world','burger kings','pixar animation studios','lamborghini','the los angeles times','the ford motor company','the benz patent','tyler the creator','cray','idont','artic','congress of cultural','caddy','the uk doesnt','waybackmachine','the boskin commission','the dvd rental service','9pm','cbs all access','waze google','hg','gah','division bell','evel','touch','artic monkeys','the simpsons',' homer','detective pikachu','originally tv','the new yorker','hulk hogan & andre','the ultimate warrior','epa','pence','energy','el tri','the hungary national football team','the ny yankees','rutgers university','manga','bbt','the michigan state u.','poo','lebron','winning oscars','garfield comics','the identical twins','bentley','air play','idol and survivor','c&w.','les pauls','the universal music group','marley','cassettes','the dark side of oz','lincoln center','waltz','keith urban','yup','cds','cma','kilmonger','forest whitaker','the wayback machine','the michigan state university library','excelsior','lte','asl','football league','crt','dungeons & dragons','bloomberg','sas','everything sucks','ti','horrible','nypd blue','banchco','hopper','netflilx','truth initiative','simply','havard','gwashington','creepy','ty :)','radio city music hall','the national symphony orchestras','fordham','green arrow','flash','the super bowel numerous times','pomp & circumstance','the national enquirer','musicians','darpa','the wall street journal','va senate','the tea party movement','truman committee','romonovs','brain?n','social network','detroid de la mothe','red-green colorblindness','bear it','raos','disney of bambi','rocky horror pictures','the rue morgue','the washington redskins','the kansas city chiefs','scotch','penn','teller','systems','genie','etrade','grand tourismo','lawyer.com','district court','make america groovy again','crafts michaels','cheeki','jerrys puffy','magnum pi','this magnum pi','mass media','the detroit pistons','mvp awards','the presidential election','lupus','burbank california ikea','fow news','fox nex','sean hannity','hannity','trump & hillary','church','armenias parliament','nikol pashinyan','hollywod','the progressive party','tories','breakfast club','fox spends','frankie & grace','fox news next','the u.s. senate','very potent','everclear','the pittsburgh steelers','eli manning','elisha','chargers','astronomerastronomers','the rock hall','russia &','knowledge','fergie','duke','avg annual','nba league','mwa','pgp','eggo','cya','standford','google search','swat','coup de ville','wolkowsky','the university of pa','the white houses','the gangster disciples','washington & jefferson','wash. & jeff','lbj','archer','sulaiman','amazon rain forest','the catholic church','yellow','lol its','zoolander','the san francisco giants','minor league baseball','television','the national league mvp','the american league (al','the american league','my mother the car','alcs','fantasy football','purple','hunger games','lipinski','the treehouse of horror','vc','the air and space museum','not chicago','trump university','kow','noi','layin gth ecables','fan fuel','the gameboy color','thwey','scarefit','aaa','tsa','rooney','schwinn','senate chambers','the boston bruins','komaneci','pokemons','pokeon','outlander','mysapce','crazy little thing','rca','heartbreak hotel','the arts program','the u.s. congress','the national endowment for the humanities','the lebron james family foundation','the looney tunes','the looney toons','junior guard','psy','neil de grasse tyson','jeter','the national college athletics association','winston churchills','billy bean','the us congress','issues','thoughts','postal service','the fantasy league','prohibition','jfkn','elmo','apparentl','the usa senate','the senate offices','the reebok nano','stephon marburys','pump','stephon murray','ck','vp hilliary','big es','smoke','tbs','seinfeld',' friends & frasier','country music hall of famers','schleswig- holstein','kelly ripa','ivy league school','billboard','blakes music','yep house','american football','professional bowlers','pro football','the university of iowa','diet','american beauty','ithe','channel','literature','relic radio','the burger king promotion','csi','texas instruments','the chicago bulls','patrica cronin','the florida panthers','charming charlies','dangerous woman','the national park service','national forest service','solar panels','secret service','aloe','affleck','phoenix air','the googleplex hq','kinda crazy','advanced aviation threat identification program','american airlines','ufo','the king of england','permanently','stephon malbury','races','kremlin','gillespie','jazz trumpeters','big mac lol','cambridge university press','the chicago symphony orchestra','the chicago symphony','enders shadow','fitzgerld','us congress','sci-fi comics','fredie','rolls-royce','bbc news','lower','rav4ev','the blue grass champs','episode','speaking of tv','the barrick gold corporation','the micheal brown','wesley bell','our white house','freddy mercury','south pars','sanders','jfky','gree-ellis','the university of iowas','kraft','safari casual','googleuniverse','djt','the national football league','buf','sidenote','lannisters','arrowhead','gillette','chiefs-patriots','osu','the belichick / brady','the pats the lannisters of','cowboys','packers','the cincinnati bengals','super bowls','afc championship playoff','the american offic','life time fitness','cable tv','a&e','the life time fitness','news corp','fox entertainment group','reagon','first eragon','expanse','rowling','r& b','meshell ndegeocello','kimjong un','man and space invaders','goldeneye','showbiz','cardinals','marcus mariota','football/basketball/baseball','cleveland stadium','afc','nfc','the no fun league','maduro','jefferson & jfk','strange','the united states chamber','psephology','cna','hhahah','medicare','pocket monsters','fox news probably','the same corp','the us supreme court bldg','spongebob squarepants tv','humboldt state university','laurel and hardy','niclelodeon','spongebob','mobb','blue heeler','spongbob squarepants','spongbob','martial arts','juice','reel','famicom','wreck-it_ralph','national sports','bowlers','u.s. olympic','summit','p.m.','doonbeg','the irish labour party','the national park system','the blair house','national forest','chaser','the voice of meg','trolls','the nintendo hq','better','great writing!nixon','fireplace','mysteries/thrillers','the fox news network','the travelers united','genocide','the mueller investigation','tombstone','the amazon rainrorest','geneva conventions','motor','spf','decon','vets','social security','crufts','the kennel club','simsons','burks','conroy','the georgia tech','rb benjarvus green-ellis','university of iowa','us department','daca supporters','payroll & benefits','foxdisney/pixar','devils curve','food network','appaer','imho','chato','wholy holy of youve got a friend','la baptist','holy crap','a baptist church','pollack','franklin','macdonalds','the emmy espn','patriots rb','the beloit fairies','hart','fox news surprising','keep','benz patent-motorwager','cox','netflix',' hulu','netflix dvd','considering netflix','fox news','fox broadcasting','fox entertainment','south park / family guy','nannette','trains','automobiles','simpsons',' homer','treehouse of horro','interview','the pineapple express','the cleveland indians','bs','lawyers vs judges or criminals','american history','scleswig-holstein','lol totally','the yellow pages','they','ga tech','arena football','the philadelphia eagles','auburn','the georgia tech-cumberland','the philly eagles','xxx','purple rain','collisiono','n.w.a','platinum status','the sugar hill gang','raptors','ps controllers','notoriety','looney toons','annie jones','st. albans','the black crowes','the tampa bay rays','galveston tx','mpg','hogg','gwb','hansen','btu','diessel','the youth peace center','what','bam','iman','korean compliment','buenos aires','constitutionally','am','education appropriations','dj','radio to facebook','oxyclean','manafort','crappy','the chicago art museum','the cleveland museum of art','gridiron','empire of enchantment','oxford university press','ramo samee','the house of reps','pet cemetery','castle rock','television tv','thoams','blutube.com','wear panda','nintendo system','starcraft','guest house','evil kneivel','reptar lol','the arctic monkeys','hahahahaha','ll cool j and busta rhymes','ll cool j','rap music','rock and roll','seinfeld',' friends and frasier','clint eatwood','wine','caballus','duke ellington school of the arts','amazon web services','the school of the arts','nyu','julliard','askjeeves','the surgeon generals','homeland security','blasey-ford','a national risk management center','department of homeland security','the federal emergency management agency','fema','aretha franklins','wr','done','daid ruffin','hyde-smith','confederate','sar','democrars','fruit','potus','the trump administration','medicaid','uaw','mccain','the website imdb','yum','u2','male & female','the u.s. nuclear','inonesia','gold','foa','bell labs','google corp','peewee','atv','coolidge','pilates','the new york philharmonic','the los angeles philharmonic','philharmonic','congresswomen','w','freakonomics','indoneisa','taft','us senators','teh senate','football and baseball','hsi universitys','granturismo','indiana pacers','conflicted','ar','ar/m16s','pol','trumpisms','the united staes','gatestone','the electoral college','citizens of austin','ramone','the electoral collge','the house of representatives flip','liberal republican party','the red and blue','exec','felonies','celebrity apprentice','the young republicans club','schleswig holstein','champions','the uefa champions league','the simpsons treehouse of horror xxi','chimp','an inventors hall of fame','patent and trademark','washington redskins','stone','trumps','starbury','covergirl','the commercial spaceflight federation','bruno','compaq','x.com','nevadas','the virginia senate election','the republican elephant','the rep. party','the republican partys','cabinet','hrc','disneyland lol','us hopes','the us treats','politico','polico','nafta','cruze','world bank','harley-davidson','general motors','the fox entertainment group','fashionistas','the notorious rbg','ya','roosevelts','obrother','the department of homeland security','border patrol','wowo','whopper sacrifice','','harvard.edu','final cut','flame throwers','the travel channel on tv','uber lyft','cancun','zucker','fox news headlines','the white house correspondentsthe press corp','the white house correspondents dinner','nthe','hehehe','jon hamm','little league','asu','neighbors','civilian dc','obstruction','am radio','jupitors','drive thru','toys story 1','assoc','seinfeld',' frasier and friends','netfix','the comedy morgue','python program','lysistrata','great white sharks','big brother','niceee','dead article','gd','aor','clockwork','the dream theater','rush/kansas','seventh wonder','crosby','columbine','lizzo','this national space council','us companies','diplomacy','dt','chase','konner','led','the nintendo swithch','domino','the national spelling bee contest','dark crystal','orville','wasa','santa fe high school','the santa fe','dimitrios pagourtzis','awesome!!!daniel','gamboy','chamber of secrets','harrys','starship troppers','photogenic','government','directnow','the office',' parks and rec','the post office','alhambra','carroll','the arizona fall league','cubs-rockies','cactus league','pretty little liars','sphere','adr','highlight','schilling','sobriquet','the central division','national league pennant','shark tanks','dnc','nuremberg courts','the us government debt','mc hammers','earls court','congressus','dad','daft punk','blair house','arid','uber or lyft','radio lab','gwynn','bonds','the albuquerque isotopes','office tv','burger kins','villanova university','the red skins','new zealand rugby','the us supreme courts','somebody stop me','vista del lago','classic!i','hall of fame','boxer','the united states congress','dad','super storm sandy','the outer banks','alot','ahahahahaha','presidental','mre','loophole','polanski','catholic charities','the crossing','us military','the us marines','maddog','ohio state','mar-a-lago','uae','jazz nba','mind','the nba hall of fame right','hq','nothingham trent university','thrid','the university of iowa locker room','us football','the pan american maccabi games','awesomeegosurf','non-nfl','the olympic center','adults','facebook & youtube','neville','the football association','ac milan','real madrid','the usa womens','patriots rb benjarvus green-ellis','soccerplex','dc united','portland timbers','mnt','xfl','burger king wouldnt','next world cup','fox sports','adams','a white house','bull moose','nfs','nps','gopmembers','bull moose party','the smithsonian institute','the new york daily news','the new york post','inquirer','their house of representatives','a fantasy congress','draft','monsanto','pinkerton','ag-econ','umd','adblock','revelation','haters','congress league','cpac','guns','tbi','another brett farve','the university of oklahoma','lebrons','le bron','iverson 800','0','smart boy','the general car insurance','the oceanic nations','ford motor','interstates','moe','air force','durst','snow patrol','dictators','blue oyster cult','pink floyed','urban','obamacare','priebus','fund pbs','sea hawks','the ne patriots','hexagon','champions league','mob','polo shirts','waaay','homer simpsons','the shark tank','megalodons','the white shark cafe','daily news','java','fasier','sunrise','pixar studios lol','huawei','ones','jared','crt tvs','facebooker','holt','les moonves','american tv','police academy','wawa','rocky','water','holiday inn express','makeshifteagles court','yea pretty sexist','cheer-gate','symphony','first king','congress cultural significance section','g-eazy','teh bull moose','interesing','the oval office','repub','the fuzzy party','rugrat','wcw','addidas','the supreme court justices','advertising','rfk','the discovery channel','rainforest','the library of alexandria','bobbit','triangle','ikea to dc','the brooklyn dodgers','fox news corp.','fxx','university of virginia','conde nast','grand ole party','walter reed','googles','treehouse of horror','kemper','total recall','virginia law','jack russel terrier','the king of pop','tele','freddi mercury','burning man','black/white','thriller','the state of the union speech','gq','washinton','pureflix','boston red','the cherokee nation','caroll spinney','the simpsons on southpark','caroll','the national basketball association for the milwaukee bucks','jayhawks','cambo','preston','billy crystal','olympic towers','oled','bluebloods','usvi','raleigh','volvo','questions','ceos','wa','best buy and target','the warner brother studios','warner brother studios','w.h.','american pickers','jaime n commons','aramaic','the old executive office building','kingdoms','duerte','duterte','the montgomery police','reed hashings','house of cards in netflix','the new black cancellation','fox network','red foreman','chappelle','ebart','murphy','brewers/dbacks nl','veggieburger','the presidential guest house','multi','busienss','one','macbooks','ipods','the rain forest','episcopal','olympic basketball','rugby 7s','arena','the h.w. bush administration','fox simpsons','the rain forest cafe','rand','ha - assange','dem and rep','urban meyer','the ohio state university','house?n','gallup','the news media','episcopal high school','kung-fu hustle','northwestern university','reynolds','the sony playstation','ribs','goodbye','rnc','app menu','thini','international house','speaking of england','redbox','the food channel','you tube users','doubt','jonathan daniel hamm','ethiopian celebrity tv','the guest house of the president','the rugrats movie reptar wagon','fins','cathode','lcd','thomas the tank','slovakian womens','thehighest court','cool beans','citadel','demarcus ware','supersonic','cooperr','live pd','eli manning and peyton','ole missthe capital gazetter newspaper','cadillace','a space force','helo','scientific american','black mirror on netflix','princeton universitys','sci-fi like starship troopers','seaman','novels','atlanta united','new england patriots','nep','the european league','fox news co-creator','burger kings promo','alex jones/info wars','c64','ga','outta compton','chubby checker','vinyl lps','radio jove','white house down','aerial','apush','doj','good olpulitzers','lop','cbc','hoop','torch','snk','sn','trump & hannity','the movie aladdin','catholic church','usccb','army/air force','humour','dumbo','sctv','the first aladdin','deliverance and smokey','bandit','the democratic party of old','sienfeld','micky dees','caddie','bush','simpsons on netflix','friends and the office','uhd','uhd tv','shogun world','rotten','reed jastings','rotton','ireland &','eagle','the blue jackets','gruden','the uk office','bread','ds','seattle mariners lol','modems','jumbotron','hahahhahahahha','hahahahahha','the make','the university of iowas locker room','fakebook','n for nepotism','raidernation','gaelic football','high school civics','np','durant',' curry',' green','kt','cleveland cavaliers','markieff morris','markieff','q&a','the family over everything foundation','g-league','kansas unviersity','iowa state university','wijnaldum','indonessia','the style invitational','rb benjarvus','american college football','geogia','the lakers and celtics','white tvs','cdc','jupitar','color tv','dramatic tv','handmaids tale','people magazine','handmaid','mashable.com','the democratic partys','tbh','kutztown university','app pages','chefs and barbers','the presidency pop tour','the computer history museum','ford fusion','the london symphony orchestra','awd','mc donalds looks','the russian embassy','the russian foreign ministry','hedy','ipone','usd/gbp exchange','tree house of horror','payton','serra','ole miss','eli mannings','lum &abner','waterboy','american nfl','shark-fin soup','university of oregon','information','fairies','the atlanta falcons','lambeau','national football conference','big ben','high school the green bay packers','ny yankees','cleveland browns','beloit fairies','avg nfl','pit','mayfield','first energy','first energy stadium','the indian packing company','the greenbay packer','u of oklahoma','congrats','govt','imo','burch','the new york giants','a university of georgia','the trump organization','monticello','jaguar','rb leonard fournette','guice','nfl blitz','hawkeyes','acc','gb','degrasse','the st. louis cardinals','macho man','benz patent motorwagon','freedom-woodbridge','jambalaya','vey','central high school','thier','abe','walt-mart','the obama administration','us government employees','dfw','cowboys radio','u.s. congress','grays anatomy','homeland','the juniperso serra high school jv','gallaudet college football team','motorhead','n.c. state','the junipero serra high school jv','american college','the u of ias','the patriots rb','oakland raiders','army-navy','university of oklahoma','nola','georgia techs','iowas','the dream team','amrican football','the navy midshipmen','tib-fib','seahawks','the carolina panthers','bal','sherwin williams','aat iowa university','darryl jones','fantasy team','benjarvis green & ellis','juipero serra high school jv','the dixie chicks','dalton brothers','the jazz hof','wahsington','haha nope','pensicola','amarillo','aal league','the cleveland browns','new england patriot vollmer','years?n','ne patriots','calais campbell','the patriots the lannisters of the nfl','the bills for super bowl','patriots american','the university of utah','sanchez','the seattle seahawks','bills','the university of central florida','ucf','the university of florida','the net passer rating','jacksonville staduium','the american football league','the new england patriots the lannisters of the','the new york patriots','bill','detroit lionsjupiters','the junipero serra high school','belechik','edelman','the cousins/smith','pittsburgh steelers','xcel energy center','the arizona cardinals','university of ok','afl','green bay packers','nfl draft','the phildelphia eagles','steelers','junipero','bellchick','national television','gisele','jaguars','dandy','avg','no saint','the university of michigan','london symphony','pruitt','wheeler','crtc','jfk & washington','the pro football league','pelecanos',' dc','the supreme court buliding','iowa state','pastime','the hall of famers','the u.s. imagine','boxing',' football',' baseball','phenom','groerogia tech','ux','dawsons','yowsa','chciago','ohio school of broadcasting','chic-fil-a','turbo','montery',' ca','dlp','the og nintendo','wwii soldiers','mirror media group','ministry of state security','china daily','the clean india mission','green- ellis','the patriots the lannisters of the','the university of texas','the socialist party','the while house','hilarious)maybe','eagles vs vikings','great life','mcdaniels','the u of ia','g tech','jaz','university of iowas','kinda sad college football','dream team','sierra','the cbs radio mystery theatre',' suspense','the censorship board','uo','fox/trump','deutsche bank','us radio or tv','cable channel','fox news ever','fox opinion','jw booth','barrons trumps underground','alexandria ocasio cortez','fox n','fox news fan','canadian radio','fox and friends','aeronautical','fantasy baseball league','the phoenix suns','cheerleaders','illinois standards','burrfect','linc','blackhawks','fantasy congress leagues','deangelo hall','allen tx','pity cumberland','movies','zimbabwes first','crossword','niagra','hamas','the apple corporation','the orlando magic','wilkes booth','whoopers','mfol','mis','mac & cheese','game theory','fresh off the boat and superstore','kuroko no basket','tank','the jnipero high school','bge','iowas university','julion jones','take brandin cooks','the patriots','republican party','the democrat party','junipero serra high school','kosar','football','panthers','ever!former patriots','midtown tavern','representative comstock','science fair','bucs','the texas rangers','jeffferson','sinclair','the chicago sun-times','john deere 4020','commonwealth','the commonwealth of nations','hondas','yamaha','teddy rooselelt','dyson','new york times','their trump derangement syndrome','the browns and steelers','bernie','the national economic council','national economic council','papadopulos','spygate','the ny times','indonesia king banana','t.jefferson','comedy centrals','wth','iowa university','heitkamp','sci-fi tv','jargon','national anthem','trump & hilary','vandelay','northrop fry','british comedy','nuns','fluffy','cnn & msnbc','republican media strategist &','fox new corporation','the simpsons homer','nbapa','national harbor','benz patent motor wagon','detroit antoine de la mothe','hit','georgia state','the alpensia sliding centre','usa mens','maxine waters','the congressional black caucus','the united states &','feorgia tech','msm','the naval academy','goergia tech','the alpine skiing world cup','exqcexa','benz of mercedes-benz','protecting pregnant workers fairness act','guesthouse','megan','knowthe national football league','the national football conference','the american football conference','playoffs','ballet dancers','tango','nfl draft pick','american alliance of football league','tampa bay','the bucs squad','the iowa university','ag','splc','leaf','boise state','the foreign service','amazon forest','federal reserve','welsh','the windsor chapel','the democratic peoples republic of korea','jp morgan','crimera','air bnb','jupiter radio storms (great','farc','santo','th am','forest!!very','jeff sessions','sessions','rfk stadium','mcgarvey','the oakland as','teh white house','the apprentice','fedex','truett mcconnel university','the college of ozarks','tmu','wilkes barre pennsylvania','the detroit lions','nsa','the canadian football league','breitbart news','cesar','rpo','rpi','nes nintendo','the tampa bay bucs','cleveland brown','the digital tv','remote','electric','broadcasted','community','da do','the georgia bureau of investigation','hillary pres & vp','the new zealands','kansas history','simpon','the communist party','treehouse of horror xxi daniel radcliffe','the university iowas','africare','abey','the oregon ducks','eli mannings','the university of mississippi','the san diego chargers','unfair','ny giants','university of mississippi 2000','the iowa hawkeyes','indian packing company','vince lombardi','macho mans','stossel','shane','smackdown','raw','hogan','the wwe','american flags','falcons - patriots superbowl','deflategate','university of michigan','ben-jarvis green-ellis','commonwealth of virginia','sephon marbury','oklahoma state'],
'PERCENT':['0.62','71 percent','29 percent','more than 80 percent','more than 80%','0.75','0.628','62.8 percent','0.63','as much as','almost 63%','more than 62.8 percent','75 percent','about 71%','0.71','just 38%','0.19','0.38','0.93','above 44%','0.86','the 86%','40 percent','80 percent','hundred percent','the other 29%','0.33','only 70 percent','0.8','0.7','about 85%','only 20%','0.34','63 percent','8000','000 ppl','eighty percent','up to 40%','about 10%','a better than 90%','only 3%','almost 71%','0.29','over 80 percent','0.2','0.66','like 90%','1.1','0.143','only 30%','0.15','less than 1 percent','0.1','30 percent','over 63%','only 7%','the 7%','over 80%','the remaining 29%','under 70%','one 75%','over 62%','14 percent','about 56%','like 34%','2000 40%','0.14','56 percent','0.56','95 percent','60 percent','0.9','about 71 percent','only 55%','0.85','0.9986','about 99.86%','almost 100%','worn 94%','about 75%','about 63%','only 0.53%','about 86%','less than 1 %','above 63%','a tiny 29%','0.98','a little over 1 minute','0.6','up to 10 percent','about 30%','0.45','more than 60%','7 percent','about 1 percent','0.35','20 percent','only 29%','the other 71%','46 percent','about 6%','84 percent','less than 63%','about 33%','0.51','0.0001','about .01%','99.86 percent','only 80%','around 80 percent','0.3','more than 80 %','about 80 percent','the 71%','the 20%','about 0.01%','about 80%','33 percent','up to 33%','10 percent','only 60%','0.014','about 90%','the 33%','0.94','only 94%','only that 94%','2000 40 percent','about 50%','15% and 32%','86 percent','about 70 percent','0.78','0.566','like 42%','0.25','only half a percent','about 58%','about 1%','nearly 90%','0.5','0.95','some 84%','almost 90%','over 85%','just of few percent','over 70 percent','about 60%','the 10%','the 78%','that over 80%','over 70%','almost 80%','100 percent','up to 200%','up to 50%','about 20%','200 percent','about 14%','24.3 percent','only .53%','almost 10%','only about 7%','less than 0.50%','16 kb','only 7 percent','the 93 percent','more than 38%','one than 44%','over 40%','just 44%','more than 44%','like 40 percent','the 93 %','the 30%','fifty percent','only 3 %','over 99%','about 44 percent','over 60%','higher than 63 percent','50 percent','the other 20%','the 85%','71% percent','43 percent','about sixty percent','ten percent','the 93%','the 7 percent','a hundred percent','like 1 percent','the 80%','20-30%','a little over 50%','roughly ten percent','close to 100%','over 90%','up to 10%','seven percent','only 0.53 percent','only about 7 percent','only about seven percent','at least 40%','0.88','over 40 percent','as long as 40%','such %','our 71 percent','this 7%','the other 93%','about owning','0.65','like 30%','like 93%','all 86%','about 99.86 percent','like 99 percent','about 73%','about 25%','the 29 percent','0 percent','1 percent','34 percent','0.9886','0.21','less than .3%','0.06','the only 7%','0.02','the 99.86 percent','like 40%','nearly 35 percent','like 33 percent','at least 40 percent','swimming than 80%','1-3%','1 to 3%','less than one percent','only .53 %','as much as 7%','unfortunately 34%','0.995','one hundred percent','90 percent','0.99','nearly 50 percent','unfortunately more than 80%','44.6 percent','about 7%','0.0053','approximately 73%','about 78%','the last 20%','about 70%','like 71%','0.89','0.39','throw %','approximately 78%','0.73','today 86%','like 86%','78 percent','only 15%','93 percent','0.011','fewer than 8%','15 percent','only 6%','0.09','2013','40%','about 1 %','the the 40%','law 40 percent','at least 40 %','about 40%','forty percent','only 63%','150-200 percent','2 percent','just like only 7%','the 15%','70 percent','the other 93 percent','almost 60 percent','almost 99.86%','almost 86%','35 percent','over 50%','30-35%','under 63%','27 percent','less than 62.8%','0.323','the 34%','8.5 percent','over 62.8 percent','0.013','less than 40%','0.87','over 30%','approximately 33%','0.08','thirty percent','only 29 percent','around 60%','less than 1%','3.8 percent','3 percent','a least 40%','a little above 3 hours','0.37','more than 99%','as much as 10%','about 34%','around 62%','around 30%','only 7 %','0.48','over 62.8%','99 percent','as high as 62%','68% to 38%','under 50%','several hundred percent','another 10%','like 85%','about 99%','more than 40 percent','only 28%','the7%','the seven percent','as much as association','the 34 percent','62','8%','only 53 percent','more than 10%','0.999','150 100%','66 percent','only 42 percent','that 40%','more than 10 percent','0.96','0.79','up to 33 percent','law 40%','about 63 percent','at least 75%','almost 50%','around 50-60%','0.53','0.26','7 &','6 super bowls','less than 0.01%','0.47','0.61','the radio 40%','the 60%','0.81','around 65%','92-95%','about 98%','44 percent','nevada 86%','47 percent','the 86 percent','86% percent','0.03'],
'PERSON':['sundar pichai','larry page','michael jacksons','michael jackson','jessica','tchaikozsky','garfield','anderson','harley quinn','stan lee','earth-616','moon ganymede','gadget','tintin','james earl jones','george lucasmarcia','george lucas','chewbacca','episode iii','roosevelt','tuna','yuck','teddy roosevelt','roosevelet','bimbo','cute stuff','the loch ness','the zebra fish','theodore roosevelt','haha ya','aunt matilda','can eat prey','harrison ford','alden','george rr martin','good morning','taylor swift','brett kavanaugh','ancient athens','george','ridley scott','hank','richard nixon','pajama day','elsa','pete rose','jose canseco','minerva','snow queen','rapunzel','minnie mouse','mickey mouse','namaste :)','davey johnson','rollie fingers','maurice','jane mcgongiai','tom hanks','jim hanks','littlebigplanet','harry potter','stephen fry','stephen frys','edgar','julius ceasar','edgar allan','julius caesar','edgar allan poe','demetri martin','dolphins','jeff bezos','edgar allen','especially icelandic','jeff bexos','dinosaurs','hillary','bernie sanders','bill clinton','clinton','timothy leary','schwarzenegger','ralph lawrence','carr','lets','hillary clinton','harry truman','arnold schwarzenegger','tim learys','ralph lawrence carr','arnold','tim leary','steven spielbergs','steven spielberg','richard donner','disney','ready player','sleeping beauty','valentine','the jurassic parks','dude','tom','oprah','netflick',' hulu','robin williams','thomas jefferson','jesus christ','john quincy adams','babel','william shakespeare','lewis','clark','william gladstone','bibles','iti','eve','phil collins','emilia clarke','rogers','mr rogers','bill bailey','alicia keys','ashton kutcher','jennifer love hewitt','larry hogan','haha good one','bush','nixon','michael bays','juno','channig tatum','jenna dewan tatum','patrick swayze','speilberg','tran','chloe bennet','star wars','leonardo dicaprio','johnny depp','will smith','daniel day lewis','james cameron','george lucass','john williams','kelly marie tran','george lucas','leo di caprio','bill murray','johnny','seuss','seuss look','edward scissorhands','bram stoker','forest gump','ben kenobi','yoda','mouser','helena bonham carter','lol btw','sleepy hollow','nic cage?','queen elizabeth ii','jean chretien','gene wilder','john christopher','depp ii','mary shelley','timmy thomasjon stewart','lil','wayne','eddie van halen','bohemian','paul mccartney','mark farner','brian','bohemian rhapsody','hey jude','richard nixons','rami malek','brian may','torino','matthew bellamy','louis armstrong','francisco tarrega','google','googled borg','mcenroe','shia labeouf','borg','lol','neil armstrong','lawn','serena williams','ryan gosling','isaac asimov','haha yea','godfather','golden slam','signmark','minerva mouse','bill nye','walter elias disney','john legend','minerva lol','mermaid','the loch ness monster','donald glovers','walter elais disney','walter disney','korean rap','ewan mcgregors','knights of the old republic','kylo ren','oscar isaac','james earl','tommy john','david','woody','destiny','mario','david price','guy findin','charlie chaplins','tom cruise','ron kovic','tom cruise haha','rainman','jamie foxx','nicole kidman','eyes wide','christopher robin','peter dinklage','top gun and cocktail','nat geo wild','tom kruse','tom cruise edge','yea fox','rupert murdoch','haha duels','mardi gras','fighter concert','dave matthews','marco rubio','ted cruz','richard','richard allies','richard ailes','tommy oranges','cheyenne','imagine edgar allen','winston churchill','switching','lol same to rocky','kinda big','teddy bear','harrison schmitt','john von neumann','boas','amy adams','gillian flynn','lynn','amy dunne','camille','flynn','julius caesars','george martin','denzel washington','ruth bader ginsburg','bill murrays','box','alexy pajitnov','alexey pajitinov','chsitmas','holidays','susan westmoreland','susan gage caterers','sport wii','normally','croat','worldcup','modric','mookie betts','babe ruth','babe','ben afflecks','ruth','lebron james','lou gehrig','dodgers','wrigley','samuel l. jackson','micheal jordan','samuel l jackson','james naismith','aubrey drake graham','ramon','drake graham','timmy thomas','joanna gaines','chadwick boseman','grisham','jack london','george w bush','chawick boseman','ryan coogler','michael b jordan','tony stark','bruce wayne','standup comedy','bill burr','daniel toshs','ken jeong perform','ken jeongs','ken jeong','robert downey','chris hemsworth','chris evans','pratt','jarvis','bean','ken','kung foo hustle','gilda radner','chevy chase','lou ferrifno','jackie chan','jackie','bill mays','recycle','rip billy mays','rippon','ostrich','daniel murphy','matt adams','pete','jack sparrow','chris','ewan mcgregor','winnie the pooh and tiger','winnie the pooh','lol the','allan','james wong howe','stanley kubrick','kevin spacey','spacey','roger deakins','stanely kubrick','steve smith','miguel cabarello','mark zuckerburgs','mark zuckerberg','wears grey','mariah carey','glitter','ariana grande','jerk','linkin parks','trogdor','kinda goofy','george harrison','john','paul','timothy learys','man','anabelle lee','deville','ricky gervais','nicolas rehn','james wong','knw clint eastwood','elon musk','christopher nolans','trot','aaron','albert einstein','franklin d. roosevelt','flexner','william whewell','macaroni','fred durst','hulk hogan','nicole kruspe','kruspe','hanako','romeo','mccarthy','jeff','billy sianis','doug harey','crocodiles','martinez','ronald regan','billy goat','eric hosmer','mitch moreland','manny machado','jude','roaches','stephen strasburg','aaron nola','max scherzer','jacob degrom','ryan zimmerman','j.p. crawfords','puig','frank robinson','daneil murphy','jim abbott','soccer','ronald reagan','reagan','moneyball','barry bonds','billy','lou','womens','harry lloyd','charles dickens','harry lloyd?','oliver twist','visery targaryen','charlie chapins','talisa maegyr','khal drogo','robin','judy','pixar studio','carol burnett','dalmations','lebron jamesn','merry christmas','repu','bi mart','dry goods','kinda lame','hal','stephen hawking','kim jong-un','kim','jude judy','rbin williams','must','gehrig','guessing long ball','don mattingly','daryl strawberry','bobby richard','bobby richardson','ol bill','bill oreilly','ted williams','bill oben affleck','ryu','maz muncy','roberto osuna','astros','osuna','chapman','johnny damon','astro','bryce harper','alex cobb','angel hernandez','joe torre','shin shoo choo','alexi lalas','solitaire','doom','scott lindroth','the edgar allan','demetri martins','kristen stewart','bri bang','clifford','stitch','lockheed martin','there','mark zuckerburg','magic leap','lol nice','watson','facebook','michael','taylor switf','ahaha','mark zukerburg','micheal jackson','micheal','knoew taylor swift','aloe blacc','amber tatro','king kalakaua','zara','kinda resembles','martens','lol :)','briggs','jon briggs','considering siris','bing','beanie cap','susan bennett','sugito','harambe','fantasia','library genesis','bezos','jar haha','drew goddard','terry pratchett','ant man','iron man','kenneth branagh','zack stentz','ashley edward miller','anthony hopkins','idris elba','natalie portman','jeff bridges','cynthias','cabin','natallie portman','tom hiddleston','idris','jim henson','salvador dali','gmail','winfrey','o','salvadore dali','brandon belt','dacid benioff','george r. r. martin','dickens','charlie chaplins','jeffry','talis','james','dirk nowitzki','alladdin','george r.r martin','tabby','alex jones','joe rogan','giamatti','stadium','gerrit cole','justin verlander','charlie sheen','tribe','jayson werth','charles dickens lol','verlander','tommy lasorda','justin biebers','wayne rooney','mesut ozil','rene the crocodile lacoste','windows','donald trump','manchester united','beckham','dizzy gillespie','zydeco','tom waits','billy the kid','justin beibers','gran turino','beanie','bob ross','ross','haha fisher','roy wegerle','roy','eddie johnson','freddi adu','ozil','freddy adu','luke skywalker','mark hamill','obi-wan','gal gadot','johnson','ill','cigs','steve jobs','steve martin','steve jobshan solos','peter mayhew','haha yup','isaac','drew barrymoore','jamie lee curtis','rosemary','moody','larry','a.e.w. mason','king kamehameha','ceo','isaac newton','sci fi','larry fine','kinda person','king zeno','kylie jenner','bruno mars','ive','red green colorblind','patricia heatons','bruno sammartino','peter gene hernandez','benjamin franklin','haha imagine','moon walk','marcia lucas','ren','paul mccarthy','paul ryan','nancy pelosi','jim jordan','lol yup','steven colbert','stephen colbert','fifty shades','diane keaton','candice bergen','mary steenburgen','moby dick','don quixote','john carter','drew carey','evan','dave chappelle','evan almighty','jim carrey','bruce almighty','haha weird','raymond','mozart','e.e. cummings','wi','online','mayor cat','dang nature','lol crocodiles','patty jenkins','ursula k le guin','le guin','emily jungmin yoon','wiman','talkeetna alaska','gal','catwoman','tina turner','winston chruchills prize','bruce springsteen','elton john','tina','ike','joe jackson','tijuana ike','kim kardashian','megan fox','michael bay','bey','rodney wallaces','ping pong','rodney wallace','arthur ash','john isner','ralph lauren','jon steward','rene lacoste','solaris','ti','coupe mondiale','yea phil collins','peter gabriel','rick gervais','xtc','rikey gerwais','rami','mick jagger','mick','andy warhol','judy colling','joan baez','marc bolan','syd barrett','jack','modal','frank sinatra','sinatra','roger daekins','gavin free','hot fuzz','lou reed','tony bennett','lou coppola','amphitheatre haha','michael trister','john macain','steve malkmus','alpine valley','john mccain','john mccains','martin luther king','alphabet inc','john doerr','risks','billy joel','joe bonamassa','dire straits','nick cave','king crimson','srab sheik','joe hisaishis','listening','osama bin laden','st patricks','stalin','chruchill','thogh','david bowies','duncan jones','close encounters','schindler','shootiing man','moon movie','e.t. the color','vida','haha speaking','katharine graham','andrea camilleri','joseph haydn','black keys','neil young','albanys symphony','chopin','vivaldi','gangam','issac asimov','steve','berrys','austin texas','michael jordans','dumbos','michael jordan','trick dick','matt bellamy','george w. bush','teddy','john candy','bunch','jack purcell','jack purcells','moncler','haha mine','hilary clinton','strom thurmond','aquaman','lol speaking','gore','no jimmy page','monty pythons','timothy learys','gypsy jazz','lambert','roger allers','rob minkoff','matthew broderick','simba','lee','stanely cups','henry david thoreau','nationa','winn dixie','ex machina','henry thoreau','bradley cooper','bradley coopers','lady gaga','iron maiden','lady gagas','bradly cooper','dave mathews concert','dave mathews','elton johns','roger waters','lol weird','ugg boots','earl grey','george bush','john adams','george hathaway','tenold','michelle obama','james madisons','roger federer','novak djokovic','jon isner','gael monfils','arthur ashe','roger','andrew jackson','polos','rodger federer','glow','nicholas mahut','stan wawrinka','rafael','rene the crocodile lacoste','djokovic','stephen kings','camaleona','larry oage','juan martin del potro','rafael nadal','tiger woods','gael memphis','opens','darley arabian','julie taymor','james camerons','jon favreau','steven kings','morw','ernst haeckel','ryan reynolds','dp2','david fincher','mini','ryan stiles','mitch mcconnell','beto orourke','the thin silence','clooney','barbara mikulski','carl moseley','gantt','duft punk','art thou','phil collins btw','jane mcgonigal','mikulski','braun','gee','barbara washington','sushi nakazawa','jiro dreams','miles davis','aspen colorado','emminem','kim jong un','locheed martin','peterson','grant imahara','rosie','dave','taj mahal','john wainwright','kum jong un','nintendo super mario','judy btw','tom hanksjimmy hanks','proxima centarti','justin timberlake','n. koreas ','jessica biel','moon hay fever','grrr','lola anastanove','lola','waters','cameron diaz','jason segal','moon dust','bruce lee dancing','trooper','sharknado','zebra fish','lamprey','fro knights','obi wons','obi','family guy','an academy award','boy','liam neesen','bambino','samuel l jacksons','idra novey','samuel jackson','kim jong-ill','turker','buck owens','buck owens tv','david bowie','mark knopfler','bob marley','lady macbeth','lol me','james blake','janelle monaes','duran duran','bon jovi','def leppard','hanson','madonna','lady macduff','charles ii','lady mcduff','good riddance','tchaikovsky','avon','odysseus','cristiano renaldos','stanley kubrik','gavin','christano ronaldo','marvin joseph','denis cyplenkov','wrestler','ruth bader ginsberg','donald ritchie','kinda gross','stephen marburys','stephen marbury','run','abraham lincoln','abe lincoln','jabbar','king sandoval','nathaniel white','brad pitt','samuel i jackson','daisy','monty pythons','eric idle','mython','perry mason','andy griffith','matlock','dish','c.s. lewis','adam sandler','medici','terry crews','steve buscemi','danny trejo','nick nolte','lego knockoffs','adam sandlers','rotten tomato','farley','civic govt','haha good point','imagine hillary','ayn rand','salmon','shrimp','stephen colberts','jesus','james martin','nichols','nichelle nichols','tom morello','jr','colbert','album fearless','kinda rude','jean chretiens','taylor swifts','m. night shamalan','jared leto','salad','gassy','gon','brainiac','thomas edison','kinda stupid','coulda','jimmy carter','ye','neil degrasse','fleisher studios','button kinda','loraxes','tina fey','catehrine glanagan','don[t','duane johnson','spider man','spider-man homecoming','peter parker','justin biebers','david harbour','jaden smith','achilles','jenna marbles','connie b. gay','george strait','darius rucker','henry ford','banjos','bass','melissa mccarthy','mila kunis','kate mckinnons','girls','dennis rodman','kim jong','kim jong-il','ko yong-hui','kim ii-sung','the point(ref youtube','kim jong-uns','james naismiths','shaq','ruth bader','ginsburg','kim jon-un','eric clapton','george lucus','golfer','golf','daenaeryus','robert downy jr','iron mans','paul bettany','mark fergus','hawk ostby','art marcum','matt holloway','jon favreaus','nicholas cage','yuck lol','michael jordans','allen iverson','olympic hockey','stanley cups','bowler','stephen wolfram','johnny clarke','kurt vonnegut','mary higgins clark','goodfor','heheheeee','william shakespere','bill s.','john oliver','wsc avant bard','henry v','anne hathaway','andre tchaikowsky','steve carrel','harold','angelina jolies','hygiene','hugh jackman','environment','carl sagan','alec baldwin','meryl streep','de niro','michael caine','al pacino','lyle wagoneer','esther williams','stell guitars','hillbilly','peter kavinsky','robert de niro','marc randolph','rcok','bob','koi fish','dick','sporting goods','lol funny','not eminem','nas','muhammed ali','tony parker','hip hop','muhamed ali','vanilla ice','anee jones','andrew johnson','glass','tom hardy','michael keaton','val kilmer','george clooney','michelle pfeiffer','chris nolan','supergirl','eddie murphy','bob kane','robert oppenheimer','oppenheimer','slapstick','craig fergusons','calvin klein','kudos','elizabeth','joey','chandler','lol true','michelle yeoh','henry golding','constance wu','jon m chu','law libraries','jim dale','chick flick','jungle','karate','weird al yancovich','wil wheaton','steve king','consoles','mario bros','henry cavill','jerry siegel','braniac','lex luthor','matt groening','ronald mcdonald','ronald mc donald','mc donalds','nick offerman','megan mullally','nicole chung','david grann','whoa','ralph','liberia','happy holidays','sergey brin','the jon stewart','seren fryatt','blazing saddles','christian andersons','mariah careys','mariah','sleeping beauty?','eliza dushku','bill nyes','bill nighy','netflix way','pitfall','jennifer lee','frozen lol','robert lopez','robin hood','alan tudyk','zootopia','timmy thomasquriesh ahmad','kareem abdul-jabbar','grand jete','queen elizabeth','kareem abdul jabbar','jay','bruce jenner','ray j','kylie','david schwimmer','mayeb','netflix youtube','kinda ridiculous','al gore','louis braille','jimmy buffet','harper lee','huckleberry finn','mark twain','sega genesis','mickey ds','anne joneslol yea','mark twains','the adventures of huckleberry finn','tom sawyers','lady gagas','robbie','danger','will robinson','molly parker','everyman','sandra oh','lou ferrigno','stark','cloverfield lane','john goodman','rick barry','tim duncan','stan lees','toby','judith polgar','pro-persian','randolph','diong haha','ntflix','reggie miller','peter','madame web','crunch','orson scott card','uncle walt','ginsberg','jordan peele','leo','robert lopezs','blazzing saddles','lilly von shtoop','ruth bader-ginsberg','chad hurley','steve chen','jawed karim','cruz','baker','legett','howard','leggett','michael jones','roosterteeth','petri hawkins-byrd','yea lol','millard fillmore','beard','blue ear','mcd','lady killer','post-nixon','gavels','tricky dicks','man linkin park','batman begins','terry pratchett btw','jessica jones','bryce vine','bill evans','debby','paul rand','lol ya','linkin parks','jay z','led zepplin','staind','mike shinoda','red sun','peter kamp','barron trump','sonny rollins','eddie perfects','stewart','chapelle','jack back','heisenberg','nikolas cruz','jerry','pinky','david jolly','vevo','tatum channing','king james','channing tattun','james corden','yeti',':) humans','pyramide','carbs','miley cyrus','marie osmond','miley cyrusdestiny hope','miley','godmother','dolly parton','dad billy ray','hannah montana','jessie j','jessie','j.r.r. tolkien','elizabeth warren','el chapo','barbie','ruin wikileaks','ricky gervis','a space jam','chapo','ismael mayo zambada','lol wikileaks','uncle','colonists','andrew bonar law','michael jacksons','brian may.','google moon','del port','rafa','andy samberg','andy murray','drew cary','bill murry','the silence of the lambs on','red dragon','bryan hill','black lightning','bam pow','alfred','gordon','bill finger','lego batman','calendar man','wheni','mark hammill','moo la','sleepy beauty','chuck e. cheese','tim burtons','tim drake','tim burton','norm breyfogle','bat-man','rob','jason todd','weird al yankovic','bye','bat man','duke thomas','knight','bill finge','weird al yankovich','bat','bane','rip stan lee','sideshow bob','mortal kombat ii','burt ward','ceasar romero','jay z.','ryan ewing','lichens','justin beiber','budweiser','cybanobacteria','anthony bourdain','mardi grass','tony','julia louis-dreyfus','carson','jack gleeson','joaquin pheonix','joffrey','lewis carroll','kenneth graham lol','schindlers list','i. youtube','non-cameron','brianna hildebrand','ryan reynold','josh brolin','zazie beetz','t.j. miller','mc hammer','agatha christie','nevada barr','park ranger','ranger','earthy','anad','grappa','apt pupil','lookin','christopher nolan','shinning','robert downey jr','robert','ralphie','jabba the hutt',' luke skywalker','anakin skywalker','obi-wan kenobis','tattooine','scott denning','guatemalan','kreslins','gretchen bolton','hugh laurie','jurrasic park','mia','jaw','homer simpson','coconut bras','stefi graf','martina','john mcenroe','regarding gael monfils','maria sharapova','gordon ramsay','marks','williams','joe','caine','elvis presley','jodie fosters','jack nicholson','mortal kombat','loved hanson','jack nickelson','forrest gump','kurt russell','bohemian rapsody','venu','elton john sang ','james brown','yea korea','singmark','jason paige','kinda odd','sam harris','eckhart thole','goriot','balzac','anna burn','sirens','jann mcgonigal','goosebumps','jane mcgonigaln','tom hanks','christopher watts','nurse sharks','speedy kinda feel','foo','mamma mia','odin','mickey head','philip','dave grohl','the foo fighters','bill ney','nextflix','she-ra','kinda funny','dragonfly','garth brooks','vladimir horowitz','would horowitz','beiber','stan van gundy','shoulda','gucci','rick harrison','miguel cabarllos','greeks','hedi slimane','louis vuittons','catherine deneuve','hermes','dapper dan','loch ness','gadot','kinda guy','pokemon go','fireman','justine','brahm','ted','thnat','jeff bezos amazon','psy ganham','rap song','ww1','theodore','dan reynolds','pat sajak','fall out','fall out boy','sting','adele','daniel craig','skyfall','black klansman','spike lee','btw','tom hank','keanu reeves','speed','wholly molly','paul rudd','neal degrassi tyson','elephants','andrew sean greers','rotten tomatoes and metacritic','jose','lily','mary','larry johnson','shawn kemp','tim hardaway','giannis','dirk','michael phelps','douglas fairbanks','jack skellington','mickeys','abdul-jabbar','kareem abdul jabbars','kareen abdul-jabbar','slam','zamboni','kareem abdul jabar','flipper','kacey musgraves','kacey','thom','pearl jam','day lewis','saddles','ethan fogle','crash','ruth bader ginsburg slam','wilson fisk','punisher','charlie cox','vincent donofrio','wilson bethel','kacey musgrave','sean conway jr.','dolphin','scooby doo','christopher reeves','gamestop','cardi b','john cena','harvey fierstein','jon luvitz','carol burnette','will spring','ben franklin','mork','mindy','doubtfire','doubfire','shame zuckerberg','wanna','miles','price william','king kalakuana','buchanan','would james buchanans','milky ways','carol moseley','vladimir putin','somebody','space odyssey','marcia lucasfloyd concert','velvet underground','paul manafort','mary tyler moore','harvey gantt','mark zuckeberg','tom brady','linkin prk','hahahhha','ty segall','madison','gnc','walgreens','kohl','tar-jay','goodfellow','grandfather','imagine andre tchaikowsky','hobo literature','earcth-616','billie jean vs spider-man','henry ford hadnt','footloose','achy breaky heart','lazy lester','musicianship','slim harpo','freddy fender','geico','tim mcgraw','chamberlain','leslie johnson','fred reif','ferb','douglas high school','maya','dp','robin williamsgrandpa kitchen','hugh','jaffar','here','song','william','laughing stock','wild goose chase','shakespeare','alex garlands','yule','normal man','black leopard','wakanda','hahahahaha good one','rip farley','thanos trucksounds','luther','maizel','let','colleen wing','wu ao-shi','yao ming','the harry potter','nich','steven king','dean koontz','cajun salmon','dave martinez','comedic','glad','an ice rink','david christians','sapiens','agriculture','doorlocke','doorlockean','a happy meal','orca','nancy','frank miller','alan moore','watchmen','kevin smith','brian quinn','erect','yuk','brad bird','sarah vowell','dwight howard','alan iverson','granny','capitals','ethan hawke','bill burray','van','clintons','joe biden','ric','koch','soros','taylor swifts','dang i am','dave brat','scott taylor','elaine luria doesnt','david albo','elaine luria','j.p. morgan','marsha blackburn','jimmy buffett','joe perry','mary jane','iverson','stan','wilt chamberlain','eminem crazy','horses','kinda corny','james harden','melo anthony','adam silver','spencer haywood','curb your enthusiasm','larry david','unbreakable kimmy schmidt','tchalla','chadwich boseman','outta campton','keith richards','wowww good','thom yorke','neptun','briatin','mark','andrew garfield','joey diaz','joe rogans','jenna','jenna glanzer','daisy ridley','rey','ancient greeks','merle haggard','donald glover','jimmy kimmel live','kanye wests','carol burnetts','michael buble','wiz khalifa','love drake','rapper xxxtentacion','jahseh dwayne onfroy','merry x-mas','volleyball','boyd rutherford','withou','kinda suck','thaat','brenda frasier','chris walken','ncaa history','drums','grizzly bear','rapper freedia','jed','gaga','elton','ellie kemper','stefani germanotta','regrow ribs','zukerberg','smart guy','katy perry','russell brand','russell','jrr tolkien','katy','emilla clarke','daenerys targaryen','numb','napoleon bonaparte','geoff peterson','craig ferguson','unless google','googele','justin timberlakes','haha netflix','chris brown','steve martin contest','tech fan','nintendos','anthony dj hollywood holloway','peter pan','abdul-jabbars','jerks','pete maravich','jr.','robert downey jr.','gwyneth paltrow','cinemas','reggie','alexis rhee','6','walter isaacson','guy','joan b. lee','gwen stacy','emma stone','mark zuckerburgs','rne lacoste','crocodile','samuel l jacksons','lol golf','kareem abdul-jabbars','rene lacosta','lacosta','kareem abdul-jabar','luka doncic','nor i.','johnny carson','tupelo honey','nick','lisa marie','sam phillips','lisa maries','lol good','kominski method','michael douglas','charlie chaplin','king fu hustle','lance stephenson','stephenson','michael jordon','beat','maketto','chai','jimmy valentines','mark z','breaking bad','nintendo wii','jimmy kimmel','harvey weinstein','casey affleck','john wheeler','leo decaprio','royal','meghan','sweeney todd','gary payton','stephen curry','green','d klay','larry bird','mark price','scott skiles','patrick stewart','cooper','donald jackson','colin mcgregor','spider verse','thomas jeffersons','stephen spielberg','steve spielberg','jim carreys','minnetonka','minnie mousess','frankenstein','s. speilberg','william kotzwinkle','chelsea mannings','clampetts','robinson','rip michael','george w.','too funny','governments','eminem rap song','j.k. rowling','harry potter musical','hough laurie','jon haumm','yea hugh laurie','john coltrane','michael jacson','trane','ravi shankar','tommy flannigan','beeb','walter white','cassandra wilson','respect','halen','lol wow','quincy jones','dimitrius martin','bill murrar','demitri martin','no van halen','mathew bellamy','john fahey','stephen hawkings','haha true','teenager','stephen hawkins','america','matthew','steve tibbets','mary halvorson','marley albums lol','les paul gibson','kevin huerter','mosquito nets','kevin durants','stephen curry ii','kevin durant','wardel','mosquito','lo','stephen currys','hahhaaa','chris paul','clint capela','steve curry','seth curry','mychel thompson','seth','stephan curry','steve kerr','coach kerr','klay thompson','van gundy','draymond green','mavericks','rick berry','kyrie irving','spencer hayward','james hardon','madness','kevin durants','steven curry','ike more','wardell curry','coach van gundy','specer haywood','andrew bogut','akron asap','tim duncans','tim','thatlebron james','klay thompsons','klay','yea steph curry','oppa gagnam style','dwayne johnson','cersei lannister','apropos','guilds','yamaka','louie','baby shark','yea frozen','yea korean','gangam style','lol ..','grammy oscar','robert lopez co-writer','korean pop','kangaroo','kepler-20e','kepler-20f','mark twains','frnd','propeller beanie cap','segey brin','amazon kindle','will amazon','lol thanks','moore','nelson','hunter','vowell','michael giacchino','rich','olivia wildes','olivia cockburn','connie lloyd','kissing','angela bassett','michael b. jordan','mark zuckerbergs','cockburn','reading gaols','futurama','carrie fisher','william shatner','anton yelchin','chekov','arnold s.?','james kirk','picard','james tiberius kik','lance henriksen','bill paxton','gene roddenberry','jack n','bram stroker','bambis','belle','mumble rap','madams organ','adams morgan','linkin pars','michael jackson/justin timberlakes','insane','joanne angelina germanotta','britney spears','loved bradley cooper','iron maidens','yep','scarlett johansson','micheal jacksons','jay-z.','bugs bunny','reasonable doubt','howard stern','breibart','unbeknownst','loch','copy cat','frozen 2','frozen non-stop','dong','amaon','jeff bezos','micky mouse','marpi','lucy lu','rapper travis scott','minaj','a baby boomer','harriet tubman','rosa park','gorillas','caitlyn jenner','denzel whitaker','malcom x.','surprised pink floyd','edgar allan poes','mary shelly','octavia spencer','ellen degeneres','shazam','kazam','billy batson','barry','j.j abrams','viola davis','frederick joseph','chad boseman','ceasar','markus persson','mojang','billy may','devil','steve mcqueen','koren','tale eminem','larry moneta','yea ludvig stigues','j lo','triassic','jacob david','barry trotz','junior hockey','airbnb.','haha man','cardi b person','cardi b perform','wu-tang','childish gambino','minnie me','dopey','gram','wildlife','sifi','joe smith','darrell green','jon','claire constant','lauren flynn','manu','john stewart','anna callahan','callahan','sergio trujillo','bart simpson','cher','lisa','arthur lintgen','beethoven','yep hybrid theory','scott stapp','gael','gael monifils','jim carry','rog','hawkman','steven universe','steven sugar','charlie brown','the lone ranger','collinsville ill','hammer','daniel kaluuya','edgar allen poe','emma gonzales','joan','jordan peeles','daniel day-lewisya vanilla ice','jeff bezoss','ted bundy','pm herbert asquith','johnathan lithgow','not jonathan','cirque de solei','maria exposto','boggles','rob spiderwebs','unlike google','remmy','coconut oii','coconut','banks','natasha leggero','kill fat bastard','blueberry salad','sandra bullock','coen bros','moshe kasher','glenn close','mario kart','deluxe','mario cart','jann mardenborough','muggsy bogues','richfield coliseum','ken griffey jr.','griffey','lebron space jam','michael jordans','good biz','joe camel','haha this','ellen musk','edwards','down syndrome','kalakau','mule','jeez','betty josephine green','breaking benjamin','michael jacksons','snoop doggs','jay zs','andrew gillum','hamilton','lung hockey','shawn corey carter','aka jay-z','jay z. he','jaz-z','katie perry','jay-zs','jam soundtrack','ohtani','john greens','jim carey','billy murray','jupiters moon','kareen','seasons','abby','karl benz','simon','dracula','die antwoord','reeves','merida','john travolta','matt groenings','love frozen','eliza','haha tht','mark waters','barrett','knopfler','mike','ray lamontagne','thiel','green lawncare','wandering spider','jenna fischer','lou malnatis','shedd','jeff goldblum','newman','yorkie','samin nosrat','ramsay','bobby flays','parts unknown','gordon ramsays','bill cosby','carol creighton burnett','harold ramis','ramis','jon lithgow','xenacanthus','eugene','doesnt','e.g. windows','sam altman','cinematographer roger','george r.r. martin','matt patricia','queens brian may','matt','eve-online','joseph gordon levitt','askthebuilder','kinder eggs','organ','grammys','hahhaha good point','battle','gambino','lil wayne','lil waynes','drakes','eminem lol','yeh','julia heaberlin','julia heaberlins','rihanna','charlottes web','aubrey','jenna marble','burgerking','harry potter facebook','maria butina','butina','van gogh','william gibson','earthlings','moon rocks','boaty mcboatface','chao','moon phobos','mjii','reggie millers','larry nance jr','bron','tom petty','button ting','bull durhams','connie mack','jennings','johnny evers','isaac asimov-type','paul simon','guy','damon','the shohei ohtani','brandon kintzler','petworth','brad paisley','queensland australia','mike tyson','ursula vernon','vermin hunter','bert','kinda knew','fermi complex','fermi','jon hamms','toby mcguire','dibs','ellen kemper','dre','giancarlo stanton','mickey mantle','sharon','american gangster','linkin parkss','mixed','wardrobe','lol same','chick-fil','frank herbert','herbert','joe maddon','kaminski','amazon flex','amazon seller','genre','wat','sarah marshall','chaturanga','jesus christ superstar','michael mayer','the boy scouts','katy perrys','perry','george holtz','bocelli','a garth brooks','herod','breeces','mchammer','gates','gnr','steve birnbaum','birnbaum','willie mccovey','hitler','olsen','davis','khe','mike tysons','jazz orchestra','shawn carter','david letterman','renee rosenblum-lowden','shawn','alecia keys','anthoney','jordan peterson','peterson','gary vaynerchuk','emily dickinson','edgas allan','leonardo decaprio','jim','michael stuhlbarg','tubman','amelia eldred','justin biebersbabyis','hungry haha','serena williams','kareem abdul-jabars','snarknado','steve-o','jackass','sherpa','mythbuster','meek mills','kevin hart','meek mill','nicolas','alice','bill ny','kutcher','hewitt','michael bays','robin willians','aladins','nicolas cage','king fu','drew carrey','dean','rowan atkinson','gurls','alicia keysgroundhogs','rocawear','ancient greece','god','cartoon','rapper eminem','speaking eminem','lassie','muhammad ali','ali','paul simons','nacho libre','yea netflix','set','bojack','kindle','newt gingrich','newt','moo moos','helen keller','africn','vs democrats','louie braille','travis knight','marky mark','marty','ronald reagans','vitamin d','brown','fortnite','strangely','creator','renee','jenn mardenborough','henry winkler','jim graham','trunks','elmer fudd','apples','keren weitzberg','language','scotts','lamarr','dgar allan','bohemian rhapsodybill cosbly','mesereau','felt so good','kinda different','st barnard','james buchanan','wheels','christopher paolini','yea 1000 dollars','haha ah ok','gran tourismo btw','gasol','jonas','joran','spenser haywoods','brady','stephs','lol granny','captain morgans','wong','kyle kuzma','harmony','lonzo ball','witch','michael cane','michael scott','carry','grace gummer','jim parsons','meryl','a tony award','meryl steep','dino de laurentis','robot','roboto','stanley tucci','t.','martin luther king jr','malcom x','martin luther king jr.','malcolm x','antonine de la','yea us','hamm','carrey','john hart','anne jones -4700','harris schmitt','gilligan','bob denver','megyn kelly','matt lauer','thin','concert withou','harvest box','bob marleys','roosevlet','pat conroy','robert duvall','seth macfarlane','suzanne scott','macfarlane','bill murrays','frankie','merry xmas','tucker carlson','norman rockwells','j. r. r. tolkien','wu-tang clan','whitman','frost','arent rich','dante','cookie monster','tom arnold','radar oreilly','anthony davis','dan patrick','david west','honey badger','jack white','emilia clark','dolph lundgren','john segraves','les paul guitars','moskovitz','mo','shepherd','ariana grande butera','bird cage last night','tucker','moute','pete davidson','allen iversons','cheryl miller','yea curry','pistons','kate beckinsale','mosquito borne diseases','mychel','mosquito nets lol','whaaaaaat','piggy smallz','adriana','kevin','demon deacon','tegan marie','scott hendricks','tanya tucker','stephen kind','simon cowell','wwo','hitchcock','conway twitty','johnny cash','wealthy','graham chapman','graham','scott strapp','tim allen','hedy lamarr','hely lamarr','vin diesel','john lithgow','steven martin','bill hader','alyssa milana','marvel','jimmy stewart','biber','youtoob','seinfeld','didn;t','slim','stark rip lol','ned','john francis daley','jason bateman','kyle chandler','steve carell','tywin lannister','aria','robbin williams','claplin','rhino','pluto haha','propeller beanie hats','ronald reason','hahhaha funny one','monopoloy','ludwig','run dmc','greta van','bob marleys','tycho brahe','jessie ware','saint jhn saint jhn','jesse ware','jnn saint jnn','jidennna','hoodie allen','jorja smith','blake sheldon','adams morgan movie','kim jong il','alexander hamilton','aaron burr','burr','tyson','spinks','james marsden','joseph s. lacob','peter guber','lebron jamesthe tom brady','benedict arnold','kudy','marcin gortat','scott','doc rivers','devean george','george stanley','daniel day lewis','lebron james','retired allen iverson','damarious randall','yea lebron','kevin love','benedict arnolds','lol less','allen inverson','spcae jam','michal jordan','oldman','orwell','enima-m','decaprio','spike jones','hedy lamar','gary oldman','weinstein','a allen iverson','sandy hook','jazz age','reebook lol','lightning','webkinz','yay','scott tilley','carrie underwood','john denver','rachmaninov','hank williams sr.','seem kim jong un','pokemon lol','alexander','tang','duncan hunters','pres trump','john wilkes-booth','carrier underwood','mike fisher','zack whatshisname','michael cain','demetri martin fan','lolol','brynn cartellis','spensha baker','kyla jade','britton buchanan','kelly clarkson','elton johns','selfie','brynn cartelli','tumblr','eleanor upscale','ms pacman','haha kinda','lyme disease','johnny dep','marilyn manson','wilder','ed wood','bye bye','kailani bailey','brian adams','wounded','mezut ozil','de la','model t.','sashimi','sumo','mother nature','jon haam','a walking dead','glen','john lennon','jacob','esau','bill bye','the nintendo nes','hahhaha go','yea jellyfish','cain','vaping','h. wayne huizenga','wilfredo lee','frances l. lloyd','lloyd','king kalakauas','tarazan','phill collins','fish','bayer crop science','sunions','satsuma','boucherie','art thousoundtracks','happy feet','agreed','dear amy','reeboks','patrick steward','charlie','van halen fan','juan soto','ed','mark twin','tom sawyer','huge laurie','vitamin c.','judy make','jumps','draymond','amy schumer','wonderbah','alec guinness','miami heat fan','billy corben','draymond greens','cousins','gobert vs giannis','jason mraz','jason derulo','duke ellington','rodney dangerfield','stripes','comedy graveyard','pixar studios','eduardo saverin','jamie','shaquille oneal','louis daniel armstrong','kate christensen','shiatsu bichon','walgreen','jim carriy','ryan stile','bromantic comedies','slumdog','cinderella','tottenham','illiniwek','lol netflix','lift carls','edna','craig t nelson','holly hunter','bob odenkirk','craig t. nelson','holly hunters','edna mode','thare','saul','aaron posner','stephen chow','incredible','frozono','steven chow','sally','whe','directer','typo','samule l jackson','michar giacchino','brad','science guy','dave quit','trevor noah','gold jerry','bill nye - the','betty white','directro','the science guy','jack black-nacho libre','grandpa','posner','kin da','edna mowe','duck hunter','edna modes','l. johnson','gyromite','huckleberry milner','jonathan banks','ghost busters','corny','xbox one','tom clancy','ps5','hustle','antonio apostrophe','catherine keener','steve martin look','the brad bird','pres','victor borge','frozone','starr','fav','chill','samuel l. jacksons','b. murray','kungfu hustle','jonathon banks','bob odekirk','sarah powell','sarah','bob odenkikrk','bil murray','wolf','bison','kunfu hustle','duck hunt','good luck','gabriel inglesias','pool','osmosis jones','kun fu','elaine','yep lol','kung fu panda','dolcezza','tofu','sara vowell','kunk fu hustle','aaron posners','huckleberry','dashiell parr','ratatouille','i. bill murray','holmes','woulda','antione de la mothe','piper','catahoula curs','purina proplan','john mayer','haha nice','modelo','carey','ellie kempern','bin','chuck lorre','phillips','the punisher','sara bareilles','will ferrel','erin hannon','waitress','hugh lauries','david grubbs','robert frost','chris cornell','eddie vedder','oral groove','laura vaccaro','hey kiddo','edgar alan poe','phil murphy','ralph carr','spike lees','nuntil latini','meteora','lebron jamess','reggie millers','patriot','owner bezos','becuase zuckerberg','lean','mark zucerburg','chief mouser','theresa may.','meg ryan','mcdonlads','tome hanls worn','larry crowe','benz patent-motorwagen','t. hanks','fringe','password lol','tchaikowsky','unlike facebook','warren','yep - netflix','appletvs','george w','jennifer aniston','selena gomez','justin bibiers','barney','right!facebook','hats','michael moore','mcgovern','descartes','ben franklins','lol i m too','westbrook','robertson','jordan kept','carmelo anthony','jam','etsy','peja stojokavich','henry fords','jack whitehall','walter elias','kissing romantically','cat jack','bobby bones','ryan seacrest','horro','hound','ed sheeran','edward','paw patrol','lois','bezos rich','funny','kyle kinane','paradise pd','reed hasting','amy shumer','jeff dunham','kile kinane','gabriel iglesias','kinane','denis johnson','annabelle lee','greg fisher','froggy','east potomac','steamboat willy','knick','seinfeld',' king','always sunny','mil','j. k. rowling','robert galbraith','jo','john green','james bond','alyssa milanos','scott kelly','scott kellys','ringo starr','kathy bates','bill c.','lucius','reese witherspoon','lol doubt','frasier three','scooter','lp','laptop','jack baclk','pemelope','simile','metaphor','no drama discipline','ripcurl','knw','gaia tellu','alex ovechkin','bill murray','dean martin','michael caines','bert kreischer','duncan trussel','jim carrey wouldnt','joseph fink','danny boy','kimmy schmidt','will ferrell','darwin','salt burns','anne rice','don rickles','wu','adriana grande','buster rhymes','tom hannks','kendrick lamars','donald','jason','pichai','gangham style','george r.r. martins','thee','tanka','haha rick barry','lol lebron','page','brin','a date lab','bruce willis','kevin gates','bobby darin','afflack','gilbert gottfried','a wrinkle','louise braille','elias','mandy','nic cages','nic cage','winston churchills','winston chuchills','bernardo atxaga','walter van tilburg clark','ella','humingbirds','alice walker','isao takahata','fathom dong','had jeff daniels','james franco','the good place','zoe kazan','coen','westworl','john huston','jeff tweedy','wilco','ray charles','definitely charley pride','richard thompson','mavis staples','mostley helium','lewis jrr tolkien','jarrod ramos','arya stark','arya this','julius bjornsson','joaqui phoenixs','i. babe ruth','offseason','dara torres','bryce hunter','gallo','sam','jarrod ramospowerball','bobby v','jon lester','victoria secret','lamb','jessica olivia','goof morning','cobb','krasinski','blunt','ellen page','donald duck','luke perry','w/zuckerbergs','koifish','canine companions','bieber','rap','p. diddys','craig mack','haha ah ya','sammartino','florentine','ricotta cheesecake','prey','beau williams','frances ogradys','nodealbrexit','queen elizabeth lol','william shakespeares','mario klingemann','alex kid','rom','sierra burgess','noah centineo','lenny kravitz','alex malarkey','ann arbor','que opinas del','denise','robert van winkle','pancho','bucky buckaroo','the loch nest','mouse','picksz','gibson guitars','jonah hill','owen','limpet','sun yat sen','yom','john hamm','dave chapelle','cc','lol mine','mardenborough','romero','damaris','bent','nick friedell','jabari parker','jabari parkers','police youtube','walker jr','taylor swiftbill gates','love story','you belong to me','jimmy page','john bonham','immigrant song','ellie kempers','christian rap','battle before','zepp','peter grant','robert plant','johnny unitas','kellan moore','pat','alex smith','brady','rub','amazon alexa','bill belichick','tom bradey','lol michael caine','sam darnold','garoppolo','robert kraft','the blossom kite festival','ender game','germany','enjoy facebook','bookstore junkie','jack ryan','peanut','john candys','charles haley','gisele bundchen','baker mayfield','richard branson','branson','maisel','strawberry','chances','kurt warner','marino','the browns','belchick','jezz bezos','tom bradys','kinda kills','arie','krystal','tia','kendall','roger staubach','chris long','ellie','orson wells war','ted kennedy','shawshank redemption','ted kennedys','m. night','shamilan','lol forrest gump','comedic fantasy','ventriloquist','quincy','superhero','mad max','mythology','fort knox','stewart lupton','iggy pop','hero','varsity blues','monkey wrench','everlong','an edgar allan','jonathan fire eater','patti smith','lupton','john hader','rob thomas','junkie','peggy whitsons','haha ya youtube','rota','arm wrestling','cixin liu','mc donalds','fb messenger','lol ohh','haha paella','iphone jobs','nessi','george hotz','chris stapleton','lynrd skynrd','steven tyler','laurie halse anderson','angie thomas','jason reynolds','moviesin.co','the cloverfield','jj abrams','serviceman','blippi','prince williams','oliver','gangum','ellie kempes','micheal hamm','supermario bros','dan akroid','john belushi','a hardcore','khan','imran khan','bonnie hunt','bradley pierce','tim curry','chris van allsburg','don','jumanjis','beauty and the','napoleon einstein','kevin heart','jar jar binx','leonard bersteins','wolf trap','wagner','etermenanki','facebook haha','wagner','moron','cheetah','sylvester stallone','frank stallone','jennifer lawerence','waterphones','creator','sided football','mickey mouses','gordon ramsey','xavier becerra','senegal','lol youtube','fifty shades freed','luis miguel','will george r.r. martin','lily allen','viserys targaryen','nat geo','facebook ipo','moor salman','mufasa','omar mateen','noor salman','salman','harry lloydn','clup pluse','pete gray','george steinbrenner','yankee bobby richardson','clint frazier','piccard','jake arriets','russell crowe','brainchild','grinch','michael myers','seuss','doh','knew','smart man','gene hackman','dark web','hunter s. thompsons','andrew schulz','jimmy fallon','geoff browning','fort tottens','actess helena bonham carter','herbert asquith','fri','north to fredrick','stephen malkmus','lithgow','lithgow hilarious','cats','theresa may','candy crush','bezo','banjo','sufjan stevens','matthew ballamy','brian harold','edward lodewijk','van haien','paul gibson es-175','tamara jenkins','hollyweird','ian boyd','george mason','vince carter','soap operas','alfonso cuaron','that;s','lol jupiters','ask amy','yea ellie kemper','gene weingarten','gene weingartens','joshua bell','led zeppelins','simpsons - fox','fox extra','tom brokaw','add','steve carrell','green latern','ground hog day','george carlin','walking dead','george carlins','quee elizabet ii','capt jack','alec','peppa','pokemon-go','chris pratt','microsd card','whose line is','buck rodgers','isaac newtons','peter rabbit','lillhammer','patrick oconnell','george washington','kristen page-kirbys','page-kirby','gene','george costanza','depps','ja rule','don lafontaines','mao','kim jong uns','x','christine woods','justin trudeau','hagrid','pedro','mcdonals','billy mcfarland','marshall mathers','sexiest man','kinda weird','kickball haha','hudson','johnny depp leonardo dicaprio','katy hudson','luke bryan','richie','nicole','george zimmerman','trayvon martin','trayvon martins','california gurls','bustha rhymes','yea busta rhymes','yea eminem','doe hugh laurie','staley kubrik','josef fares','remeber','tv','ummmmm yeahhhh','marc','gagnam style','zuckerburgs','michelle tanner','brad johnson','mckenzie stough','robert kahn','vint cerf','kate atkinson','transcription','haha danny','george rr matin','manners','microwaves','emily post','justin biebers','augusta ga','lol linkin','trunk','alex cora','cora','hada laptop','john krasinski','teeth','neil degrasse tysons','ocarina','a quiet place','emily blunt','emily blunts','mcnaulty','stocky guy','miranda lambert','jim carreys','the headless horseman','erin on the office','jimmy webb','wichita lineman','molly shannon','markle','formula 1','medieval','amazo','amazman','andr tchalikowsky','bob hicks','gungnam','lawrence olivier','elaine may','mike nichols','gladys green','lila neugebauer','john hamms','chong','seth rogan','jack daniels','blake shelton-miranda','david sedaris','van wilder','kung fun hustle','levine','jennifer hudson','kennedy holmes','imogen heap','adele laurie blue adkins','lindsey buckingham','mick fleetwood','mcvie','steve kerr milli vanilli','derrik rose','andrew luck','mike campbell','tom pettys','neil finn','heard hugh laurie','beyond g. of t.','king lear','buckingham','chrstine andjohn mcvie','charile chaplins','johnny walker black','elmos','heavens netflix','solomon','rachel','gus fring','ed harris','sidekick geoff peterson','evan rachel wood','thandie newton','james mardsen','thomas the tank engine','starfire','beast boy','john qunicy adams','woodrow wilson','lab','wookie','fox billions','maria','oz','kangroos','lazy :)','sean park','boracay','phil collinsdaft punks','matthew bellame','pete townshend','mattew bellamy','eddie very hazardous','axl rose','brown m&ms','super mario','ted nugent','jason momoa','maegyr','geroge lucas','jason mamoas','night live','charles chaplin','alec baldwin ringo starr','drew brees','kamara','tdr','als9o','harrison smhmitt','silent bob','gregory mcguire','bodega','lauren macellaro','james patterson','rapper eminems','inches','arnold swartzenhager','kanya','lift yourself','milwaukee schlitz','nick saban','cree nix','jankins','michael jodan','tracy ulman','lagron james','dunno','daniel day','labron james','jose conseco','alex borstein','miriam','housewifes','diffrent','henry fords','high laurie','ramsey','soap operas','sienfield','drat lol','homer','von neumann','parks','recreation','jim careys','terry gilliam','hugh llaurie','housewife','katy mixon','molly','christopher columbus','cha','michener','space x.','captain picard','kirk','maw maw','raffey cassidy','vox lux','allen poe','natalie portmans','natalie','jude law','sia','jude laws','baroque','noah bushnell','busters','buster','joe tuner','snicker','alex swanson','joe turner','capitol arena','mcmahon','vince mcmahon','jimi hendrix','jeff bezod','henry','shoes bruce','beiber','jimmy','warmbier','ray haha','johnny depps','will wonka','anna wintour','shih tzu','smart response','zoos','robert mccammon','jonathan maberry','justin cronin','wes anderson','online lol','argus','mat','trey','fisa','mary rich','joel rich','seth rich','ed butowsky','riches','steve harvey','von neumman','halo 2','john cage','david wright','met','warren buffet','buffett','mark zuckerbergs','michael j. fox','family video','rammel','billie holiday','primarily blue','gooooogle','grindlewald','queenie','j.p morgan','behind google','friendster','bob ross youtube','alec baldwins','mom','thos','eddie v.','daniel tiger','daniel radcliffe','robert f kennedy','lady bird','lyndon johnsons','ladybird johnson','hey speaking','burns','vitamin c. got','lol blockbuster','forrest','chihuahuas','haha poor pluto','sesame st.','chromebook','file','eunwon lee','perez','julie kent','kent','john crankos','paula fischetti','brendan','avid','roman polak','roman polanski','cheecher','content','llama','yanny','onahan','bryan adams','hook','celine dion','simon templar','roger moore','sean connery','egar allen','simpsons creator','james howe','academy award','pentatonix','disneyland truman','<cc>','anna jones','big willie styles','liu','knw carol burnett','richard qiangdong liu','judy judy','hobbit','btw haha','tricky dicky','rose','yea pike','especially carlin','matt james','bobby','bobby fisher','reggine miller','jann mardenboriugh','rose mcgowan','bernie mac','haha ya mine','jennifer lopez','joel mchale','battlestar galactica','kinda cool 212','marie','aplle','john perry barlow','grateful dead lyricist','bob weir','john barlow','anything','dan lebatard','coach nick','a le batard','john barlows','jerry garcia','tommy chong','barlow','mourihno','old','bros','chickens','paul hubbard','ia m','jimmy garoppolo','lololol','michael vick','grayson allen','piano paul','jack nickolsen','steven kings','philips','king kalakua','steven marbury','atrick stewart','hasta la vista','kler','bill baily','read hastings','character','rodney king','hail caesar','killer','a justin timberlake','usher','fred astaire','blockerbuster','rebok','taylor hickson','wong howe','nicolas winding refn','susan luchy','spencer finch','beofre u view','george jones','karaoke','michael stanley band','ally mcbeal','teh moon','the king kalakaua','joe hisaishi','faster','gretchen','homey','daniel radcilffe','mohammad yousuf rasheed','fantasy drafts','sheldon','fisherman','haha dalmatians','bedbugs','jaws munchs','abdul','yea james naismith','paul george','me kate','lefty driesell','john thompson','surprisingly pocahontas','judith','ref','scott brooks','otto porter','john wall','klayb thompson','reggi miller','shakesphere','james wood','haha ya like','evan almight','dick francis','bill murray leonardo dicaprio','johnny depp lol','kinda meta','les paul','cohen','dan akroyd long ago','conan obrien','karl malone','patrick ewing','benjamin morrow','martin fan','winsont churchill','furry','lol hmm','eddie grant','alex morgan','richard bachman','mike tyson lol','kris draper','unlike lebron','mike scott','rapping keeps','faith hill','reggie miler','jim naismith','steve smith - great guy','deandre hunter','take tim duncan','james naidmith','multiplayer mode','bram stokers','slasher','alfred in','proper','keaton','kenny g','zombie','woody the cowboy','mr benz','ron livingston','holly slept over','hug laurie','reg','shooting granny','larry byrd','tweety bird','charles barkley','lol good old','marie kondo','trevor james','johhny depp','shipping','edward cullen','smash bros','bill murray combined','johnny jepp','lol julius caesar','eric','talia','no king kalakaua','daughter','fennec fox','alfred kinsey','nunti latini','bradley beal','aleen iverson','chadwick bosemans','jack kirby','surprised tim duncan','will ferells','j r smith','remington','jr smiths','yes rip nintendo','pythagoras','aurelius','robert mccammons','swan song','robert heinlein','haha yes','jedis','gerge lucas','km','dwyane wade','dwyane wades','rumba','bachata','james earle jones','david prowse','patrick stewarts','lol good point','don draper','hahahahaha imagine','uncle dave','lol drama','james bond-ish','tricky dickvitamin c. well','tupacs','drai','rye','dennis cyplenkovs','mach mans','kindred','bobs burgers','online wu-tang','phil','twilight','burnett','lionel messi','balloon','trey parker','the walking dead','daniel radcliffes','kate','meghan markel','kate middleton','luck','bumpkin','de la mothe','kinda ugly','jesse hernandez','jessy','andy kauffman','co-ed','haha nice segway','brahms','anthony dj hollywood','chuck e','steve martins','gregg','amazon','amazing grace','alan elliott','alan elliot','leonardio dicaprio','matt bellamys','amazon customer','yep netflix','kohls','ted bundys','kim kardashians','robert kardashian','o.j. simpson','jennifer nettles','ice cube','lol starship troops','art','glue','chrismas carols','lowell weicker jr','weicker jr','bush jr','yummmy','milky','sheeran','adult','suckerpunch','no bruce lee','mcds','haha movie','army xbox','whew','kevin costner','lol someone','hellen keller','helen','martin luther kings','kinda slow','nordstrom rack','goodfellow dry goods','google hang outs','before google','nellie belle','bin laden','every st','patrick','daniel benoit','bench','alexander graham bell','alina zagitova','tiny toons','carl schuhmann','andrew finch','buderi','michael jacksons ip','charles manson','kareem abdul-jabbars','gail monfils','wii tennis','joe hamm','all blacks','grass','hoops','sparky anderson','jim leyland','john mcdowell','mr zuckerberg','amber alerts','jeff besos','david copperfield','oy vey','nick cage','boardwalk','hubs','lol smh','julie louis dreyfus','romney','dwts','dustin offman','hoffman','tom bergeron','nikki glaser','mary lou retton','cdwts','juan pablo di pace','kimmy','lady grape','lady grapefruit','angelina germanotta','iron maden','buick rainer','antoine de la mothe cadillace','reading','jonn mardenborough','yea an english guy','tony perkins','homer wagner','the az diamondbacks','goeorge strait','yall','avril lavigne','woos','fro teh','optimus price','franklin roosevelt','steven hawking','ruth ginsberg','rookie','ben simmons','donovan mitchell','simmons','charlie parker','spiro gira','kenny g.','starter','dominique wilkins or clyde','spencer','barack hussein','wynton marsailis','tim nelson','denny','hymlec','jadakiss','merry melodies','haha hmmm','yeit','sigh','blind willie johnson','kareem abdul jabbars','kane','genus','breaking good','rutherford b hayes','diane','frank zappa','bob dylan','nils lofgren','bonnie raitt','elvis costello','quantum leap','the holograms i saw','jann mardenborugh','ltworld','george straits','angus young','scwhetty balls','will farrells','marty allen','zlon','caesar salad','ur kareem','wade','lol thats','martin allen','berry','eisenhower','stan van grundy','tricky dick','carl benz','john quincy','jefferson bible','bull bailey','jack somebodies car','tinny','addy','haha groovy','wallace lynch','alpha browsers','freebooting','valve','dwayne wades','jimmy butlers','tom thibodeau','cool stuff','michael beasley','zion williamson','williamson','james naishmith','colby bryant','dan gilbert','jayson tatum','ciao','grizzlies','jayson tatums','space jam ;) lol','bo jackson','lol did','brent kavanaugh','kareen abdul-jabbars','jeff green','kareem abdul','tall','kareem abdul-jabber','j.r. smith','james hardin','kyrrie','james naismithn','jam sequel','air jordan;s','luke walton','james naismath','charlotte hornet','jason kidd','kidd','trader joes','dan patrick show','david robinson','david stern','klay thomas','stroker','kraniski','wasn','paul mccartneys','enjoyed car talk','maria lucas','james earl jones','dames judy dench','helen mirren','orson wells','moonlight sonata','moonlight','bryce','cary fukunaga','peter meyhew','tanaka','piano man','earl jones','dwight yokam','george gershwin','todd duncan','gershwin','hmmm ariana grande','stephen king movies?n','saporo','gal godot','tucci','movies.n','dino de laurentiis','mary louise','nick young','de niros','mikael kohler-frost','walter','vp platain','kim jung un','thor ragnarok','kim yo jong','lol hillary','the king of amazon','charlie pride','crispin glover','george mcfly','blake shelton','dis','swimmin','kimm gwang suk','omgosh','phang the snake','new mascot','daniel radcliff','skinny jeans','levi strauss','ying yangs','bob dorough','sugar ray robinson','john wilken','kids','jacob w davis','steve b.','billy bob thornton','robert redford','forrest tucker','robert redfords','sissy spacek','carrie','danny glover','the old man','specek','spacek','green book','telly savalas','bertha','lou pinella','jess mendoza','joe romano','john sawchuk','beiber fan','adsense','bobb ross','skyscraper','ben stiller','a ben stiller','chard hurley','lucky','imagine trump','obamas secret','hussein','drivethrus','michael j','griffin','kim jon un','kim-jong un','david muse','studio','andrew lloyd webber','sophie ann caruso','charles chapplin','hahha','micheal caine','bil nye','mickey mantle rookie','moe berg cards','ellie kempner','yes - carrey','top gun or the color of the money','bryan brown','doug coughlin','kidding','parker','popovich','manu ginobili','win win','rayman','dustin hoffman','christopher mccrory','tom cruises','def','jada pinkett','sandy duncan','elaine herzberg','judy lol','michael bolton','heddey lamar','humm','james a mirrlees','mirrlees','doug mackenzie','jerome robbins','michael ondaatjes','kurt vonneguts','warlight','hahahahaha yes','shirley jackson','a kareem abdul jabbar','joanne boyle','thomas the','yep alec baldwin','dwayne wade','the nba','andrew','the queen mary','matthew weiner','mad men or the romanoffs','the john ham character','billy nye','j.r. smiths','larry obrien trophy','j. r.','iggy azalea','jim dutcher','hedar','barak','ahh ok lol','obamarama','obamas destinations','john glenn','jaimie','expo','gary c. robb','tony batista','alfonso cuarons','knoe','kareem adul-jabbar','philip grubauer','braden hotlby','phillip grubauer','jim mattis','frank black','seymour bernstein','philipp grubauer','bobby hull','gordie howe','cajun','orson welles','bruce lee knew','bob wills','roy acuff','mickey gilley','jerry lee lewis','hillary duff','kristen bell','hilary duff','benz patent motorwagen','ethiopias','top chef','mukbang','the creator','seahorses','yea dark side','atlas','louie armstrong','kid cudi','lil peep','model t. american','i. bill nye','gran-turismo','mario golf','sam jackson','mega man','metal blade','michael boskin','kalaukauau','uncle sams','ill do','honk','hybrid theoryj gordon levitt','arctic monkeys','dove','patrick stewert','micheal cain','philip defranco','roseanne barr','carl burnett','karen slaughter','louise penny','becky masterman','elizabeth george','linda castillo','elvira','vh1','soutpark','nicholson','metalica','macho man and','oooooohhhhhh yeeeeeaaaaahhhh','mark epstein','homer sec','maggie','grampa','lol elon musk','wozniak','cheryls shadow','abdul jabbar','free throws','lol jon stewart','don stewart','gylfi sigurdsson','lol football','daniel radcliffes','brandon sanderson','grandson','gratiot','wow eminem','goerge lucas','a homer simpson','weiss','pokeman','yea hybrid theory','dierks bentley','glad trent','harry connick jr.','john maynor','harry conick jr.','john mayor','sam cooke','dierks bently','chevelle','dierks bentely','led zeppelin iv','the eagles greatest hits','hootie','greedionaire bezos','scotty mccreery','trent harmon','hank williams','rucker','scotty mccreerys','john deere','ozzy','won idol','winton marsales','debbie','james taylor - they','james taylors','gemini','lol gemini','george stait','wallace','maya angelou','sam barsky','dorothy steel','penny marshall','andy serkis','andy sirkus','lupita nyong','anime','fidel castro','kim snapchat','peter parker lol','erik larsson','chuck pahalniuk','kellen moore','russell wilson','goon','seann william scott','brian cranston','sputnik','alec balwin','gerge carlin','bbq ribs','tasty haha','millie bobby brown','finn wolfhard','yea blockbuster','elfen lied','chris farley','edward cullenn','steve bochco','norseman','james dean','marilyn monroe','a-rod','john wilkes booth','jfk washington','honest abe','orchestras','carlos miguel prieto','emily clarke','ballerinas','tori amos','morena baccarin','jesse l martin','law','overly','marry shelley','prometheus','greg berlanti','andrew kreisberg','geoff johns','barry allen','debra fordham','les misrables','les mis','tom vs time','tec the tractor','cherry trees','mike pompeo','pompeo','fred rogers','kim john un','kim johng un','strom thurman','blackberry','michael cohen','jessica drake','mahi mahi','james buchanans','sue','oohhh','casbah','michelle obamas','peter the great','catherine the great','nicholas ii','romonov','wash','gran tourismo','facebfac','lena dunham','a s. martin','johnny english','e. t.','the wizard of oz','kinda creepy','trey anastasio','paul reed smith','ree','granny style','carol','shazbut','grant theft auto v','lacey jonas','lindsay lohan','lindsay','pinedo','condi','mark zuckerbers','cannan banana','tom selleck','chuck taylor','chuck taylors','grey','nurse jackie','the granny shot','reggi millers','jury duty','another space jam','banana haha','will farrel','reggie bush','gyro','wish','patrick stewarts','tim duncan?n','bet spencer haywood','yea the','chris wallace','yea ronald regan','doy ou','lol do','pashinyan','koalas','japan.it','leah remini','top gun','lemont cranston','d. trump','endless love','jerry seinfeld','roosevelt','aubrey drake graham','hello!so','kinda..sorta','snoop dog','crdi b','cardi bs','amanda prestigiacomo','michael flynn','vp clinton','hello lets','crocs','mike pence','moscow mule','elisha manning','giselle','cooper manning','logan paul','drew bledsoe','blake bortles','nick foles','archie manning','dan snyder','jason taylor','julian edelman','mcmaster','mix 96.9','serzh sargsyan','dominique wilkins','r-g colorblind','haha good','abraham','david williams','leonard thomas','david wolkowsky','ballast key','barbara bush','snow','zebra','gungam','richard peabody','.i','ernest hemingway','explorer','beto','nepotism','andrea mitchell','larry hoover','yeezy','tmz','salah salem','lol netflix','mst3k.','murphy brown','bram stokers','puttin','switch','arie luyendyk jr.','keith hernandez','gary carter','keith hernandezs','keith','padres','kaptain kangaroo','rin tin tin','dick van dyke show','jackie gleason','johnny weird','tara lipinski','johnny weir','suzanne collins','clarissa','stanley kubricks','whale wars','cartman','jonathan swift','lyndon johnson','connie chung','iwould','peppa pig','halloweens','scare','facebook messenger','allan poe','antoine de','8am-10pm','mancheter united','d.c. united','hank scorpio','tom jones','diana gabaldon','starz','larry nassar','rosemarie aquilina','brialle','elvis aaron presley','pelvis','van morrison','babadill','peter jackson','adriana lima','winnie harlow','spency haywood','taylor swift song','khaleesi','jahn mardenborough','michael jackso','pandora app','blaire watson','wowza','kinda pointless','mopeds','condoleezza rice','college basketball','tim duncun','bryant gumbel','condolezza rice','tim ducan','n.korea keeps','kareen abdul jabbar','gumbel','kinda funny lacrosse','yea hockey','plantain','john roberts','hillary c.','james madison','fed ex','enjoy elton','go stanley cup','mitch albom','morrie','cleo','trumps vp','socks','james cook','charles krauthammer','krauthammer','bananda','an infinite jest','chow cup','chow','can george strait','alex baldwin','tanakh','babal','grom galveston','tavis smiley','blake','guttenberg','mark z.','adam levine','benjarvus green-ellis','kut','georges w bush','robert ebert','bill clintons','monica','goofy','roger ebert','antoine de la cadillac','kinema','mona lisa','martha stewart','the mona lisa','leonardo da vincis','mona lisas','da vincis','martha','hugh luarie','mark e smith','mturks','chick','looked','google sundar pichai','jack nicholas','manhattan','enrique chagoya','ariana grande-butera','ariana grande bulera','grande butera','renate alumni','haha the white house','w bush','ben afflecks','jennifer garner','extra','matt damon','hugh laurie earns','a google ballon','yupp','donald trumps','josiah wise','michael mann','hot wheels','belgravia','schmitt','especially zeppelin','childish gambinos','karen dawisha','samuel adams','jennifer higdon','riccardo muti','carol mosley braun','burkina faso','ira levin','julius casar','george rr martins','fredie blom','blom','denton young','fridie blom','arles','lol ttyl','space x','linux','leon kagarise','patsy cline','leon','apu','reed hastings lol','don owens','c&ws george strait','hoss','pete munks','ferguson mo','rober mcculloch','darren wilson','michael brown','mcclloch cam','mcculloch','mccolloch','democracy','whaaat','wigg','christine wigg','blair','monticello jeffersons','kristen bells','john adams','dang lol','carlos curbelo','curbelo','b. rhapsody','eric garcetti','giuliani','john f. kennedy','mark cuban','american dad','cheney','dick cheney','christian bale','cannan','cheeto','jefferson washington','jon wilkes','thurmond','misty','meetups','benjarvis green ellis','snyder','the top banana','melania trump','margaret kenyatta','tbtgd','kim kardashian wests','john wilkes','kim k','haha-so','fighter','rush limbaugh','foxhole radios','randy moss','shoud','bill belick','bill bellichick','fran trakington','engineer','yang','jim kelly','patrick mahomes','mack','lions','u of m','trey flowers','bill belichicks','yup tom','jags','gronk','tom landry','roger starbauch','bellichick','bill blichicks','doritos','yu','lifetime','willie nelsons','buddy','isaac hayes','scientology','kim jong-nam','alice cooper','persepolis rising','antione de la','glad w','john legends','sara barielles','wu li masters','tao','coach marvin','doug williams','steeler','ben roethlisberger','robert griffin','jack nicklaus','the king of kalakaua','teddy rosevelt','chamber','yup screwy','aaron tveit','catch me if you can','foo fighteres','ashton','elie kemper','patrick stuart','de','yep southpark','mohammad','yelp the simpsons','kimmy k.','antonio de la','drive thur','macdonald','stephen hillenburg','lou gehrigs','seth rogen','scarlett johansen','smelly cat','ben jarvis','guy episode','jerry influence','taht patrick stewart','little','stephen hillenburge','the white stripes','wizard of oz','yea steve martin','mediums','youtube video','judas','benjarvus geen-ellis','enjoy','jazmine fenlator-victorian','jordan greenway','county clare','vegan','nintedo','roger d','kermit gosnell','randolphs','keanu','elliot','jean luk piccard','limp bizkit','would trump','pharrell williams','unique','whig','frances mcdormand','kobe bryan','a jesuit priest','harrison schmidt','john vo neumann','frozen dvd','carl','officemax','yea bambi','carl','ronald regean','ash ketchum','yo enjoy dramas','micahel caine','sister taxa','ther','cocaine','hunt','james taylors','buicks','charles leclere','lynyrd skynyrds','king george','lynard synard','david gilmour','richard wright','sydney pollack','a wiz khalifa concert','andrea bocelli','benjarvus green ellis','terrance howard','haha mayor monkey','hot line','john paul young','drak','jane fonda','fonda','ed helms','hannah gadsby','wet hot american','chaplin','buster keaton','vincent van gogh','willem dafoe','twighlight','dennis miller','teh ref','caprio','the pres of indonesia','kinda stuff','wee','sameuel l jackson','samuel','slim shady','trl','month python','king arthur','hayden fry','tim tebow','glen frye','anthony dj hollywood hollaway','xxxtentacion','avril levigne','trunk lol','qualtrics','cuspert','bone thugs','lose yourself','camaro','greeks caesar','dee snyder','jerry stackhouse','jordon','roadrunner','buster bunny','dizzy','philip savopoulos','savvas','today aloud','rich dad','kin jong un','sonny bono','maria bueno','king jong-un','rocco baldellis','bueno','gael monfits','button lol','willie nelson','timmy thomas before','mario lopez','mike golic','zach','david hogg','hatred','jimmy carter','m guessing jfk','teddu roosevelt','aristotles poetics','elizabeth thorp','chelsea hodson','essay','rent a car','avis','albumhybrid theoryis','norma hopcraft','kristin budinich','haha :)','hybrid theroy','m.','arne duncan','billy moore','tupaq','lana del rey','ben carson nick','jeff talman','w. wilson','loretta lynn','lynn 1st','juventud unida de gualeguaychã¹','starship trooper','dennis kucinich','dog','ann jones','norman rockwell','larry kudlow','mmbop','jim knoblach','eduardo saverine','paul manforts','laporta','lol yep','tiger','home simpson','steve huffman','alexis ohanian','pat holmes','nessy','benjarvus','dammit kirk','maga 2020','skarsgard','olymics','madeleine albright','glass joe','jar jar','something george','mark hamell','darth maul','glad mcdonalds','colorblind humans','james mardenborough','claire','dede','jays','tom robbins','pizzagate','liz crokin','chrissy','crokin','teigen','lou malnati','matthew mcconaughey','richie merritt','wershe','detroit','andy weiss','logan miller','noah miller','warcraft','bruce dern','cliton','clump','wu tang','james browns','muhammad alis','m&m comix','james haha','mohammad ali','busa rhymes','cam newton','hunter s thompson','andrew jefford','clysedale horses','blueray','kirsten nielsen','kristjen nielsen','thomas the tank engine fan','hairdo','manuf co','kirstjen nielsen','deep purples','concert lou reed','michael thomas','pick','rosa parks','sharpton','rev jesse jackson','smoky robinson','isiah thomas','matt ryan','arethra franklin','cindy hyde-smith','rottentomatoes','feinstein','ask trump','harry trumans','al franken','dick chaney','hawk','agnew','comey','3rd jefferson','zimbabwe mr banana','barbar mikulsk','michelle','glad trump','m. kirkland cox','stilll','zodiac','toschi','storm alberto','actress hedy lamarr','king k','weeee','phd abd','a buzz lightyear','meagan duhamel','eric radford','duolingo','keagan duhamel','duhamel','kindof','caroline','obama haha','sultan','skins','trumps lawyers','haha sound','tredeau','o.j. brigance','chanda','tom garrett','versailles','comey','john harvey kellogg','eco','deborah borda','van zweden','classical musica','lol great','virginia emili mcphail','jefferson jfk','r-ky','scrooge','trump clinton','saxophone','heather locklear','heather locklears','rain man or born','melrose place','richie sambora','matt harmon','matt stone','matthew sweet','jeremy roach','john w booth','magic johnson','will bill murray','lemay','carefree','codias','schumer','honorary phd','alexandria ocasia-cortez','barry goldwater','trump towers','john mccains','ally mc beal','gangsta rap','malawi','mindy kalings','snarky nerd','mindy kalling','charizard','twilights edward cullen','w.','albama','bejarvus green-ellis','sherrilyn ifill','natalie hopkinson','kimberly crenshaw','george hw bush','john quincy adams did','mike pences','tory bruno','space xs','ben shapiro','tump','jfk jefferson','really banana','teh whigs','harry nilsson','yore','justing biber','suff','william howard taft','anne royall','william taft','dwight','michael scott character','hope hicks','john f kennedy','peas','mike rogers','didy','no george w.','carrots','turkeys','loveline','malcom gladwell','benjarvus elis','kavanagh','hillary working','ayn rands','marine serre','phil colins','alicia keys song','far 3700 mil','chris dewolfe','eventually mark','dion','harder','eulas','liek amazon','ricky bobby','clifford calvin','conductor','james hoban','bias','idiocrasy','yea michigan','nfl rookie','forgetting sarah marshall','yea myspace','michael wolff','carmen','timon','dan aykroyd','roseanne','lol gore','paula vogels','ferb show','lol','lesh','garcia','john petrucci','steve morse','vanden plas','david crosby','rob zombie','haim','columbine high','richie blackmore','gee wiz','yoou','tony soprano','james gandolfini','soprano','polemon go','gandolfini','david chase','alfie','rodger','tim cook','tim apple','helena bonham','ppl fantasy','derrius guice','mcneill','anthone de la mothe','jim hensons','sydney loofe','nevermind','prom','lol .bell','benny hill','kolbie sanders','maybot','spinach','daniel day lewislethal weapon','kellyanne conway','bret beier','kellyane conway','ali baba','bezos for','juana the crazy','pete carroll','dback','dhe','munchhausen','matt patrica','curt schilling','vie','jack pearsons','extant','bily sianis','ben','ww3','aladdin','roger stone','donald trumps','haha ya exactly','hulks','jeffrey dahmer','carol nburnett','see emily play','emily','wayne gretzky','rod stewart','rod','bana','hire','google map','ill eat grass','john mardenborough','cool!i','julianie','colin farrell','ypou','canadien','diode razor blades','jon mammskareem abdu-jabbar','grandmas','hugh laurie time','jordan shoes','john wicks','abdul-jabber','rudy','starry eyes','wicks','mary chapin carpenter','shaqille oneal','wall','intro drama','the dalton bros','hank williams jr.','siouth park','flowerrs','kenny chesney','were','keys','campaigns','granddad','a george strait fan','amphitheater','probably george strait','henry fonda','moseley-braun','melissa etheridge','whitney houston','s creepy','yea polanski','taiking','washington jefferson','stephan fry','woody','carlo burnett','opps','tolien','mark manson','anne bogel','julian rubinstein','alexandre dumas','johnny bobbit','bobbitt','take allen iverson','gran torino','stan van gundry','facebook hahaha','facebook jay zs','snoop lol','yea one','mark griffiths','daria kuss','lisa byington','sooo long ago','jon stewert','mesut','yea georgia','alex jones facebook','david beckham','cristiano ronaldo','oguchi onyewu','quentin tarantino','albert hofman','phil neville','surprising','benajrvus green-ellis','eryk williamson','eagles fan','bill bradley','pennsylvannia ave','haha thats','james shar jr','teddy roosvelt','jos roozen','roozen','good jeopardy','gearge w bush','george w bushs','saddam hussein','jared as','walter kronkite','pick kanye','a mt rushmore','peach','craven','franklin graham','lowell weicker jr.','j q adams','t. roosevelt','niger','bach','braham','mccarney','trumps ex lawyer','caanan banana','hugh laurie 700','0','imagine hilary','ledzep','donald j trump','neon lion','essa','jarrow','paul d hubbard','tom bradys','calvin johnson','carson palmer','jimmy graham','bill b','tome brady','tele anymore','squirtle','madden nfl','lebron james 101','lebron james high school','okie dokie','peter careys','peter carey','volkswagens','yep ford','victoria lake','guest','enjoyd chattin','children of the corn','haha classic','merriam-websters','merriam webster','indy','merriam websters','fes','thurman','mia hamm','womane','loris karius','dogs to cats','elections','dee see','john kennedy','a t rex','gorrilla','jeff ross','standup','dianne feinstein','richard roeper','sanford son','fyre festival','jared dunn','zach woods','michal jackson','yo kow','hous md','ryan styles','micael caine','elle kemper','congeniality','haroldand kumar','andre braugher','sandler','fine ty','man','shepards','the penguins of madagascar','jena marbles','darn patriots','true lol','carson palmar','calvin johnsn','payton manning','yen','bill cobsys','scott walkers','ross perot','michael tomasky','anti-eminem','andre burakovsky','plow','stephan currey','burakovsky','kevin plank','cute','dan','heady lamar','haah good point','teh amazon rainforest','lake tahoe','presiden tbanana','knockoff','richard ales','micheal cohen','trump cheeto','sao paolo','richard aliles','adrian peterson','almost as','millie','jeb bush','mildred','george bushs','springer spaniel','wayback','glad fox','kang','kodos','web','robocop','i. michael caine','the antonin scalia','scalia','andrew mccollum','mark daniels','jessica watson','bart simpsons','billie jean','video','kim jong ung','anthony wiener','jalen remsey','r.r. martin','paul verhoevens','justin noeners','daisuke matsuzaka','alec baldwins','gipper','daisuke','steve martin lookalike contest','big bird','eric jacobson','piggy','grover','spinney','jacobson','kirpik','billy preston','ringo stark','motorcycle crashes','car-rambo','erin hernandez','gheorghe muresan','muresan','wbna','debris','patty','paula abduls','paula abdul','christopher reeve','lamar jacksons','felt','marthas table','jeff bezzos','patty stonesifer','stonesifer','yea michael caine','laugh laurie','not dead','pokemon sun','pokemon moon','hiilary','waashington','lol making','john tesh','detective jacai colson','taylor krauss','colson','krauss','tidal','geek','commons','jaime','gary clark jr','quincy adams','kimba woods','hughley','celeine dion','hannah baker','hanna','blackbuster','hemlock grove','katz','h jon benjamin','eric foreman','jason statham','craig counsel','yep - craig','loved jr.','sean mcvey','rams coach','grienke','right?','david zeng','mike yang','jrue holliday','georgie tech','liverpool f.c.','gene simmons','sun tzu','washignton','drudge','anti-trump','twittering','zeng','michael irvin','charlotte rae','joh hamms','bone cancer','vitamin c. lol','mirrors','michael carbanaro','bush sr','richard goodwin','richard n. goodwin','dick goodwin','lyndon b. johnsons','g. w. bush','the wall of the south','batd','especially family','only kellan moore','feb','lol bird','pokemon super','james hugh','monica lewinsky','greg krading','josh duhamel','marcc rose','wavyy jonez','b.i.g','liam neeson','john quinicy adams','teh bible','moses','green ellis','chris rock','kill the messenger','chris rocks','tamborine','bo burnham','chris rocks','anthony dj','rob base','gerry','timothy coggins','mcdonald','bing crosbys','doris burke','d12','ben raby','marconi','anthony holloway','haha shaq','wu tang clan','doc emrick','joe beninati','nichols hardware','nene leakes','norm macdonald','ringo starr george carlin','vigo mortenson','tinashe','shawn grate','hasselhoff','haha spanish','pickles','rudolph','true rudolph','pookie','nermal','patricia','melodrama','barkley','duff','dear abby','alexander bain','andy kaufman','kaufman','andy','msut ozil','colin kaepernick','justin beibers','woodrow','brent cobb','shooter jennings','kellie pickler','brent cobbs','providence canyon','allan iverson','especially croatia','hannibel burress','nexflix','hannibal buress','latini','sidney hillman','justin beiber canadien','loncoln','pop quiz','guatamala','marx','twashington','brains','honey sherman','kimmie schmidt','th sipsons','fox nudes','lebowski','symphony orchestra','archbishop theodore','pope francis','mccarrick','dinardo','banana lol','martin short','captin ron','burt r','burt reynolds','wind gap','james melville','joko widodo','huge lorry','steve bannon','model ts','justine bieber','genghis khan','joseph e. hall','jay gruden','alex smiths','jj watt','abbi jacobson','judy garland','cliff huxtable','drew carey funny','robin harn','knockoff legos','robin williams - do','guinness record','dakwandre marshall','jack forsyth','snoop doggs','dummys','zucherburgh','kaepernick','graf','martina navratilova','ellis','joel embiids','joakim noah','mike conley','stevens','evan turner','kyle lowry','joel embiid','fav nba','phil jackson','marcus','scott pruitt','bunny','lol yes','tracy ullman','reese','haha randy moss','kurt warners','ashton kutchers','john ritter','zika','pokã©mon','michelle wolfs','justin biber','billy graham','janis joplin','janice','sergey lavrov','kelso','daniel wann','jason lanter','levels','','sandra parks','halsey','apparently bing crosby','jonathan bennet','bennet','mumps','vp hillary','hannah','banana btw','emoji','ben carson','joe k.','trent williams','haha hed','definitely payton','kellan moor','paul d. hubbard','manning','david carr','lupo','kirk cousins','yea eli','philip rivers','a superbowl ring','clemson','brad johnsons','sportscasting','no bing crosby','gov ronald reagan','george h.w. bush','keelen moore','aaron rodgers','kellan mooreis','junipero high school','baker mansfield','aaron rogers','mike mccarthy','brad johnston','hue jackson','aaron rodger','alex van pelt','hoboken jets','hoboken','kickoffs','russel wilson','brayd','quarterback baker mayfield','junipero serra','rodgers','tomlin','antonio brown','brett favre','w. bush','neo','lol sometimes','boh','the george w. bush','emmanuel macron','nicolas maduro','randy savage','motorwagen','hunter burch','neil degrasse tyson','jared lorenzen','bertie','bellicheck','spider-man into the verse','leonardo','junipero serra high schools','another bo jackson','wolverine','mitch trubisky','tom benson','brett farve','redskins rookie derrius guice','jhane garner','saquon barkley','bronco mendenhall','jeff thomas','baer mayfield','larry fitzgerald','ring starr','denis cyplenkovs','lol plato','molly smith metzler','kramer','no troy aikman','vick','iowa hawkeye','jeff george jr','jay cutler','alec baldwins','rich haha','should trump','orange haha','samuel i. jackson','volley ball','michael vik','usually sirius','delay','usually youtube','kennedy history','lincon','ray donovan','lol sounds','teh length','ryan finley','tony romo','roger gooddell','benjarvus green','ken niumatalolo','dexter williams','khalil mack','tim tebo','warren moon','rubgy','richard sherman','sherman','gren ellis','this doc bonner qb','teamwork','maryland uni','hhah','yeeeeah','bama','bilichek','left handed','ym og nes','jupter','emily strayer','martie maguire','joe rogans','dean delray','led zepellin','sweet caroline','neil sadaka','elton john song','sebastian vollmer','bill bellichek','bilichick','foles','mcnabb','andy reid','reid','sullivan stadium','bill belichik','steve young','benjarvus ellis- green','hilton','odel beckham','sony michel','lawrence guy','geroge rr martin','andy dalton','norv turner','mel kiper','ted tebow','bortles','doug marrone','belicheck','fitzpatrick','lamar jackson','tyrod taylor','lol baker','johnny manzel','kelan moore','perhapse','tim brady','tim brandy','hillary obama','kirt warner','dana patrick','carson wentz','eagles wentz','roethlisberger','qb russell wilson','cook','tommy','haha carson palmer','coach gruden','colt mccoy','josh johnson','terry bradshaw','kellan more','jerry jones','jalen hurts','belichick lists','dang good','ho','alvin kamara','marshon lattimore','mat patricia','malcolm jenkins','malolm jenkins','thomas edward patrick brady jr.','belechick','trubisky','kellan moore btw','ypu','tom brad','elway','kelley','giselle bundchen','will justin','kyler murray','gisel bundchen','morse','andrew wheeler','swamp','jerky desk','lol k.','jame naismith','george pelecanos','redskin','alex rodriguez','rendon','sandy koufax','yom kippur','haha yup exactly','sheldon cooper','dale earnhardt','earnhardt','dale','besides trump','bush jr.','willaim henry harrison','susilo bambang yudhoyono','jan','bulbasaur','kink kalakaua','urkraine','carmel','gump','kim ju','yumm','jason clarke','ted kennedys','mary jo kopechne','kate mara','kopechne','chen xiaoping','chen','guo wengui','guo','shohret hoshur','qb brady','colton mccoy','kuddos','colt','mccoy','duterte','vox','rajapaksa','actress helena bonham carter','afterall','toms','qb alex smith','qb brad johnson','betsy ross','rob gronkowski','wolf stops','cassius marsh','marsh','joe namath','colts','jim palmer','lii','gronkowski','coach belichick','danny amendola','personally green','kristin cavalari','kingpin','triumph','antoine cadillac','colin kaepernicks','friendy','owen vaccaro','cate blanchett','eli roth','polands','picasso','pauld d hubbard','pod casts','bull murray','democracy longterm','rick wakeman','abe linchon','balkanized','georges soros','imagine clinton','barron','pitbull','seems fox','bahahahaaa','lee greenwood','sometimes ill','roger ailes','geography','jumpiter','justin beider','laura ingraham','trumpism','ann coulter','anti-clinton','nuntuu latinijupoiter','alessia cara','neon dreams','chris gronkowski','poeple','jimmy kimmels','monkey','diamond','riverside highs','coach sam plank','az diamondbacks','az cardinals','raider','yea alec baldwin','thomas the train','antoine brand','justin herbert','thorson','madri gras','tyreek hill','josh norman','niagra falls','jupiterhas','jaylen brown','allen iverson 800k','micelle obama','jennifer hudsons','mool','love j. hudson','nicole richie','biryani','donkeys','indoneasia','vaya','jim kelley','know2','beard haha','woodward wilson','mc allen tx','geogia tech','deshaun watson','jarod goff','jeff fischer','robert woods','joe montana','yep georgia tech','brady 2','terry pratchet','terry looong','jimmy g','josh allen','ridley','halo 1 and','lindsey graham','john brown','playoff','calvin ridley','luke kuechly','trump jr.','anderson cooper','sarah huckabee sanders','jeff flake','rep comstock','rep barbara comstock','shak hill','amplitude','frequency','hz','russell wilsons','glenn','pai','woodrwo wilson','buick hearst','anna olson','celine dion lol','justin bieber lol','bing was great','team hillary','the circus galop','lol the white house','pittsburgh dad','larry kudrow','corallo','raegan','bananas house','kimmy carter','penn ave','john muir','prez','john chapman','rene russos','anthony hopikins','jeff brohm','geroge carlin','thomas the tank engine?','plow king','chris hadfield','jesse','flacco','al galdi','bezos 2020','curacao','billy ray','lol nice.','sister act','enrique iglesias','enrique','richard prior','neal brennan','ta','haah ya','woodrow wison','speaking','whil','glee','yea nba','ben rothlesburger','luckily nike','saint cheerleaders','kareem abdul-jabarrs','aaron hernandez','mckinley','qb paul d hubbard','mariota','deshone kizer','kizer','elena meyers taylor','womens usa','tsubasa','allan iversons','ric barry','ethan happ','conductors','my shih tzu','bill the goat','bob beattie','simpssim','kurt cobain','apps','kinda of tinny','selma','laura','karolina wilson','ingraham','laura ingrahams','elizabeth mckeown','imagine vp clinton','xmas haha','alice johnsons','kim kardashian west','john wilkes boothe','ilike southpark','john kelly','starfruit','bret','michael vic','vic','lauletta','huddle','mike francesca','mike francesa','virginia teach','yea smith','hilinski','patriots green-ellis','geroge washington','hill-dawg','jason momoas','lol kahl drogo','prince harry','meghan markle','henry boltons','sloan','tom wolfes','tom wolfe','serge martins','pro-putin','classical latin','windrush','shockingly','hanson haha','beforetv','pro quo','luckily hanson','angela merkel','dee','alan diaz','elian gonzales','margo largo','tappan zee','leaving neverland','ben jarvus','calvin murray','buzz lightyear','trump-clinton','michael keatons','haha omg','bobby bones?n','amber wyatt','omg kim jong un','hobby','kim jeong hoon','kareem hunt','otto','haha very dumb','trump lol','whopper lol','cabrera','joe kennedy','andrew breitbart','bannons','george washingtons','top banana','quiting','paul d','barbara alston','gerry goffin','toni alston','phil spector','lana clarkson','knowing the simpsons','ron ron','what;s','sherry hall','celene dion','bachelorette','sweeny todd','viking','stabler','nguyen mai khoi','mai khoi','dissent','frank sinatras','blinky','brett','alex smith - smart','c. payne lucas','free healthcare foos','malcolm perry','kelly-moore','qb perry','ivan jasper','jasper','kareem adbul-jabbar','talladega nights','lol lol','woody harrelson','uncle buck','elis','aaron jones','david beckan','da bears','lawrence','lil wayne green and yellow','cyplenkov','macho man randy','neil degrasee tyson','john stossel','dieon sanders','chris benoit','perfect','eric bischoff','razor ramon','scott hall','diamond dallas page','he hate me','derwin james','alex something','jonathan allen','sean tyler','bob kraft','bold','haha tat','adam rippon','macys','phil knight'],
'PRODUCT':['plex','eohippus','f','the chrome os','the little mermaid','force awakens','playstation 2','emmys -47','cherokee','choctaw','dino','chaos','nwa straight outta compton','galileo','a nat geo','hollywoods biggest 6','retro','team spider','maps','hal 9000','cat cafes','magic the gathering','ncaa champion','playstation 3s','the original star wars','the star wars franchise','google plus hangouts','spot mini','mars bars','bets','bce','release','jt','model','in1955','volta','werent','liver','the force awakens','walkman','lara croft','king candy','skyrim','net worth','classic rock','earth gaia','f430','barnes','sunshine','200k','milkman','cathode ray tube amusement','guccio','mavs','big hero 6','superheroes','the last jedi','weird','bandwidth','the blue ear','earth 616','breath','best comedy','a star is born','the jazz orchestra','3/5s','warriots','lords','seo tajij','the star wars for','remake','jay-z-blue','enigma','stormi','ms windows','burn','goblin','tg387','planet nine','exhausting','fat bastard','bird box','the python','the model s','model x','model 3','m6','bolt','f150','mra.text twitter','tide pod','the rocky horror picture','guinness worldrecords','the extended universe','350z','subway','legend of zelda','f zero x','bojack horseman','funny steph curry','adrenalin','enimen','ranch','austratia','roam','macs','sonata','hyundais','red wings','foxhole','a nat geo wild','broke','tale','st bernards','the compliment battle','bryce vines','soccerroos','fiba','throw','destino','the scarlet witch','strongbow','kyle','voyager','the model t.','the uss little rock','mars attacks','playstation 4','the uss govt land','the ford model t','detriot','the man who sold the eiffel tower','the godfather 2','black dog','the s un','youtube though.n','the star wars','trap adventure 2','the star wars solo','etemenaki','the shawshank redemption','the pink floyd','the net and hackers','mr sportscenter','ailes','air force rotc','the big bang','discovery','playstation 3','the fashion awards','shaun of the dead','game of throne','claritin','andriods','black','the playstation vr','a playstation 2','shapovalov','billboard hot 100','malibu','shouldve','greektown','the all blacks','yorrick','dodge neon','caddyshack and stripes','amazon turk','caines','pigeon','787','amazon go','the fais-do-do','accord','gymnastics','the brick','wigs','glitch','the model t','the oc thunder','u of k','iconic','amazon fire tv','blazer','private','gasoline','senfield','romnaoffs','the black swallower fish','supernova','classic','300000 euro','beoutq','eureka','fatigues','the fender stratturntable','enforcers','jetta','lain','freak','risky business','thunderbird','motivation','stole','pokemon-750','abbot and costello','seattles','secrete','model-t','black struggle','razor','salahi','bengals','aristotles','the government','pekingese','turismo','professional race car','ark','the real slim shady','the tiny tunes','stimpy','the crashed car effect','the 70s show','roleit','gasthaus','bachmann','st','the tank engine','trump on snl','personalities','kellogg','quarterhorses','cadicall','aks','trumpsim','trumpish','challenger','h and k','the word wars','frech','playstation vue','appollo','guns n roses','excel','cards','ever','atari 2600','the naked hulk','marjory','model t car','pencil','bradley','newwars','newswars','fords','model t','bmore','all star','bears','roof','the dumbo ride','thingi','veterans','youtube combined','2340 mlb','pj masks','ez','flight 93','the apple ii','trump keeps','last man standing','classic radio dramas','the model','mustangs','real big fish','parade','tribalism','meatloaf','youtube netflix','f-zero x.','f-zero','wendys','silly con','a netflix original','trumps presidential addresses','tb12','quartback','the bears haha','rangers','noise','the t model','the video referee','why cant we live together','calls','buccaneers','the redskins qb','corruption','the banana!','razor blades','golddigger','hundred and twenty-two','the midtown tavern','mega','aunt','air force one','music','c300','actress','mahommes','area 69','the foxhole radio','brannon','mtv cribs','cicada','im kinda glad','elicia','superstars','gameboy'],
'QUANTITY':['2000 degree','622 feet','a country mile','a ton','about 3 billion hours','1 mb','1mb','7-15 miles','84 foot','over 3/4 mile','45 degrees','about 7 miles','356 pounds','only 356 pounds','about 2 inches','4-5 foot','6 tons','only 2 inches','between 2 inches','9 feet','six tons','over 300','000 gallons','around 4 million gallons','4 million gallons','312k gallons','about 312','000 gallons','4','0','000 gallons','2 inch','9 foot','4500 mpg','between 7 and 15 miles','7 to 15 miles','up to 15 miles','300 pounds','50 foot','160mph','15 miles','four hundred million','20 k lol','256mb','three hundred thousand euros','4500mph','5000 yr','7 foot 6 inches','160 mph','500k mph','5x hotter','the 15 miles','9 shuts','over six feet','7 miles','10 miles','30 degrees celsius','90 min','about 5 mins','455 light','2000 degrees','1938 meters','3g','a birds feet','only two inches','about 356 pounds','30 pounds','66 pounds','2 feet 9 inches','30 pound','2450 pounds','up to eight pounds','64 bits','20 grand slam','5 cm','2.75 m.','50 feet','almost 35 million miles','50 ft tall moon','7300 pound','a red moon','3 billion hours','three billion hours','almost 2000 meters','one third hollow','7 ft 6 inch','312','000 gallons','50-100 mile','about 50 miles','100 miles','one mile','160 miles per hour','844 miles','138 pounds','2 min','only 1 min','10 feet','four feet','312000 gallons','8 pounds','about 8 pounds','only 58.46 million','only 1mb','300','000 gallons','four million gallons','22 yards','3/4 mile','1 min','50 foot tall moon','this 50 foot','1 min and','1000 copys','a moon','about 20000 miles','about 100 pounds','11 min','eight mile','tens of meters','900 degrees','some 455 light','a mile','almost a mile','three mcdonald','250 square meter','4 miles','4 plus inch','40 pounds','about 1 mb','about 4500 mph','one mb','1 mb ram','10 gb','the extra mile','up to 20 mph','4 billion miles','20 mph','up to 100 feet','more than 2.2 billion','six mile','six miles','6 foot 10 inch','1500 pound','a billion hours','1','938 meters','100mph','40 mile','40 miles','more than 8 pounds','8 pound','500 meters','55 meters','over 5 pounds','5 pounds','0.083333333','25 billions hours','9ft','85 degrees','almost 60 degrees below zero','a hundred sixty miles per hour','65 degrees','just 650 feet','650 feet','12','000 feet','11 acre','50mph','1.39 million km','over 300000 gallons','over 4 million gallons','the 4.25 inch cup','around 312','000 gallons','2 inches','8 bits','only 1 mb','only 50 mil','4 and 1/4 inches','up to four million gallons','only about 9.4 inches','only 18 inches','around 312 thousand gallons','two inches','13 lol','6 foot','3 finals','8 mile','a meter','only 2.7 inches','a few miles','18.7 million acres','100 mph','35000 feet','about 5x hotter','2500 mph','2 feet','up to 7 miles','17','000 miles per hour','10 pounds','13 nominations','around 13 hertz','2 seventy foot','five feet','33 shakespeare','about 6 paris','3 pointer','5 acres','12 inches','100 pounds','2000 meters','one megabyte','64 bits.n','a 1 mb ram computer','up to 160 mph','160 miles','8','000 square foot','a 3/4 mile','2.7 inches','2.7 inch','a metre to 33.6 metres','the 1000 miles','21 nominations','69 camaro','7 and 15 miles','live about 10 miles','two left feet','about a meter','a hundred pounds','312 000 gallons','70 inch','1/3 hollow','124 degrees','six foot','3 oscars','8gb','eight pounds','4 to 6 pounds','3 pounds','about 300','000 gallons','million gallons','about 12 000 gallons','200 yards','only 2','7 inches','4500 miles per hour','150 kilograms','2 meters','3000 foot','about 45 miles','12 ft','52 feet','40 acres','that many miles','76 miles','30 degrees','1.39 million kilometers','3 g tower','4.25 inches','the 312','000 gallons','50 pounds','161 mph','only 365 pounds','like 29','000 feet','just 2.7 inches','65 millioon','about 8 ounces','a metre to 33.6 meters','around 312 000 gallons','hundreds of miles','only about three inches','only 10 inches','1mb ram','less than 1mb','at least 3 billion hours','more than24 acres','24 acres','30 miles','102 degrees hotter','5 degrees','3 books','110 degrees','65 inch','live about 40 miles','about six tons','about 6 tons','59 degrees','5 mph','more than 2.2 million','less than 3 inches','1 million consoles','256 mb','three consoles','about 7-15 miles','300','000 euro','seven miles','25 miles','almost 100 mph','2m apps','1tb','9pm-12:00 am','around 13','3 billions hours','only 4.25 inches','15 pounds','7 nominations','75-85 mph','up to 5 miles','4 or 5x hotter','16gb','the 8 mile','between 5 and 6 thousand dollars','4-5pm','93 million miles','between 7-15 miles','7 inches','about 15 miles','only 3 inches','roughly 100 pounds','3 min','100 lol','60 feet','green mile','356 pound','170 degrees','171 degrees','158 degree','8 mph','32 000','32','000 books 3/4 miles','over 1000 mph','about 7 to 15 miles','over 6','000 feet','6.5 inch','every couple of miles','almost 45 degrees','160 miles an hour','hundreds of feet','one 1 mb','about one megabyte','9.4 inches','18 inches','between 7 to 15 miles','about 3 inches','5','000 y','645 fifth avenue','about 2.7 inches','no just 2.7 inches','55 inch','about 8 miles','5.25 inch','about 1mb','10 mph','65 mph','millions of a meter','about 30 meters','only about 3 inches','three miles','as much as dark side','300 ft','2 ft','15 mph','300 feet','less than three inches','2 or 3 inches','thousands of miles','10-15 million','10 mile','half a million miles','3 consoles','25 billion hours','almost three hundred thousand euros','356lb grand piano','about 15 pounds','a few extra pounds','7 foot','7 to 15 km','at least 15 miles','live half a mile','32 mil','12 feet','15 feet','ten feet','10 ft','40 tons','8 yr','over 7 feet','about 5000 pounds','356 pound grand piano','20 miles','about 1.39 million kilometers','5 foot','20-30 pounds','fifty pounds','100+ miles','50 bc','68 camaro','4000 miles','160 mile','25 acre','6 min','up to 100 mph','around 8 pounds','about 4','0','000 gallons','over 200 mph','159mph','an extra inch','inly 3 inches','about 3 world cup','100 feet','35 mph','18 min','over 300k gallons','however many feet','5 min','just over 2 inches','50 miles','3am','455 million light','about 8 mile','4 more inches','up to 160mph','1.39 million kilometer','90 tons','only 1938 meters','1/3rd hollow','more than 50 miles','16','000 square foot','around thirty two million','321','000 gallons','1','100 pounds','about 10 miles','1 megabyte','several thousand feet','over 40','000 feet','2 mores','4','500 mph','12 foot','9:00 pm-12:00 am','zero-g','98 yards','up to sixteen miles','16 miles','sixteen miles','two degrees','about 312 000 gallens','about 312000 gallons','2','699','990 its 6','000 square feet','the guy feet','a quarter mile','3 inches','1100 pounds','2650 mile','75 mph','3112 thousand gallons','312 gallons','100 pound','only 2.1 inches','112 nominations','20 timer','almost 300','000 gallons','3 nominations','3 feet','105 lol','4.24 inches','33.6 m.','some 110 foot','110 ft','2.6 miles','as high as 296 mph','4000000 gallons','6am','sub-300 mph rickshaw','about three hundred thousand euros','five mile','one billion hours','3 lol','580 mil','46cm','50 foot moon','three inches','75 degrees','around 78 degrees','a couple of hundren miles','33 meters','1000 pounds','more than 4','0','000 gallons','4million gallons','3 miles an hour','around 7 miles','only a few miles','three billion','more than 20 tons','only 5 inches','about 15 feet','about 16 feet','20','000 to 40','000 pounds','as long as 40 feet','under 5 feet','60 miles per hour','more than 2000 yards','over 800 pitches','9.4 inch','18 inch','29','000 feet','11 degrees','206k / hour','25 mph','30 min','18 mph','10 pound','25 mile','over 300 yards','160 pounds','1412 yards','about 1','100 pounds','only a few inches','40','000 miles','650','000 tons','18mph','10mph','110 yards','about miles','6-7 feet','the 3 billion hours','just 66 yards','400 meters','40 plus and millions','over 1','000 pounds','60 mil','1.100 pounds','352 yards','more than 40 yards','375 passing yards','250 to 300 pound','50 td','as much as 4000 yards','only 11 min','about 11 min','57 yards','20 foot','2-3 pounds','million of miles','2','100','000 squire miles','21.64 miles per hour','9 inch','an 18 inch hoop','a ton of yards','seven inches','100 yards','just a few square feet','over 5000 yards','300 pound','80 mph','about 20 mph','nearly 1.5 million kilometers','only two quarterback','1','176 yards','about 1/4 inch','about 40 miles','415 yards','282 yards','107 yards','1','100 pound','a thousand pounds'],
'TIME':['the night','two and half hours','only 2.5 hours','tonight','a good night','only 5.5 hours','40 hours','3 billon hours','this fine evening','midnight','a great night','afternoon','this afternoon','a good afternoon','morning','3 hours','only 2 hours','24 hour','1 minute and 17 seconds','one minute and 17 seconds','only 5 1/2 hours','24 hours','evening','2.5 hours','2 hours and a half','10 per night','29 minute','nearly 30 minutes','11 hours','almost 30 minutes','five minutes','over 11 hours','5 minutes','22 hours','2 1/2 hours','early in the morning','29 minutes','a good evening','night','a little over two hours','5.5 hours','a 40 hour day','about 1 minute','the 24 hours','those peak hours','last night','8 seconds','several seconds','three hours','this morning','the evening','the late hours','an hour','late night','an afternoon','about 15 minutes','more than 24 hours','just over 5 hours','2 hours','one night','a lovely night','this evening','a fun afternoon','couple minutes ago','8:07 am eastern time','odd hours','overnight','a nice evening','5 minutes in 2013','12 minutes 45 seconds','about a minute','a minute','about 8 seasons','only about 6 hours','20 hours','400 hours','every minute','the hour','some night','5 hours','the 20 hour work day','20 hour','a night','9 pm to 12 am','a midsummer night','a nice night','15 minutes','about 1 minute and 17 seconds','9pm to 12am','38 hours','him hours','hours','mornings','the morning','every night','a good morning','about 5 minutes','about five minutes','later today','an awesome night','only 5 hour days','a great afternoon','at least seven minutes','only 11 hours','11 hours and 3 days','all night','many hours','the morning of jan. 13th','one 24 hour','less than two minutes','more than one moon','a wonderful night','only 455 light years','4k hours','all hours','more than 2.5 hours','1 second','early in the 1900s','hotter','7 minute','7 minute miles','the late night','2 hour','some late night','10 minute','the 24 hour','every 44 seconds','about three hours','five minutes in 2013','hour','those hours','30 minute','a half hour','a few hours','1.5 hours to 8 minutes','the next few minutes','17 seconds','121 minutes','30 seconds','30 minutes','just two hours','half of peak hour','just over 24 hours','just over a minute','about 4 hours','1 minutes and 17 seconds','the peak hours','10 minutes','four minutes and 33 seconds','a half hours','tons of hours','four or five hour','last minute','the daylight hours','46 minutes','37 minutes','1 minute','one minute','a 5 minutes','peak hours','5.5 hour','only 4 hours','like 100 hours','50 hours','60 minutes','a single night','5','5 hours','1 minute 17 seconds','11 hours 5 minutes','only 6 hours','about 40 hours','6 hours','only a minute and 17 seconds','18.5 hours','the 5.5 hour days','5 minutes on 2013','this all night','like 2 seconds','55 hours','five minute','20 minutes','150 minutes','each minute','the hours','less than a second','the other night','a mere 5 minutes','4 wheels','10 hour','6.43 seconds','between the hours of 9pm to midnight','every evening','late at night','the 9 pm to 12 am','later at night','about 3 hours','2 seconds','between the hours of 9pm-12am','9pm-12am every night','weird hours','7 minutes','an hour long','around 9 pm every night','nighttime','up to 38 hours','the last 17 seconds','only 1 minute and 17 seconds','a few seconds ago','thought maybe 12 hours','nights','3','000 hours','more than 400 hours','eleven hours','61 last night','a late night','about six hours','25 hours','between 9pm and 12','0.833333333','9am','the evening hours','32 lol','less than 3 hours','9 a.m. to 12am','an hours','seconds','minutes','monday night','my five minutes','3 minutes','about 400 hours','every minute of the day','one hour','live a few hours','thursday night','the last minute','70 minutes','50 hour','about half an hour','earlier today','each night','short hours','20 yearsn','5.5 hour days','nine hours and 26 minutes','nine hours and 30 minutes','so few daylight hours','the first quarter moon','a few nights','0.724305556','9 hours and 26 minutes','the 11 hour','the 15 minutes','only 5 minutes','between 9pm and 12a','at least 20 minutes','only 10 minute','ten hours','9am to noon','15 seconds','around 30 last night','three dog night','our moon','a couple hours','later tonight','20s night','9am to 12am','the 8 seconds','four hours','six hours','one moon','more like 90 minutes','the working hours','every morning','2am','this beautiful morning','all 24 hours of the day','like half an hour long','ten seconds','about 10 hours','10 hours','later that night','almost every night','a little crazy haha','little 30 minute','every 10 minutes','this early morning','only about six hours','around five to six feet','the morning hours','minute','70 hours','every hour','earlier and','a whole hour','that night','hours upon hours','around 5:30 pm','the last 5 minutes','a few minutes','9 p.m.','every 22 seconds','3 bil hours','7 seconds','us hours','100 night','50bc lol','almost 2 hours','a couple of weekends','only 54 colors.nthe','118 minutes','bernard work forty hour','between 9pm and 12 am','every thursday night','a couple of hours','only 18 minutes','about two minutes','the first 5 minutes','the minute','the shifting daylight hours','the 7 minutes','about 15 seconds','just a few minutes','only about a minute later','64 bits now','less than a minute','just a few hours','good night','the last 15 seconds','8.5 millionth','friday morning','right 15 minutes','68 hours','date night','an interesting hour','just five minutes one day','a minute ago','between 9pm to noon','a little less than 300 to','taking hours','an accidental 8 minutes','8 minutes','no night','a cool evening','15-25 minutes','midmorning','her 40 hours','that tonight','60 seconds','6 hour','only 1 hour and 27 minutes','only 24 hours','the mere 24 hours','only 5','5 hours','seventeen seconds','9 odd hours','6-8 p.m.','7 p.m.','9 to 12 pm','thousands of hours','about 455 light years','half an hour','48 minutes','10 ft to 12','6-8 hour','zero hour','9 pm to 12 am','chill hours','this fine morning','4 hours','nine hours','100+ hours','1 1/2 hours','9 pm til 12 am','two hours','this 24 hour','a preview night','normal opening night','a few seconds','opening night','7am','oscars tonight','a fantastic night','1 minute ad 17 seconds','a whole afternoon','extra hours','a nice morning','12 hours','more than an hour','the first five minutes','3-4 seconds','0.375','4 minutes','36 hours','only live a few hours','mere seconds','eleven hour','11 hour','between 9 pm and 12 am','business hours','30 hour','about a minute and a half','1am','a lot of hours','saturday night','5 minutes and 40','all their minutes','more than 40 hours','0.299305556','about an hour','3 hour','5.5 hour long days','the same night','more than 5 minutes','about quarterbacks a minute ago','an interesting night','9 p.m. to midnight','48 hours','about 5 hours','midday','late night hours','a goods nights','12 hour','just evening','an off night','the afternoon','only 1 billionth','1-2 hours','a short night','so many hours','longer nights','10 minutes later','game minute','only a minute','many minutes','millions hours','72 hours','over 4 hours','youtube tonight','9am to 12 am','less than 2 hours','election night','40 minutes','longer than 5.5 hours','about thirty minutes','the first night','a hot minute','crazy hours','the last few seconds','two hours and a half','every sunday night','much hotter','sunday night','less than six hours','about an hour and a half','every 20 seconds','about 60 seconds','up to 20 hours','12 or more hours','1 hour','about 18 minutes','just five minutes','late evening','that morning','an evening','about 45 minutes','almost half hollow','about an hour inland','9 in the evening','9 pm to 12 pm','24 hours and 18 minutes','only 11 minutes','daytime','only so many hours','early the next night','a couple minutes','all the minutes','14 hours','8 a.m. to 10 p.m.','9 a.m. to 7 p.m.','just an hour','the 1 minute','the next minute','6 or 7 hours','the last 77 seconds','most evening','1 seconds','day/evening','29 lol','forty hours','20 hour days','how many hours','11 minutes','last like 3 hours','an entire afternoon','another hour','about 11 minutes','three minutes','around 11 minutes','5 1/2 hours','that minute','a 24 hour day','the 5.5 hour day','0.875- midnight','noon','several hours','just 1 minute','some last night','this time of night','the night hours','eight hour','couple of minutes','more than 11 minutes','a great evening','all evening','10 or 15 minutes','seven minutes','less than 6 hours','riight','one 1 time a year','110 minutes','the longer hours','18 minutes','the minutes','only about 11 minutes','1 lol','one minutes','only 1 hours','at least an hour','1 oclock','six seconds','live like 30 minutes','that hour','a mere minute','just 5 hours','thousand of hours','only 5 minutes and 40%','only being 11 minutes','just 11 minutes','15 seconds max','9-12 pm and half','an additional hour','0.1875','8 good hours','different hours','10:30 a.m.','like 30 minutes','5-10 minutes','the lunch hour','over 24 hours','about 30 minutes','some moon','fifteen hours','school hours','one morning','only last a few minutes','may hours','10-20 minutes','about 20 minutes','the average 11 minutes','9- noon','myself at night','12 hour days','almost 10 hours','late nights','about 10 or 11 minutes','less than an hour','the same night lol','that particular night','18 minute','about 7 or 8 hours','9pm-midnight','less than 2 minutes','the 11 minutes','9-12:00 am','at least saturday night','9 to 12 am','9-12:00 pm','last evening','an evening/','many *minutes','a couple of seconds','only last 11 minutes','some saturday night','0.333333333','11am','every 2 seconds','two minutes','between 9pm and 12 pm every day','earlier this morning','15 minute','more than 250 hours or 10 days','only eleven minutes','the 10 minutes','them night','one 3 pointer','every single minute','a few minutes ago','almost every morning','the next morning','169 minutes','up to 3 hours','those 11 minutes','ten minutes','dozen or so minutes','christmas morning','all the 11 minutes','up past midnight','60 minute','6 hour days','1/2 hour','earlier in the season','all 11 minutes','only do 11 minutes','the final two minutes','only a few seconds','last nights','3-4 hours','at least an hour and a half','roughly 11 minutes','over 11 minutes','about eleven minutes','eleven minutes','last about 3 hours','last for hours','3 plus hours','a lousy 11 minutes','average 11 minutes','at least three hours','only 7 minutes','more than 3 hours','2 and half hours','about 3 -4 hours','just 5 minutes south of lake erie','countless hours','every 4 minutes','less than the 11 minutes','12 minutes','every few minutes','a couple of minutes','all morning','like hours','a great morning','monday morning quarterback','9 pm to 12am','between 9 p.m. and midnight','3+ hours','a consecutive 11 minutes','only three hours','every couple of seconds','11 brutal minutes','about 10 minutes','some morning','the whole 11 minutes','his morning','4-5 hours','about 2 minutes','saturday morning','almost 3 hours','only 11 minutes woah','2-3 hours','an nice night','those few minutes','15 minutes early','how many minutes','one evening','the actual 11 minutes','most nights'],
'WORK_OF_ART':['none of these','come together','the tarzan st','silence of the lambs though','the brave','charlotte','tonight show','the godfather','under the sea','best picture','tyrion lannister on game of thrones','the color of money','the last samurai',' samurai','the half hour news hour','a nobel prize','curse of the bambino','astronomy towncommisioners trophy','next generation','1800','cock-a-poodle-do','a hard days night','the astonishing','the nobel prize for physics','the wiz','be a lion','ease on down the road','the theory of everything','amazon family','in the realms of the unreal','the marvel cinematic universe','back to back world series','the game of thrones','the joy of painting','the shining',' the omen','the greatest scientists are artists','the four feathers','cask of amontilliado','nightmare on elm street','uptown funk','dumbo the elephant','the nutcracker','the supreme achievement of the modern age in terms of comedy','the raven','romantic kissing','normal','a nobel peace prize','against all odds','in the air tonight','the posttoi','queen or led zeppelin','apollo 13','the jungle book','dog blood drives','fowl ice t','little big planet','the wall','beat it','the guinness book of world records','man of the woods','call of duty','the circus gallop','the crow','man in the woods','the imperial march','hee haw','the epic of gilgamesh','do you realize','born this way','the wrestler of the year award','the highest court in the land','the life of brian','you laugh','the odyessy by homer','if i ran the zoo','the cat in the hat','team kim','the spy who dumped me','girls trip','rough night','the hangover','harold and kumar','star wars - ever','the othello project','a honk kong cha-cha','the jerk','the matrix','to all the boys ive','netflix and chilling','to all the boys','the punisheramerican prometheus','pulitzer','parks and recreation','all you can ever know','love actually','dollhouse','let it go','the book of mormon','wreck-it ralph','all i want for christmas','the world wide web','the late great planet earth','to kill a mockingbird','bad romance','killing eve','the avengers','the avengers on netflix','spider-man cartoon','oscar for get out','darkside of the moon','high hopes','the marvel universe','all the stars','big fish','entirely elvis','sleeping','batman and the signal','hey jude by paul','stand by me','a song of ice','enders game','the lord of the rings','a stanley cup','a christmas story','destroy all monsters','american trilogy','crazy little thing called love','a new earth','the booker prize','the great gatsby','the brat pack','compliment battle','hotline bling!','thank me later','face book','the da vinci code','hey jude','normalman whos','golden hour','havent heard the album','batman or superman','the call of duty','guinness book','highlander ;) lol','star wars in navajo','mad hatter','greek literature','shake your hips','iâ€™m gonna leave you baby','a wrinkle in time','new gods','famous funnies','annihilation','marvel and universal','tell tale heart','original story','buzz','origin story','the exorcist','three identical strangers','the purge','ant-man','to serve man','hybrid theory by linkin park','busch light','mundane (but meaningful','born to run','the queen of england','wiz of oz','nwas straight out of compton','the searcher','wish you were here','selfish','why did you do that','hair body face','grease','obi two','wesbrook','wreck-it-ralph','the cask of amontiliado','the queen of soul','nobel prize','dell','fear the beard hardon','the mvp award in 2015','the hack a shaq','fear the beard','the mvp award','so you think you can dance','marvel cinematic universe','the importance of being ernest','the portrait of dorian gray','the ballad of reading gaol','star trek beyond','the universe','afeni shakur','never felt so good','the queen song','the daily show tv','young dolphs','o brother',' where art thou','the goblin','cosmic dust near and far','the midnight sun','player of the year in the dc metro','do the bartman','love never felt so good','goodbye horses','the honeymoon standup special','nerd','the academy award for best cinematography','the king of la','american gangsterjay z blue','the blueprint and the black album','the highest court on landsalt','fat',' acid',' heat','redditor','hulu through youtube','comeback season or','comeback season and so far gone','gods plan','westminster dog show','doggie in the window','do you realize by flaming lips','the flaming lips','who says you cant go home','the babe','re-write','star trek generations','meet the faukers','the shinning','the ark of the covenant','finding forrester','antidote to chaos','for colored girls','best picture of the year','like i said this year ive','bird watching','the epic','the tall blacks','can you ever forgive me','in a world','99 problems','black lady smith mambazo','everything is love','saturday night live','horse soldiers','a noble peace prize','childrens literature','islandborn','the decision','the other','youtube or hulu','the house on haunted hill','momma mia','the shining','the edgar award','sherlock on netflix','old hickory','the great santini','the price of tides','love & hip-hop new york','spot','kids who care','me too','hand on sloopy','the whole brain child','game night','lions and tigers and bears',' oh my','oscar for star wars','darkest hour','dear basketball','the drew carry show','the redditor','boiling pointstelephonethe price of fame','the harlem globetrotters','the walking dead before','the adventures of','the adventures of tom sawyer','most overrated celebrity','the last cruise','early man','shaun the sheep','hasnt','the incredibles','the science','the winters tale','winters tale','the winters tablehump day','the comedy channel','earth',' wind and fire','cast away','the ellen show','forever after','youve got mail','saving private ryan','films to see','a kind of magic','love yourself','the house with a clock','harry potter and the goblet','cut worms','life in the garden','the mask to bruce almighty','alice isnt dead','black ops','a nobel','a nobel prize in literature','nobel peace prizes','the one true god','nobel','the city of trembling leaves','trembling leaves','the tale of princess kaguya','the cider house','the color purple','the ballad of buster scruggs','the treasure of the sierra madre','california stars','a song of ice and fire','the tempest','busta rhyme','all i want for christmas is youtranshumanists','the boy who came back from heaven','the boy','the incredible mr limpet','the mask','mad men','drop em outthe rugrats movie i guess','when the levee breaks','patriot way','self travel','the nobel literature prize','the girl with the dragon tattoo','the nobel prize','the star trek prime directive','youtube and hulu','the hate u give','cloverfield paradox','the ps2 on','chilling adventures of sabrina','sabrina the teenage witch','the chilling adventures of sabrina','the grinch','stay up late','the jicks black cat','honorable compromise','ruse','the guinness book','private life','star trek voyager','top 10 things to do on a lazy sunday','tupac shakur or eminem','the book of lists','the 1/2 hour news hour','days like these','saturday night love','days like these','the marshall','me time','a way out','saved by the bell','his nobel prize','the nobel peace prize','the wolves','kiss an angel good morning','damnrumours','the reading room on central ave','gold diggerthe battle of hogwarts','the expanse on amazon','the love boat or fantasy island','raising hope','would!i','the shining i','the art of the deal','the secret window','isle of dogs','the last starfighter','edge of nowhere','the nothing in place','world wide web','the return of the fellowship of the ring to the two towers','youtube or netflix','goldeneye for nintendo 64','family ties','bosom buddies','legend','work from home','hazardous waste','suzuki','mcgyver','stars or capitals','thomas the tank engine lol','shear madness','days like thesethe funeral','ttall','the king of comedy','a bugs life','clock dance','elite','comedy central for a season','i love','ghostland','becoming dr ruth','howdy doody','silent saturday','youtube and netflix','taming of the shrew','cow palace','mad men with joh hamm','crazy j','terrified of bambi','the outsiderchristmas trees','the food ranger','emilia-romagna','semi-pro','paws for people','the stand','the puppet master','trick','migration and economy','when hell freezes over','cpt america',' thor',' hulk','that 70s show','black lighting','la liga','game over','whos on first','greys anatomy','the bundy tapes documentary','straight out','enlightenment now','still the same tour','the return of tone loc','pride and prejudice','king in the wilderness','mating habits of bigfoot and why women want him','bigfoot erotica','roger federer of paddle tennis','the man','altho','a thing','lindas','it takes a village','the hybrid theory by linkin park','beat itphd in astrophysics','weekend updates','the â½ news hour','two trains running','the piano lesson','the truman show','facebook and youtube','woulndt','the answer','the shop','the big fundamental','granny style haha','the best basketball player in the world','corner gas','porgy and bess','post malone','the sandman','electricity',' electricity','schoolhouse rock','telly','gundam','summit for the encouragement of banana republics','third rock from the sun','the sound of','the color of money and cocktail','the godfather part 1','ww2 or something','pave the iceland','keeping up appearances','the harlem globetrotters','flubber','the absent minded professor','the four','the regae','children of men','dancing with the stars','pandora or spotify','offenders game','the worm - dennis rodman','t boone pickens','super hero','villain','the led zeppelin album','five more minutessee you tonightsouthern belle','five more minutes','youve got a friend','watch the wizard of oz','the devil went down','stranger things on netflix','the truth initiative','kung fu fighting','the flash on the cw','do you hear the people sing','the flash so entertaining','love storydesert strom','the man who stepped into','avenu malcanu','the blacks','buy one take one','happy together','the state of the union address','the state of the union','simspons','classic rock and roll','the joshua tree','born on the fourth of july','southpaw','what the health','netflix and chill','efail','the making of the other side of the wind','barbi dreams','ballers','the bachelor','fall classic','bat nightmanifest','atom ant','the walking dead and game of thrones','the expanse','the flash','crazy little called love','tik tok','gangum style','monday night football','the peace prize','the next person you meet in heaven','straight out of compton','the raven','repetition','the nightflyer on netflix','world of warcraft for a few years','many words of love','the youngs','the founder','s3xy','the rugrats movie lol','the sinking of the titanic','a grammy for best spoken word','the good life','countryman','going clear','the happy potter','tallulah','pokemon gold','the good doctor','look to him','star trek next generation','deft punk','get lucky','youtube and spotify','the noble kinsmen','the realms of the unreal','howdy doody character','what have i done','crazy taxi','model t ford','shes','our souls at night','the netflix special nanette','civilizations on pbs','search for the holy grail','bartless','i love you','the academy awards this sunday','coach with craig t. nelson as hayden fox.','jocelyn flores','everybody dies on their nightmares','the remedy for a broke heart','mo money mo problems','love game','the walking dead and animal kingdom','billie jean king','rocket man','the prestige','thing of evil','the odd couple','bieber on youtube','white boy rick','epic rap battles of history','pain','dragon energy','views','foreign policy','fresh off the boat','spin city','girlfriend','girl friend','the bull moose','emmy for the invention of the yellow line','thank you for smoking','average joes','show and king of the hill','stuff you missed in history class','made in america','the tipping point','imagineers','the romance language','my heart will go on','the daily show','fire and fury','the shining',' pet cemetary','how i learned to drive','dream theatre','bullet','american tragedy','schindlers list','schindlers list','in the reals of the unreal','paige curry','do the banana','the 70s show','the flash and supergirl','the dots','two noble kinsmen','the tall blacks','the shadow','only the shadow','hearts in her eyes','made in china','mostly harmless','ballad of the whisky robber','the count of monte cristo','no pokemon go','turn on','kick it out','justin biebers baby','youtube rewind 2018','eternal sunshine of the spotless mind and the truman show','the thomas the tank','thomas the train for my kid.','golf',' tennis',' hockey','star trek tng','a golden globe award','a golden glove award','you can never say on television','point counter point','the nun','the skeleton key','oscar the grouch','the life of birds','the giant','not for long','somewhere in time','simpsons?n','except for ryan braun','facebook and twitter','the facts of life','yes man','cooking on high','the making of a murderer','in living color','everybody hates chris','tambourine','total blackout','cultural significance','takes two','outstanding sports personality - play-by-play','captive audience','a christmas carol','homer the whopper','soccer mom','mile marker 5','sixteen stone','amazing!apparently','i might regret this','the cosby show','comedians in cars','except for super bowl','emmy for the superimposed yellow line','takes a village','much ado about nothing','call me maybe','the truthlove fez','screw the president','the cable','elijah manning','first freedom','guvnuh','men in black','republic on the move','marvels the punisher','more life','the usa','oh we are','a masters degree','sunday night football','emmy for the yellow first down line','sms','the handmaids tale and the simpsons','the shadow knows','world toilet day','gee coach','in bill we trust','eli manning of the new york giants','a mad house','rut bader ginsber','dream girls','in the realms of the unread','patiots','the witcher','flight of the bumble bee','circus galup','saturday night life','the team 980','1/2 hour news hour','bachelors degree','thomas the tank on pbs','football and the olympics','the agony of modernization','the government rap','meghan mania','the right stuff','bonfire of the vanities','the night wolves','celtic love spoons','a pulitzer prize','the honk kong cha-cha championship in','caveman','thomas the train with my kids.lol','ww','da doo ron ron','theres no other like my baby','a masters degree','the capitalism rap','taryn manning','black and yellow','the lannisters of the nfl','the law firm']}

# %%
# Get list of keys that contains the given value
#Topics will contain combined topics for all rows, row wise.
topics = []
for sent in data['message']:
  s = sent.lower().split()
  list_of_keys = []
  for i in s:
    keys = [key
                    for key, list_of_values in Tag_dict.items()
                    if i in list_of_values]
    if keys:
      list_of_keys.extend(keys)
  list_of_keys = list(set(list_of_keys))
  topics.append(','.join([str(elem) for elem in list_of_keys]))

# %%
topics
# Out:
# ['ORG,NORP,GPE',
#  'ORG,NORP',
#  'ORG',
#  'DATE,ORG',
#  'ORG',
#  'ORG,GPE',
#  'ORG',
#  'FAC,ORG,GPE',
#  'ORG',
#  'ORG,NORP',
#  'PERSON,ORG,NORP',
#  'ORG,PERSON,GPE',
#  'ORG,DATE,GPE',
#  'ORG',
#  'ORG,PERSON',
#  'ORG,PERSON',
#  'ORG,GPE',
#  'ORG,DATE',
#  'ORG,PERSON,GPE',
#  'FAC,DATE',
#  'DATE,GPE,PERSON,ORG,NORP,EVENT',
#  'DATE,GPE,PERSON,ORG,EVENT,CARDINAL',
#  'ORG,PERSON,DATE',
#  'ORG',
#  'DATE,GPE,ORG,NORP,CARDINAL',
#  'ORG,GPE',
#  'ORG,CARDINAL,GPE',
#  'ORG,PERSON',
#  'ORG,GPE',
#  'ORG,GPE',
#  'ORG,PERSON,CARDINAL,GPE',
#  'ORG,PERSON,GPE',
#  'ORG,GPE',
#  'ORG,GPE',
#  'DATE,NORP,GPE',
#  'ORG,GPE',
#  'ORG,PERSON,CARDINAL,GPE',
#  'ORG,PERSON,GPE',
#  'ORG,GPE',
#  'ORG,PERSON,CARDINAL,GPE',
#  'PERSON,NORP,ORG,GPE',
#  'ORG,NORP,CARDINAL,GPE',
#  'ORG,GPE',
#  'DATE,ORG,GPE',
#  'ORG,PERSON,DATE',
#  'GPE,PERSON,LOC,ORG,CARDINAL',
#  'DATE,NORP,LOC,ORG',
#  'ORG,DATE,CARDINAL,GPE',
#  'DATE,NORP,ORG',
#  'DATE,PERSON,ORG',
#  'ORG',
# ...

# %%
topics1 = pd.DataFrame(topics)

# %%
df1 = pd.DataFrame()
df1['speaker'] = np.where(data['speaker']=='Speaker 0','0','1')
df1['message'] = data['message']
df1['tags'] = topics

# %%
df1.to_excel('/test_tagged.xlsx')
